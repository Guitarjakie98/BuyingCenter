# %%
# Core
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning / Stats
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# %%
TechPlay_df = pd.read_excel("/Applications/WorkDataSets/Demandbase Exports/Tech Play List.xlsx")
TechPlay_df.columns.tolist()
# Out:
# /opt/anaconda3/envs/jupyter_env/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ['Hierarchy Name',
#  'Company Name',
#  'Tech Play Type',
#  'Status Name',
#  'Name',
#  'ATS Name',
#  'Notes',
#  'Next Steps',
#  'Quantity',
#  'Units',
#  'Modified Date',
#  'Solution Associated']

# %%
Main_df = pd.read_csv("/Applications/WorkDataSets/Data Analysis/Filtered_Exec_Contact10.csv")
Main_df.columns.tolist()
# Out:
# ['party_number',
#  'email_address',
#  'person_name',
#  'party_unique_name',
#  'department_code',
#  'do_not_contact_flag',
#  'do_not_email_flag',
#  'do_not_mail_flag',
#  'job_title',
#  'job_title_code',
#  'sales_buying_role_code',
#  'company_name',
#  'account_type',
#  'country',
#  'state',
#  'city',
#  'line_of_business',
#  'CustomerId_NAR',
#  'CustomerName_NAR',
#  'account_segmentation',
#  'total_arr',
#  'ats_owner',
#  'ae_owner',
#  'GEO',
#  'CustomerId_NAR_Clean']

# %%
num_techplay = TechPlay_df["Company Name"].nunique()
num_matches = filtered_df["is_match"].sum()
percent_matched = (num_matches / num_techplay) * 100

print(f"{num_matches} matching contacts across {num_techplay} unique Tech Play accounts "
      f"({percent_matched:.1f}% contacts-to-accounts ratio).")
