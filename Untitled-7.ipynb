# %%
# Core
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning / Stats
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# %%
import pandas as pd

# ========= 1) F5 schema (Iteration 1) =========
F5_SCHEMA = {
    "f5_core_adc": [
        "F5 Networks", "BIG-IP", "Viprion", "F5 SSL Orchestrator",
        "F5 Load Balancer", "F5 Application Traffic Insight"
    ],
    "f5_security": [
        "F5 ASM", "F5 APM", "F5 Bot Defense", "F5 Distributed Cloud WAAP",
        "F5 Silverline", "F5 Web Application Firewall", "F5 Advanced WAF"
    ],
    "f5_cloud_services": [
        "F5 Distributed Cloud", "F5 Global Server Load Balancing",
        "F5 DNS", "F5 WAF", "F5 Cloud Services"
    ],
    "complementary_cloud": [
        "Azure", "AWS", "Amazon Web Services", "Google Cloud",
        "Kubernetes", "Azure Virtual Machines", "AWS AppStream"
    ],
    "complementary_identity": [
        "Okta", "Azure AD", "Ivanti", "Zscaler", "Ping Identity", "CyberArk"
    ],
    "complementary_workspace": [
        "IGEL", "Unicon", "Thin Client", "Workspace ONE", "Parallels", "Nutanix Frame"
    ]
}

TACTICAL_LABELS = {
    "f5_core_adc": {"high": "High F5 Entrenchment", "medium": "Moderate F5 Presence", "low": "Minimal F5 Footprint"},
    "f5_security": {"high": "Advanced F5 Security Stack", "medium": "F5 Security Present", "low": "No Security Modules"},
    "f5_cloud_services": {"high": "Cloud-Ready F5 Footprint", "medium": "Some Cloud Adoption", "low": "On-Prem Focused"},
    "complementary_cloud": {"high": "Cloud-Aligned", "medium": "Cloud-Capable", "low": "Not Cloud-Aligned"},
    "complementary_identity": {"high": "Identity-Ready", "medium": "Basic Identity Signals", "low": "No Identity Signals"},
    "complementary_workspace": {"high": "Workspace-Enabled", "medium": "Some Workspace Signals", "low": "No Workspace Signals"}
}

def _label_for(category: str, n: int) -> str:
    return (
        TACTICAL_LABELS[category]["high"] if n >= 2 else
        TACTICAL_LABELS[category]["medium"] if n == 1 else
        TACTICAL_LABELS[category]["low"]
    )

def process_technographics(df: pd.DataFrame, tech_col: str = "Technographics") -> pd.DataFrame:
    # ensure string and handle missing
    tech_series = df[tech_col].fillna("").astype(str)

    # pre-split once for speed
    split_list = tech_series.apply(lambda s: [t.strip() for t in s.split("|") if t.strip()])

    for category, keywords in F5_SCHEMA.items():
        # matches per row (comma-separated names)
        matches = split_list.apply(
            lambda items: [t for t in items if any(k.lower() in t.lower() for k in keywords)]
        )
        df[f"{category}_matches"] = matches.apply(lambda lst: ", ".join(lst))
        df[f"{category}_summary"] = matches.apply(lambda lst: _label_for(category, len(lst)))

    return df

# ========= 2) Load → Process → Save =========
# Use your path:
in_path = "/Applications/WorkDataSets/Demandbase_techno.csv"
out_path = "/Applications/WorkDataSets/Demandbase_techno_F5_analysis.csv"

# robust CSV read (keeps all as strings, tolerates odd encodings)
df = pd.read_csv(in_path, dtype=str, keep_default_na=False, encoding="utf-8-sig", engine="python")

# sanity check the expected column
if "Technographics" not in df.columns:
    raise ValueError(f"'Technographics' column not found. Columns present: {list(df.columns)}")

df = process_technographics(df, tech_col="Technographics")

# write output
df.to_csv(out_path, index=False, encoding="utf-8-sig")
print(f"Done. Wrote: {out_path}")

# optional: quick peek at new columns
cols_to_show = [
    "f5_core_adc_matches","f5_core_adc_summary",
    "f5_security_matches","f5_security_summary",
    "f5_cloud_services_matches","f5_cloud_services_summary",
    "complementary_cloud_matches","complementary_cloud_summary",
    "complementary_identity_matches","complementary_identity_summary",
    "complementary_workspace_matches","complementary_workspace_summary"
]
print(df[cols_to_show].head(3))
# Out:
# Done. Wrote: /Applications/WorkDataSets/Demandbase_techno_F5_analysis.csv
#                                  f5_core_adc_matches   f5_core_adc_summary  \
# 0  BIG-IP, BIG-IP Local Traffic Manager, F5 Netwo...  High F5 Entrenchment
# 1  BIG-IP, F5 Application Traffic Insight, F5 Net...  High F5 Entrenchment
# 2  BIG-IP Advanced WAF, F5 Networks, F5 SSL Orche...  High F5 Entrenchment
#
#              f5_security_matches  f5_security_summary  \
# 0  F5 Silverline DDoS Protection  F5 Security Present
# 1  F5 Silverline DDoS Protection  F5 Security Present
# 2                                 No Security Modules
#
#                            f5_cloud_services_matches  \
# 0  F5 Distributed Cloud Bot Defense, F5 Global Se...
# 1                    F5 Global Server Load Balancing
# 2                    F5 Global Server Load Balancing
#
#   f5_cloud_services_summary  \
# 0  Cloud-Ready F5 Footprint
# 1       Some Cloud Adoption
# 2       Some Cloud Adoption
#
#                          complementary_cloud_matches  \
# 0  AWS Amplify, AWS App Runner, AWS AppSync, AWS ...
# 1  AWS App Runner, AWS CloudFormation, AWS Cost E...
# 2  AWS Amplify, AWS App Mesh, AWS App Runner, AWS...
#
#   complementary_cloud_summary  \
# 0               Cloud-Aligned
# 1               Cloud-Aligned
# 2               Cloud-Aligned
#
#                       complementary_identity_matches  \
# 0  Azure AD B2C, Azure AD Privileged Identity Man...
# 1  CyberArk, Cyberark Privileged Access Manager, ...
# 2  Azure AD Privileged Identity Management, Cyber...
#
#   complementary_identity_summary complementary_workspace_matches  \
# 0                 Identity-Ready         HP Thin Client Hardware
# 1                 Identity-Ready            VMware Workspace ONE
# 2                 Identity-Ready
#
#   complementary_workspace_summary
# 0          Some Workspace Signals
# 1          Some Workspace Signals
# 2            No Workspace Signals

# %%
import pandas as pd
import csv
import re

# ---- F5 Schema and tactical labels (unchanged) ----
F5_SCHEMA = {
    "f5_core_adc": [
        "F5 Networks", "BIG-IP", "Viprion", "F5 SSL Orchestrator",
        "F5 Load Balancer", "F5 Application Traffic Insight"
    ],
    "f5_security": [
        "F5 ASM", "F5 APM", "F5 Bot Defense", "F5 Distributed Cloud WAAP",
        "F5 Silverline", "F5 Web Application Firewall", "F5 Advanced WAF"
    ],
    "f5_cloud_services": [
        "F5 Distributed Cloud", "F5 Global Server Load Balancing",
        "F5 DNS", "F5 WAF", "F5 Cloud Services"
    ],
    "complementary_cloud": [
        "Azure", "AWS", "Amazon Web Services", "Google Cloud",
        "Kubernetes", "Azure Virtual Machines", "AWS AppStream"
    ],
    "complementary_identity": [
        "Okta", "Azure AD", "Ivanti", "Zscaler", "Ping Identity", "CyberArk"
    ],
    "complementary_workspace": [
        "IGEL", "Unicon", "Thin Client", "Workspace ONE", "Parallels", "Nutanix Frame"
    ]
}

TACTICAL_LABELS = {
    "f5_core_adc": {"high": "High F5 Entrenchment", "medium": "Moderate F5 Presence", "low": "Minimal F5 Footprint"},
    "f5_security": {"high": "Advanced F5 Security Stack", "medium": "F5 Security Present", "low": "No Security Modules"},
    "f5_cloud_services": {"high": "Cloud-Ready F5 Footprint", "medium": "Some Cloud Adoption", "low": "On-Prem Focused"},
    "complementary_cloud": {"high": "Cloud-Aligned", "medium": "Cloud-Capable", "low": "Not Cloud-Aligned"},
    "complementary_identity": {"high": "Identity-Ready", "medium": "Basic Identity Signals", "low": "No Identity Signals"},
    "complementary_workspace": {"high": "Workspace-Enabled", "medium": "Some Workspace Signals", "low": "No Workspace Signals"}
}

# ---- Helper functions ----
def _label_for(category: str, n: int) -> str:
    return (
        TACTICAL_LABELS[category]["high"] if n >= 2 else
        TACTICAL_LABELS[category]["medium"] if n == 1 else
        TACTICAL_LABELS[category]["low"]
    )

def clean_technographics_field(text: str) -> list:
    if not isinstance(text, str):
        return []
    text = text.strip()
    text = re.sub(r'^[\|,;]+|[\|,;]+$', '', text)  # strip pipes/commas at ends
    text = re.sub(r'[^A-Za-z0-9\.\s\-_/]', ' ', text)  # remove ! and odd chars (keep .NET etc.)
    return [t.strip() for t in text.split("|") if t.strip()]

def process_technographics(df: pd.DataFrame, tech_col: str = "Technographics") -> pd.DataFrame:
    tech_series = df[tech_col].fillna("").astype(str)
    split_list = tech_series.apply(clean_technographics_field)

    for category, keywords in F5_SCHEMA.items():
        matches = split_list.apply(lambda items: [t for t in items if any(k.lower() in t.lower() for k in keywords)])
        df[f"{category}_matches"] = matches.apply(lambda lst: ", ".join(lst))
        df[f"{category}_summary"] = matches.apply(lambda lst: _label_for(category, len(lst)))

    return df

def clean_for_looker(df: pd.DataFrame) -> pd.DataFrame:
    new_cols = []
    for i, col in enumerate(df.columns):
        col_str = str(col).strip()
        if col_str == "" or col_str.lower().startswith("unnamed"):
            col_str = f"column_{i+1}"
        col_str = col_str.lower().replace(" ", "_").replace("-", "_").replace("/", "_").strip()
        new_cols.append(col_str)
    df.columns = new_cols

    df = df.dropna(axis=1, how="all")

    for col in df.columns:
        df[col] = df[col].astype(str).str.replace(r"[\r\n]+", " ", regex=True).str.strip()

    return df

def repair_csv_rows(input_path):
    with open(input_path, 'r', encoding='utf-8-sig', newline='') as f:
        sample = next(csv.reader(f))
        expected_columns = len(sample)
    repaired = []
    with open(input_path, 'r', encoding='utf-8-sig', newline='') as f:
        reader = csv.reader(f)
        for row in reader:
            if len(row) > expected_columns:
                row = row[:expected_columns]
            elif len(row) < expected_columns:
                row += [""] * (expected_columns - len(row))
            repaired.append(row)
    return repaired, expected_columns

# ---- Main execution ----
in_path = "/Applications/WorkDataSets/Demandbase_techno.csv"
out_path = "/Applications/WorkDataSets/Demandbase_techno_F5_ready_for_looker101.csv"

rows, expected_cols = repair_csv_rows(in_path)
df = pd.DataFrame(rows[1:], columns=rows[0])

df = process_technographics(df, tech_col="Technographics")
df = clean_for_looker(df)

df.to_csv(out_path, index=False, encoding="utf-8-sig")
print("✅ Done. File cleaned and ready:", out_path)
print(df.head(3).to_string())
# Out:
# ✅ Done. File cleaned and ready: /Applications/WorkDataSets/Demandbase_techno_F5_ready_for_looker101.csv
#                        account_name         journey_stage engaged_known_people                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 0  ACCENTURE PUBLIC LIMITED COMPANY  Known Contact Action                    0  |.NET|.NET 5|.NET Framework|100TB|11:11 Systems|123 Reg!|1CRM|1WorldSync|360Plus|3CX|3CX Phone System|3D CAD|3D Systems|3DEXPERIENCE Platform|3Dexperience|3Scale API Management|3T Logistics|3scale|84.51 Insights|AB Initio Data Quality Environment|AB Tasty|ABAP|ABB 800xA|ABC Fitness Solutions|ABINIT|ACBS|ACCELQ|ACI Base24|ACI Base24-eps|ACI Worldwide|AD Fusion|ADManager Plus|ADP|ADP Celergo|ADP GlobalView|ADP HR|ADP Payroll|ADT Access Control|ADTRAN|ADVA Optical|AFS Analytics|AG Grid|AIMS Flight Operations Systems|ALFABET|ALIS|AMAZON ELASTIC CONTAINER SERVICE (ECS)|AMC Technology|AMI|AMP|AMS Billing|AMS Insurance|ANSYS|AODocs|APS|ARGUS|ARGUS Enterprise|ARMIS|ASG Zeke|ASG-Cypress|ASM|ASP.NET|AT Internet|AT&T Global Network Client|AT&T IP Toll-Free|AT&T Managed Internet Service (MIS)|AT&T Managed Threat Detection and Response Service|AT&T Network-Based IP Remote Access|ATG Web Commerce|ATIVA|ATT|AUTOSAR|AVEV InTouch HMI|AVEVA MES|AVEVA NET|AVEVA Operations Control|AVEVA PI System|AVEVA System Platform|AWS Amplify|AWS App Runner|AWS AppSync|AWS Auto Scaling|AWS Backup|AWS Batch|AWS Certificate Manager|AWS CloudFormation|AWS CloudTrail|AWS CodeBuild|AWS CodeCommit|AWS CodeDeploy|AWS CodePipeline|AWS Command Line Interface|AWS Control Tower|AWS Cost Explorer|AWS Data Lake Storage|AWS Database Migration Service|AWS Device Farm|AWS Direct Connect|AWS Elastic Beanstalk|AWS Fargate|AWS Global Accelerator|AWS Glue|AWS GovCloud|AWS IoT|AWS IoT Core|AWS IoT Greengrass|AWS IoT Things Graph|AWS Lake Formation|AWS Lambda|AWS Managed Services|AWS Marketplace|AWS Mobile Services|AWS Organizations|AWS Schema Conversion Tool|AWS Secrets Manager|AWS Security Hub|AWS Service Catalog|AWS Shield|AWS Snowball|AWS Step Functions|AWS Systems Manager|AWS Transit Gateway|AWS Trusted Advisor|AWS WAF|AYLIEN|AZURE DATA LAKE STORAGE|Ab Initio|Abacus|Aberdeen|Absorb LMS|Academy|Accenture Cloud Infrastructure Managed Services|Accenture myConcerto|Accruent FAMIS 360|Accurate Background|Achilles|Aconex|Acronis|Acronis Backup And Recovery|Actifio|ActionIQ|Activated Insights|Active 24 Hosting|Active Campaign|Active Risk|ActiveBatch Workload Automation|ActiveControl|Activevos|Actuate BIRT Spreadsheet|Acturis|Acumatica|Acumatica Distribution Edition|Acunetix|Ad Dynamo|AdEspresso|Addi|Address Intelligence|Adecco|Adledge|Adobe Acrobat|Adobe Acrobat DC|Adobe Acrobat Pro|Adobe Advertising DSP|Adobe After Effects|Adobe Analytics|Adobe Animate|Adobe Audience Manager|Adobe Campaign|Adobe Campaign Classic|Adobe Captivate|Adobe Character Animator CC|Adobe Commerce|Adobe Connect|Adobe Content Repository eXtreme|Adobe Creative Suite|Adobe Customer Journey Analytics|Adobe Discover|Adobe DreamWeaver|Adobe Edge|Adobe Experience Cloud|Adobe Experience Manager|Adobe Experience Manager Forms|Adobe Experience Manager Guides|Adobe Experience Manager Sites|Adobe Experience Manager as a Cloud Service|Adobe Express|Adobe FrameMaker|Adobe GenStudio|Adobe Illustrator|Adobe InDesign|Adobe Launch|Adobe Marketing Cloud|Adobe Marketo Engage|Adobe Photoshop|Adobe Portfolio|Adobe Premiere Pro|Adobe Real-Time CDP|Adobe RoboHelp|Adobe Sign|Adobe Target|Adobe Workfront|Adobe XD|Adsp|Adyen|Aerohive Networks|Aetna|Agency|Agent Image|Agile CRM|AgilePoint|Agility CMS|Agility Software|Agiloft|Ahrefs|Airtable|Aito|Akamai Content Delivery Network (Cdn)|Akamai DNS|Akamai HD|Akamai Image & Video Manager|Akamai Rum|Akeneo|Alation|Alation Data Catalog|Albert.ai|Alcatel Lucent|Alertus|Alex Solutions|Alfresco Content Services|AlgoSec|Algolia|Algonomy|Alias Concept|Alibaba|Alibaba Cloud Container Service for Kubernetes (ACK)|All Siemens PLM Products|AllegroServe|Allen-Bradley|Alliance Gateway|AlphaSSL|AlphaSense|Altair HyperMesh|Altair HyperWorks|Altair OptiStruct|Altera Sunrise|Alterian|Alteryx|Alteryx Server|Altice|Altiris|Altiris Asset Management Suite|Altium|Altizon|Amadeus|Amadeus Airline Platform|AmazingHiring|Amazon|Amazon API  ...
# 1                        Servicenow  Known Contact Action                   13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 2                     Kyndryl, Inc.  Known Contact Action                    6  |.NET|.NET 5|.NET Framework|123 Reg!|1Password|3D Systems|3DEXPERIENCE Platform|3Scale API Management|3scale|4project|6sense|A10 Networks|AB Initio Data Quality Environment|ABAP|ABC Fitness Solutions|ABINIT|ACCELQ|ACI Worldwide|ACL Analytics|ACLS|AD Fusion|ADP|ADP Payroll|ADT Access Control|AG Grid|ALIS|AMD Radeon|AMO|AMP|AMS Insurance|ANSYS|ANSYS Fluent|ANSYS Icepak|ANTLR|AP Images|API Suite|APS|ARMIS|ASG-Cypress|ASG-TMON|ASM|ASP.NET|AT Internet|AT&T Global Network Client|AT&T IP Toll-Free|AT&T Managed Internet Service (MIS)|AT&T Managed Threat Detection and Response Service|AT&T Network-Based IP Remote Access|ATIVA|ATT|AVADA|AVEVA PI System|AWS Amplify|AWS App Mesh|AWS App Runner|AWS Backup|AWS Batch|AWS Cloud9|AWS CloudFormation|AWS CloudTrail|AWS CodeBuild|AWS CodeCommit|AWS CodeDeploy|AWS CodePipeline|AWS CodeStar|AWS Config|AWS Control Tower|AWS Cost Explorer|AWS Data Lake Storage|AWS Database Migration Service|AWS Direct Connect|AWS Fargate|AWS Glue|AWS GovCloud|AWS Guardrails|AWS IoT|AWS Key Management Service|AWS Lake Formation|AWS Lambda|AWS Machine Learning|AWS Managed Services|AWS Marketplace|AWS Migration Hub|AWS Nitro System|AWS Organizations|AWS Secrets Manager|AWS Security Hub|AWS Service Catalog|AWS Shield|AWS Step Functions|AWS Systems Manager|AWS Trusted Advisor|AWS WAF|AZURE DATA LAKE STORAGE|Ab Initio|Abbott Instrument Manager|Abbott M2000 Realtime System|Absorb LMS|Accenture Cloud Infrastructure Managed Services|AccessData|Achilles|Acosta Group|Acoustic|Acquia|Acrolinx|Action Kit|ActivTrak|Activated Insights|Active 24|Active Dataguard|Active-X|ActiveControl|Activiti|Actuate BIRT Spreadsheet|Acunetix|Ad Dynamo|AdEspresso|AdImpact|Ada Support|AddThis|Adenza Group|Adobe Acrobat|Adobe Acrobat DC|Adobe Acrobat Pro|Adobe After Effects|Adobe Analytics|Adobe Audience Manager|Adobe Campaign|Adobe Campaign Classic|Adobe Captivate|Adobe Character Animator CC|Adobe Commerce|Adobe Content Repository eXtreme|Adobe Creative Suite|Adobe Customer Journey Analytics|Adobe DreamWeaver|Adobe Experience Cloud|Adobe Experience Manager|Adobe Experience Manager Forms|Adobe Experience Manager Guides|Adobe Experience Manager as a Cloud Service|Adobe Fonts|Adobe FrameMaker|Adobe GenStudio|Adobe Illustrator|Adobe InDesign|Adobe Journey Optimizer|Adobe Launch|Adobe Learning Manager|Adobe Marketing Cloud|Adobe Marketo Engage|Adobe Photoshop|Adobe Portfolio|Adobe Premiere Pro|Adobe Real-Time CDP|Adobe Sign|Adobe Target|Adobe Workfront|Adobe XD|Adstra|Adverity|Adversarial Robustness Toolbox|Aegir|Affinity Designer|Agency|Agile CRM|Agility CMS|Agility Software|Aha!|Ahrefs|Airbyte|Airtable|Akamai Bot Manager|Akamai Content Delivery Network (Cdn)|Akamai DNS|Akamai Edge|Akamai HD|Akita|Alation|Alation Data Catalog|Albert.ai|Alchemer|Algolia|Alibaba|Alibaba Cloud|All Hours|All Siemens PLM Products|Alliance Gateway|Almond|AlphaSSL|Alteon Network Load Balancer|Alteryx|Altiris Asset Management Suite|Altium|Altium Designer|Amadeus|Amadeus Airline Platform|Amazon|Amazon API Gateway|Amazon AWS|Amazon AWS Identity And Access Management (IAM)|Amazon Alexa|Amazon AppFlow|Amazon Athena|Amazon Aurora|Amazon CloudFront|Amazon CloudWatch|Amazon Comprehend|Amazon Connect|Amazon DynamoDB|Amazon EC2 Auto Scaling|Amazon EMR|Amazon ElastiCache|Amazon Elastic Container Service|Amazon Elastic File System (EFS)|Amazon EventBridge|Amazon GuardDuty|Amazon Hosting|Amazon Inspector|Amazon Kendra|Amazon Kinesis|Amazon Kinesis Data Firehose|Amazon MSK|Amazon Machine Image|Amazon Macie|Amazon Polly|Amazon QuickSight|Amazon RDS for MySQL|Amazon Redshift|Amazon Relational Database Service (RDS)|Amazon Route 53|Amazon S3|Amazon SageMaker|Amazon Simple Email Service (SES)|Amazon Simple Email Services (SES)|Amazon Simple Notification Service (SNS)|Amazon Simple Queue Service (SQS)|Amazon Textract|Amazon Timestream|Amazon Transcribe|Amazon Webstore|Amazon WorkSpaces|Amdocs|Amerge|American Express| ...

# %%
df_test = df.drop(columns=['technographics'], errors='ignore')
df_test.to_csv("/Applications/WorkDataSets/Demandbase_test_no_tech.csv", index=False, encoding="utf-8-sig")
print("✅ Exported test file without Technographics column")
# Out:
# ✅ Exported test file without Technographics column

# %%
import csv
import re

input_path = "/Applications/WorkDataSets/Demandbase_techno.csv"
expected_columns = None

illegal_pattern = re.compile(r"[\x00-\x08\x0B\x0C\x0E-\x1F]")  # control chars

with open(input_path, "r", encoding="utf-8-sig", newline='') as f:
    reader = csv.reader(f)
    for i, row in enumerate(reader):
        if i == 0:
            expected_columns = len(row)
            print(f"Header detected with {expected_columns} columns.")
            continue
        
        issues = []
        
        # Check column count
        if len(row) != expected_columns:
            issues.append(f"Column count mismatch: {len(row)} columns")
        
        # Check each cell for illegal control characters or unescaped commas
        for col_index, value in enumerate(row):
            if illegal_pattern.search(value):
                issues.append(f"Illegal character in column {col_index+1}")
            if "," in value and not (value.startswith('"') and value.endswith('"')):
                issues.append(f"Unquoted comma in column {col_index+1}")
            if "\n" in value or "\r" in value:
                issues.append(f"Line break in column {col_index+1}")
        
        if issues:
            print(f"Row {i+1} issues: {issues}")
        
        if i > 20:  # stop after scanning first 20 rows to reduce noise
            break
# Out:
# Header detected with 7 columns.
# Row 2 issues: ['Unquoted comma in column 4']
# Row 3 issues: ['Unquoted comma in column 4']
# Row 4 issues: ['Unquoted comma in column 1', 'Unquoted comma in column 4', 'Unquoted comma in column 6']
# Row 5 issues: ['Unquoted comma in column 4']
# Row 6 issues: ['Unquoted comma in column 1', 'Unquoted comma in column 4', 'Unquoted comma in column 6']
# Row 7 issues: ['Unquoted comma in column 4']
# Row 8 issues: ['Unquoted comma in column 4']
# Row 9 issues: ['Unquoted comma in column 4']
# Row 10 issues: ['Unquoted comma in column 4']
# Row 11 issues: ['Unquoted comma in column 4']
# Row 14 issues: ['Unquoted comma in column 1', 'Unquoted comma in column 4', 'Unquoted comma in column 6']
# Row 15 issues: ['Unquoted comma in column 4']
# Row 16 issues: ['Unquoted comma in column 4']
# Row 17 issues: ['Unquoted comma in column 4']
# Row 18 issues: ['Unquoted comma in column 4']
# Row 20 issues: ['Unquoted comma in column 4']
# Row 22 issues: ['Unquoted comma in column 4']

# %%
import pandas as pd
import re

# ========= Load raw file with no parsing to preserve exact data =========
in_path = "/Applications/WorkDataSets/Demandbase_techno.csv"
out_path = "/Applications/WorkDataSets/Demandbase_techno_F5_ready_for_looker1011.csv"

# Load CSV safely with python engine
df = pd.read_csv(in_path, dtype=str, keep_default_na=False, encoding="utf-8-sig", engine="python")

# ========= Clean Column Names =========
df.columns = [
    re.sub(r'[^A-Za-z0-9_]+', '_', col.strip().lower()) or f"column_{i+1}"
    for i, col in enumerate(df.columns)
]

# ========= Escape Commas and Clean Cells =========
def escape_cell(value):
    if pd.isna(value):
        return ""
    v = str(value).strip()
    v = re.sub(r"[\r\n]+", " ", v)  # remove line breaks
    # If comma exists and not already quoted, add quotes
    if "," in v and not (v.startswith('"') and v.endswith('"')):
        v = f'"{v}"'
    return v

df = df.applymap(escape_cell)

# ========= Process Technographics (F5 logic stays the same if column exists) =========
def clean_technographics_field(text: str) -> list:
    text = text.strip().strip('|," ')
    text = re.sub(r'[^A-Za-z0-9\.\s\-\|_/]', ' ', text)  # keep only safe chars
    return [t.strip() for t in text.split("|") if t.strip()]

from collections import defaultdict

if "technographics" in df.columns:
    split_list = df["technographics"].apply(lambda x: clean_technographics_field(x.strip('"')))
    
    for category, keywords in F5_SCHEMA.items():
        matches = split_list.apply(lambda items: [t for t in items if any(k.lower() in t.lower() for k in keywords)])
        df[f"{category}_matches"] = matches.apply(lambda lst: ", ".join(lst))
        df[f"{category}_summary"] = matches.apply(lambda lst: _label_for(category, len(lst)))

# ========= Save for Looker Studio =========
df.to_csv(out_path, index=False, encoding="utf-8-sig")
print(f"✅ Successfully cleaned and exported: {out_path}")
# Out:
# /var/folders/9p/ktbdntkn6p388k364f6v6n500000gn/T/ipykernel_33729/3628123555.py:28: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(escape_cell)
# ✅ Successfully cleaned and exported: /Applications/WorkDataSets/Demandbase_techno_F5_ready_for_looker1011.csv

# %%
import csv
import re

input_path = "/Applications/WorkDataSets/Demandbase_techno.csv"
illegal_pattern = re.compile(r'[^\x20-\x7E]')  # anything outside normal printable ASCII

with open(input_path, 'r', encoding='utf-8-sig', newline='') as f:
    reader = csv.reader(f)
    header = next(reader)
    for i, row in enumerate(reader, start=2):
        for col_index, value in enumerate(row):
            if illegal_pattern.search(value):  # detect non-printable characters
                print(f"🚨 Row {i}, Column {header[col_index]} contains invalid character(s): {repr(value)}")
                raise SystemExit
        if len(row) != len(header):
            print(f"🚨 Row {i} has column mismatch: expected {len(header)}, got {len(row)}")
            print(row)
            raise SystemExit

print("✅ No illegal characters or column mismatches found in first pass.")
# Out:
# 🚨 Row 15, Column Account Name contains invalid character(s): 'BPO Holdco Coöperatief U.A.'
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /opt/anaconda3/envs/jupyter_env/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3707: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import pandas as pd
import csv
import re
import unicodedata

# ========= 1) F5 schema and labeling logic =========
F5_SCHEMA = {
    "f5_core_adc": [
        "F5 Networks", "BIG-IP", "Viprion", "F5 SSL Orchestrator",
        "F5 Load Balancer", "F5 Application Traffic Insight"
    ],
    "f5_security": [
        "F5 ASM", "F5 APM", "F5 Bot Defense", "F5 Distributed Cloud WAAP",
        "F5 Silverline", "F5 Web Application Firewall", "F5 Advanced WAF"
    ],
    "f5_cloud_services": [
        "F5 Distributed Cloud", "F5 Global Server Load Balancing",
        "F5 DNS", "F5 WAF", "F5 Cloud Services"
    ],
    "complementary_cloud": [
        "Azure", "AWS", "Amazon Web Services", "Google Cloud",
        "Kubernetes", "Azure Virtual Machines", "AWS AppStream"
    ],
    "complementary_identity": [
        "Okta", "Azure AD", "Ivanti", "Zscaler", "Ping Identity", "CyberArk"
    ],
    "complementary_workspace": [
        "IGEL", "Unicon", "Thin Client", "Workspace ONE", "Parallels", "Nutanix Frame"
    ]
}

TACTICAL_LABELS = {
    "f5_core_adc": {"high": "High F5 Entrenchment", "medium": "Moderate F5 Presence", "low": "Minimal F5 Footprint"},
    "f5_security": {"high": "Advanced F5 Security Stack", "medium": "F5 Security Present", "low": "No Security Modules"},
    "f5_cloud_services": {"high": "Cloud-Ready F5 Footprint", "medium": "Some Cloud Adoption", "low": "On-Prem Focused"},
    "complementary_cloud": {"high": "Cloud-Aligned", "medium": "Cloud-Capable", "low": "Not Cloud-Aligned"},
    "complementary_identity": {"high": "Identity-Ready", "medium": "Basic Identity Signals", "low": "No Identity Signals"},
    "complementary_workspace": {"high": "Workspace-Enabled", "medium": "Some Workspace Signals", "low": "No Workspace Signals"}
}

def _label_for(category: str, n: int) -> str:
    return (
        TACTICAL_LABELS[category]["high"] if n >= 2 else
        TACTICAL_LABELS[category]["medium"] if n == 1 else
        TACTICAL_LABELS[category]["low"]
    )

# ========= Unicode Normalization =========
def normalize_unicode(df: pd.DataFrame) -> pd.DataFrame:
    def normalize_cell(value):
        if pd.isna(value):
            return ""
        value = unicodedata.normalize('NFKD', str(value)).encode('ascii', 'ignore').decode('ascii')
        return value.strip()
    return df.applymap(normalize_cell)

# ========= Clean Technographics =========
def clean_technographics_field(text: str) -> list:
    if not isinstance(text, str):
        return []
    text = text.strip().strip('|," ')
    text = re.sub(r'[^A-Za-z0-9\.\s\-\|_/]', ' ', text)
    return [t.strip() for t in text.split("|") if t.strip()]

def process_technographics(df: pd.DataFrame, tech_col: str = "Technographics") -> pd.DataFrame:
    if tech_col not in df.columns:
        return df
    split_list = df[tech_col].fillna("").astype(str).apply(clean_technographics_field)

    for category, keywords in F5_SCHEMA.items():
        matches = split_list.apply(lambda items: [t for t in items if any(k.lower() in t.lower() for k in keywords)])
        df[f"{category}_matches"] = matches.apply(lambda lst: ", ".join(lst))
        df[f"{category}_summary"] = matches.apply(lambda lst: _label_for(category, len(lst)))
    return df

# ========= Column Header and Content Cleaning =========
def clean_for_looker(df: pd.DataFrame) -> pd.DataFrame:
    new_cols = []
    for i, col in enumerate(df.columns):
        col_str = str(col).strip()
        if col_str == "" or col_str.lower().startswith("unnamed"):
            col_str = f"column_{i+1}"
        col_str = col_str.lower().replace(" ", "_").replace("-", "_").replace("/", "_")
        new_cols.append(col_str)
    df.columns = new_cols

    # Clean cells
    for col in df.columns:
        df[col] = df[col].astype(str).str.replace(r"[\r\n]+", " ", regex=True).str.strip()
        # Escape commas if present
        df[col] = df[col].apply(lambda v: f'"{v}"' if "," in v and not (v.startswith('"') and v.endswith('"')) else v)

    df = df.dropna(axis=1, how="all")
    return df

# ========= Repair CSV Rows =========
def repair_csv_rows(input_path):
    with open(input_path, 'r', encoding='utf-8-sig', newline='') as f:
        first_row = next(csv.reader(f))
        expected_cols = len(first_row)
    repaired_rows = [first_row]

    with open(input_path, 'r', encoding='utf-8-sig', newline='') as f:
        reader = csv.reader(f)
        next(reader)  # skip header
        for row in reader:
            if len(row) > expected_cols:
                row = row[:expected_cols]
            elif len(row) < expected_cols:
                row += [""] * (expected_cols - len(row))
            repaired_rows.append(row)
    return repaired_rows, expected_cols

# ========= Main Execution =========
in_path = "/Applications/WorkDataSets/Demandbase_techno.csv"
out_path = "/Applications/WorkDataSets/Demandbase_techno_F5_ready_for_looker2222.csv"

rows, expected_cols = repair_csv_rows(in_path)
df = pd.DataFrame(rows[1:], columns=rows[0])

df = process_technographics(df, tech_col="Technographics")
df = clean_for_looker(df)
df = normalize_unicode(df)

df.to_csv(out_path, index=False, encoding="utf-8-sig")
print("✅ FINAL OUTPUT READY FOR LOOKER:", out_path)
print(df.head(5).to_string())
# Out:
# ✅ FINAL OUTPUT READY FOR LOOKER: /Applications/WorkDataSets/Demandbase_techno_F5_ready_for_looker2222.csv
#                        account_name         journey_stage engaged_known_people                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 0  ACCENTURE PUBLIC LIMITED COMPANY  Known Contact Action                    0  "|.NET|.NET 5|.NET Framework|100TB|11:11 Systems|123 Reg!|1CRM|1WorldSync|360Plus|3CX|3CX Phone System|3D CAD|3D Systems|3DEXPERIENCE Platform|3Dexperience|3Scale API Management|3T Logistics|3scale|84.51 Insights|AB Initio Data Quality Environment|AB Tasty|ABAP|ABB 800xA|ABC Fitness Solutions|ABINIT|ACBS|ACCELQ|ACI Base24|ACI Base24-eps|ACI Worldwide|AD Fusion|ADManager Plus|ADP|ADP Celergo|ADP GlobalView|ADP HR|ADP Payroll|ADT Access Control|ADTRAN|ADVA Optical|AFS Analytics|AG Grid|AIMS Flight Operations Systems|ALFABET|ALIS|AMAZON ELASTIC CONTAINER SERVICE (ECS)|AMC Technology|AMI|AMP|AMS Billing|AMS Insurance|ANSYS|AODocs|APS|ARGUS|ARGUS Enterprise|ARMIS|ASG Zeke|ASG-Cypress|ASM|ASP.NET|AT Internet|AT&T Global Network Client|AT&T IP Toll-Free|AT&T Managed Internet Service (MIS)|AT&T Managed Threat Detection and Response Service|AT&T Network-Based IP Remote Access|ATG Web Commerce|ATIVA|ATT|AUTOSAR|AVEV InTouch HMI|AVEVA MES|AVEVA NET|AVEVA Operations Control|AVEVA PI System|AVEVA System Platform|AWS Amplify|AWS App Runner|AWS AppSync|AWS Auto Scaling|AWS Backup|AWS Batch|AWS Certificate Manager|AWS CloudFormation|AWS CloudTrail|AWS CodeBuild|AWS CodeCommit|AWS CodeDeploy|AWS CodePipeline|AWS Command Line Interface|AWS Control Tower|AWS Cost Explorer|AWS Data Lake Storage|AWS Database Migration Service|AWS Device Farm|AWS Direct Connect|AWS Elastic Beanstalk|AWS Fargate|AWS Global Accelerator|AWS Glue|AWS GovCloud|AWS IoT|AWS IoT Core|AWS IoT Greengrass|AWS IoT Things Graph|AWS Lake Formation|AWS Lambda|AWS Managed Services|AWS Marketplace|AWS Mobile Services|AWS Organizations|AWS Schema Conversion Tool|AWS Secrets Manager|AWS Security Hub|AWS Service Catalog|AWS Shield|AWS Snowball|AWS Step Functions|AWS Systems Manager|AWS Transit Gateway|AWS Trusted Advisor|AWS WAF|AYLIEN|AZURE DATA LAKE STORAGE|Ab Initio|Abacus|Aberdeen|Absorb LMS|Academy|Accenture Cloud Infrastructure Managed Services|Accenture myConcerto|Accruent FAMIS 360|Accurate Background|Achilles|Aconex|Acronis|Acronis Backup And Recovery|Actifio|ActionIQ|Activated Insights|Active 24 Hosting|Active Campaign|Active Risk|ActiveBatch Workload Automation|ActiveControl|Activevos|Actuate BIRT Spreadsheet|Acturis|Acumatica|Acumatica Distribution Edition|Acunetix|Ad Dynamo|AdEspresso|Addi|Address Intelligence|Adecco|Adledge|Adobe Acrobat|Adobe Acrobat DC|Adobe Acrobat Pro|Adobe Advertising DSP|Adobe After Effects|Adobe Analytics|Adobe Animate|Adobe Audience Manager|Adobe Campaign|Adobe Campaign Classic|Adobe Captivate|Adobe Character Animator CC|Adobe Commerce|Adobe Connect|Adobe Content Repository eXtreme|Adobe Creative Suite|Adobe Customer Journey Analytics|Adobe Discover|Adobe DreamWeaver|Adobe Edge|Adobe Experience Cloud|Adobe Experience Manager|Adobe Experience Manager Forms|Adobe Experience Manager Guides|Adobe Experience Manager Sites|Adobe Experience Manager as a Cloud Service|Adobe Express|Adobe FrameMaker|Adobe GenStudio|Adobe Illustrator|Adobe InDesign|Adobe Launch|Adobe Marketing Cloud|Adobe Marketo Engage|Adobe Photoshop|Adobe Portfolio|Adobe Premiere Pro|Adobe Real-Time CDP|Adobe RoboHelp|Adobe Sign|Adobe Target|Adobe Workfront|Adobe XD|Adsp|Adyen|Aerohive Networks|Aetna|Agency|Agent Image|Agile CRM|AgilePoint|Agility CMS|Agility Software|Agiloft|Ahrefs|Airtable|Aito|Akamai Content Delivery Network (Cdn)|Akamai DNS|Akamai HD|Akamai Image & Video Manager|Akamai Rum|Akeneo|Alation|Alation Data Catalog|Albert.ai|Alcatel Lucent|Alertus|Alex Solutions|Alfresco Content Services|AlgoSec|Algolia|Algonomy|Alias Concept|Alibaba|Alibaba Cloud Container Service for Kubernetes (ACK)|All Siemens PLM Products|AllegroServe|Allen-Bradley|Alliance Gateway|AlphaSSL|AlphaSense|Altair HyperMesh|Altair HyperWorks|Altair OptiStruct|Altera Sunrise|Alterian|Alteryx|Alteryx Server|Altice|Altiris|Altiris Asset Management Suite|Altium|Altizon|Amadeus|Amadeus Airline Platform|AmazingHiring|Amazon|Amazon API ...
# 1                        Servicenow  Known Contact Action                   13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 2                   "Kyndryl, Inc."  Known Contact Action                    6  "|.NET|.NET 5|.NET Framework|123 Reg!|1Password|3D Systems|3DEXPERIENCE Platform|3Scale API Management|3scale|4project|6sense|A10 Networks|AB Initio Data Quality Environment|ABAP|ABC Fitness Solutions|ABINIT|ACCELQ|ACI Worldwide|ACL Analytics|ACLS|AD Fusion|ADP|ADP Payroll|ADT Access Control|AG Grid|ALIS|AMD Radeon|AMO|AMP|AMS Insurance|ANSYS|ANSYS Fluent|ANSYS Icepak|ANTLR|AP Images|API Suite|APS|ARMIS|ASG-Cypress|ASG-TMON|ASM|ASP.NET|AT Internet|AT&T Global Network Client|AT&T IP Toll-Free|AT&T Managed Internet Service (MIS)|AT&T Managed Threat Detection and Response Service|AT&T Network-Based IP Remote Access|ATIVA|ATT|AVADA|AVEVA PI System|AWS Amplify|AWS App Mesh|AWS App Runner|AWS Backup|AWS Batch|AWS Cloud9|AWS CloudFormation|AWS CloudTrail|AWS CodeBuild|AWS CodeCommit|AWS CodeDeploy|AWS CodePipeline|AWS CodeStar|AWS Config|AWS Control Tower|AWS Cost Explorer|AWS Data Lake Storage|AWS Database Migration Service|AWS Direct Connect|AWS Fargate|AWS Glue|AWS GovCloud|AWS Guardrails|AWS IoT|AWS Key Management Service|AWS Lake Formation|AWS Lambda|AWS Machine Learning|AWS Managed Services|AWS Marketplace|AWS Migration Hub|AWS Nitro System|AWS Organizations|AWS Secrets Manager|AWS Security Hub|AWS Service Catalog|AWS Shield|AWS Step Functions|AWS Systems Manager|AWS Trusted Advisor|AWS WAF|AZURE DATA LAKE STORAGE|Ab Initio|Abbott Instrument Manager|Abbott M2000 Realtime System|Absorb LMS|Accenture Cloud Infrastructure Managed Services|AccessData|Achilles|Acosta Group|Acoustic|Acquia|Acrolinx|Action Kit|ActivTrak|Activated Insights|Active 24|Active Dataguard|Active-X|ActiveControl|Activiti|Actuate BIRT Spreadsheet|Acunetix|Ad Dynamo|AdEspresso|AdImpact|Ada Support|AddThis|Adenza Group|Adobe Acrobat|Adobe Acrobat DC|Adobe Acrobat Pro|Adobe After Effects|Adobe Analytics|Adobe Audience Manager|Adobe Campaign|Adobe Campaign Classic|Adobe Captivate|Adobe Character Animator CC|Adobe Commerce|Adobe Content Repository eXtreme|Adobe Creative Suite|Adobe Customer Journey Analytics|Adobe DreamWeaver|Adobe Experience Cloud|Adobe Experience Manager|Adobe Experience Manager Forms|Adobe Experience Manager Guides|Adobe Experience Manager as a Cloud Service|Adobe Fonts|Adobe FrameMaker|Adobe GenStudio|Adobe Illustrator|Adobe InDesign|Adobe Journey Optimizer|Adobe Launch|Adobe Learning Manager|Adobe Marketing Cloud|Adobe Marketo Engage|Adobe Photoshop|Adobe Portfolio|Adobe Premiere Pro|Adobe Real-Time CDP|Adobe Sign|Adobe Target|Adobe Workfront|Adobe XD|Adstra|Adverity|Adversarial Robustness Toolbox|Aegir|Affinity Designer|Agency|Agile CRM|Agility CMS|Agility Software|Aha!|Ahrefs|Airbyte|Airtable|Akamai Bot Manager|Akamai Content Delivery Network (Cdn)|Akamai DNS|Akamai Edge|Akamai HD|Akita|Alation|Alation Data Catalog|Albert.ai|Alchemer|Algolia|Alibaba|Alibaba Cloud|All Hours|All Siemens PLM Products|Alliance Gateway|Almond|AlphaSSL|Alteon Network Load Balancer|Alteryx|Altiris Asset Management Suite|Altium|Altium Designer|Amadeus|Amadeus Airline Platform|Amazon|Amazon API Gateway|Amazon AWS|Amazon AWS Identity And Access Management (IAM)|Amazon Alexa|Amazon AppFlow|Amazon Athena|Amazon Aurora|Amazon CloudFront|Amazon CloudWatch|Amazon Comprehend|Amazon Connect|Amazon DynamoDB|Amazon EC2 Auto Scaling|Amazon EMR|Amazon ElastiCache|Amazon Elastic Container Service|Amazon Elastic File System (EFS)|Amazon EventBridge|Amazon GuardDuty|Amazon Hosting|Amazon Inspector|Amazon Kendra|Amazon Kinesis|Amazon Kinesis Data Firehose|Amazon MSK|Amazon Machine Image|Amazon Macie|Amazon Polly|Amazon QuickSight|Amazon RDS for MySQL|Amazon Redshift|Amazon Relational Database Service (RDS)|Amazon Route 53|Amazon S3|Amazon SageMaker|Amazon Simple Email Service (SES)|Amazon Simple Email Services (SES)|Amazon Simple Notification Service (SNS)|Amazon Simple Queue Service (SQS)|Amazon Textract|Amazon Timestream|Amazon Transcribe|Amazon Webstore|Amazon WorkSpaces|Amdocs|Amerge|American Express ...
# 3                         Arrow ECS  Known Contact Action                   99                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 4            "Salesforce.com, inc."  Known Contact Action                    1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       "|.NET|.NET Framework|123 Reg!|2Win!|ABAP|ADP|ADP GlobalView|ADP HRMS|ADP Payroll|ADP Streamline|AMC Technology|AMP|AMS Insurance|ANSYS|APS|ARGUS|ASG-Cypress|ASP.NET|AT&T Global Network Client|AT&T IP Toll-Free|AT&T Managed Internet Service (MIS)|AT&T Managed Threat Detection and Response Service|AT&T Network-Based IP Remote Access|ATIVA|ATT|AWS App Runner|AWS AppSync|AWS Auto Scaling|AWS Certificate Manager|AWS CloudFormation|AWS CodeBuild|AWS CodeCommit|AWS CodePipeline|AWS Config|AWS Data Pipeline|AWS Glue|AWS GovCloud|AWS Guardrails|AWS Lake Formation|AWS Lambda|AWS Marketplace|AWS Multi-Factor Authentication|AWS Secrets Manager|AWS Shield|AWS Systems Manager|AWS Trusted Advisor|AZURE DATA LAKE STORAGE ...
# /var/folders/9p/ktbdntkn6p388k364f6v6n500000gn/T/ipykernel_33729/653520459.py:55: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return df.applymap(normalize_cell)

# %%
import csv
import re
import unicodedata

input_path = "/Applications/WorkDataSets/Demandbase_techno.csv"

illegal_char_pattern = re.compile(r'[^\x20-\x7E]')  # non-printable ASCII or special Unicode

with open(input_path, 'r', encoding='utf-8-sig', newline='') as f:
    reader = csv.reader(f)
    header = next(reader)
    for i, row in enumerate(reader, start=2):
        for col_index, value in enumerate(row):
            if illegal_char_pattern.search(value):
                print(f"🚨 Row {i}, Column '{header[col_index]}' contains invalid character(s): {repr(value)}")
                break
# Out:
# 🚨 Row 15, Column 'Account Name' contains invalid character(s): 'BPO Holdco Coöperatief U.A.'
# 🚨 Row 34, Column 'Technographics' contains invalid character(s): '|.NET|.NET 5|123 Reg!|3CX|3CX Phone System|6sense|8X8 Communication|AB Initio Data Quality Environment|ABAP|ABINIT|ADP|ADP Payroll|ADTRAN|AMI|AOL|AOMEI OneKey Recovery|APC|APCON|ASG-Cypress|ASM|ASP.NET|AT Internet|AT&T Global Network Client|AT&T IP Toll-Free|AT&T Managed Internet Service (MIS)|AT&T Managed Threat Detection and Response Service|AT&T Network-Based IP Remote Access|ATG Web Commerce|ATT|AWS App Runner|AWS Artifact|AWS Batch|AWS CloudFormation|AWS CloudTrail|AWS CodeBuild|AWS CodeDeploy|AWS CodePipeline|AWS Config|AWS Data Pipeline|AWS Direct Connect|AWS Elemental|AWS Fargate|AWS Glue|AWS GovCloud|AWS Guardrails|AWS IoT|AWS Key Management Service|AWS Lambda|AWS Managed Services|AWS Organizations|AWS Secrets Manager|AWS Security Hub|AWS Service Catalog|AWS Step Functions|AWS Transit Gateway|AWS Trusted Advisor|AZURE DATA LAKE STORAGE|Absorb LMS|Accenture Cloud Infrastructure Managed Services|Accruent|Acqueon|ActiveControl|Acxiom|AdEspresso|AdRoll|AdRoll CMP System|AddThis|Adobe Acrobat|Adobe Acrobat DC|Adobe Acrobat Pro|Adobe After Effects|Adobe Analytics|Adobe Audience Manager|Adobe Campaign|Adobe Captivate|Adobe Character Animator CC|Adobe Commerce|Adobe Connect|Adobe Creative Suite|Adobe Customer Journey Analytics|Adobe Edge|Adobe Experience Cloud|Adobe Experience Manager|Adobe Experience Manager Guides|Adobe Experience Manager Sites|Adobe Experience Manager as a Cloud Service|Adobe Fonts|Adobe GenStudio|Adobe Illustrator|Adobe InDesign|Adobe Journey Optimizer|Adobe Launch|Adobe Marketing Cloud|Adobe Marketo Engage|Adobe Photoshop|Adobe Premiere Pro|Adobe Sign|Adobe Target|Adobe Workfront|Adobe XD|Advertising.com|Affirm|Agency|Agile CRM|Agreeya Solutions|Ahrefs|Airtable|Akamai Bot Manager|Akamai DNS|Akka HTTP|Alation|Alation Data Catalog|AlgoSec|All Siemens PLM Products|Alliance Gateway|Altair Grid Engine|Alteryx|Altiris Asset Management Suite|Amazon|Amazon ALB|Amazon API Gateway|Amazon AWS|Amazon Ad System|Amazon Advertising|Amazon Associates|Amazon Athena|Amazon Aurora|Amazon CloudFront|Amazon CloudWatch|Amazon Cognito|Amazon Connect|Amazon DocumentDB|Amazon DynamoDB|Amazon EC2 Reserved Instances|Amazon ElastiCache|Amazon Elastic Container Service For Kubernetes (Eks)|Amazon EventBridge|Amazon GuardDuty|Amazon Inspector|Amazon Kinesis Data Firehose|Amazon Machine Image|Amazon Redshift|Amazon Relational Database Service (RDS)|Amazon Route 53|Amazon SageMaker|Amazon Simple Email Service (SES)|Amazon Simple Email Services (SES)|Amdocs|Amdocs CES|Amelia|Americart|Amplify|Anaplan|Android|Android Interface Definition Language (AIDL)|Android Studio|AngularJS|AngularJS V1|Angulartics|Animate On Scroll|Anitian FedRamp Comprehensive|Ansible|Anthos GKE on-prem|AnyLogic|Apache 1.3|Apache 2.2|Apache 2.4|Apache Airflow|Apache Avro|Apache Camel|Apache Cassandra|Apache CouchDB|Apache Druid|Apache Flink|Apache Flume|Apache Groovy|Apache HBase|Apache HTTP Server|Apache Hadoop|Apache Hadoop MapReduce|Apache HttpComponents|Apache Ignite|Apache JMeter|Apache Kafka|Apache Log4j|Apache Maven|Apache NiFi|Apache Oozie|Apache OpenJPA|Apache OpenMeetings|Apache Qpid|Apache Ranger|Apache Solr|Apache Spark|Apache Spark SQL|Apache Spark Streaming|Apache Sqoop|Apache Superset|Apache Tomcat|Apache Zookeeper|Apcon Intelligent Network Monitoring|Apigee|AppDynamics|Appian|Appium|Apple Mobile Web App Capable|Apple Mobile Web Clips Icon|Apple Pay|Apple iPad|Apple iPhone|Apptus|Aptana|Apttus|Arc|ArcGIS Online|ArcInfo|ArcSight Enterprise Security Manager|ArcSight Recon|Argo|Argo CD|Ariba|Ariba Contract Management|Ariba Electronic Invoice Management|Ariba Payables|Ariba Spend Visibility|Arista Networks|Arsenal|Artemis Health|Articulate 360|Articulate Storyline|Articulate Storyline 360|Artifactory|Artsai|Aruba ClearPass|Asana|Asure Software|Atea Zephyr|Atex Digital Media|Atlas RFID Jovix|Atlas Resell Management|Atlassian Bamboo|Atlassian Jira|Atlassian Jira Service Management|Atlassian  ...
# 🚨 Row 67, Column 'Technographics' contains invalid character(s): "|.NET|.NET 5|10x Genomics|123 Reg!|3D CAD|ABAP|AD Fusion|ADP|ADP Celergo|ADP Payroll|ADT Access Control|AIC|ALIS|AMAZON ELASTIC CONTAINER SERVICE (ECS)|ANSYS|APL|APS|ASG-Cypress|ASM|ASP.NET|AT&T Collaborate|ATI Galileo|ATIVA|AWS Amplify|AWS App Runner|AWS CloudFormation|AWS CodeBuild|AWS CodeDeploy|AWS CodePipeline|AWS Config|AWS Device Farm|AWS Elastic Beanstalk|AWS Glue|AWS Lambda|AWS Marketplace|AWS Secrets Manager|AWS Service Catalog|AbbVie|Above|Accenture Cloud Infrastructure Managed Services|Accountabl|Activated Insights|Activated Insights Retain|ActiveControl|Activiti|Acuity Elm|AcuityAds|AdImpact|Adecco|Adentro|Adobe Acrobat|Adobe Acrobat DC|Adobe Acrobat Pro|Adobe After Effects|Adobe Audience Manager|Adobe Campaign|Adobe Captivate|Adobe Connect|Adobe Creative Suite|Adobe Customer Journey Analytics|Adobe Dimensions|Adobe Dynamic Media Classic|Adobe Experience Cloud|Adobe Experience Manager|Adobe Experience Manager Guides|Adobe Experience Manager Sites|Adobe Experience Manager as a Cloud Service|Adobe Express|Adobe Fonts|Adobe FrameMaker|Adobe GenStudio|Adobe InDesign|Adobe Launch|Adobe Marketing Cloud|Adobe Marketo Engage|Adobe Photoshop|Adobe Premiere Pro|Adobe Sign|Adobe Workfront|Adobe XD|Advisory Board|Agent IQ|Agile CRM|Agilent SLIMS|Agility Software|Agiloft|Aha!|Ahrefs|Airtable|Akamai DNS|Albert.ai|Alianza Cloud Voice Platform|Alibaba|Alight Worklife|Align|All Siemens PLM Products|Almond|AlphaFold|AlphaSSL|AlphaSense|Altair EDEM|Alteryx|Altiris Asset Management Suite|Altium|Altium Designer|Amazon|Amazon API Gateway|Amazon AWS|Amazon CloudFront|Amazon CloudWatch|Amazon DynamoDB|Amazon EMR|Amazon Elastic Container Registry (ECR)|Amazon Elastic Container Service For Kubernetes (Eks)|Amazon Elastic File System (EFS)|Amazon EventBridge|Amazon GuardDuty|Amazon Kinesis|Amazon Machine Image|Amazon QuickSight|Amazon RDS for MySQL|Amazon Redshift|Amazon Relational Database Service (RDS)|Amazon Route 53|Amazon S3|Amazon SageMaker|Amazon Simple Email Service (SES)|Amazon Simple Email Services (SES)|Amazon Simple Notification Service (SNS)|Amplify|AmplifyJS|Anaqua|Android|Android Interface Definition Language (AIDL)|Android Studio|AngularJS|AngularJS V1|Animate On Scroll|AnnData|Ansible|Anthos GKE on-prem|AnyLogic|Aon Ability And Skills Assessment|Aon Assessment Solution|Aon Behavioral Assessment|Aon Coding Assessment|Aon Gamified Assessment|Aon Job Simulations|Aon Remote Proctoring|Aon Video Interviewing Tool|Aon Virtual Assessment Center|Apache 2.2|Apache 2.4|Apache Airflow|Apache Flink|Apache HBase|Apache Hadoop|Apache Hive|Apache HttpComponents|Apache Impala|Apache JMeter|Apache Kafka|Apache Maven|Apache Mesos|Apache OpenJPA|Apache OpenMeetings|Apache Phoenix|Apache Qpid|Apache Solr|Apache Spark|Apache Superset|Apache Tomcat|AppDynamics|Appboy|Appium|Apple Mobile Web App Capable|Apple Mobile Web App Status Bar Style|Apple Mobile Web Clips Icon|Apple Weather|Apple iPad|Apttus|Apture Linking Platform|ArangoDB|Archibus|Arduino|Argo|Argo CD|Ariba|Ariba Contract Management|Ariba Electronic Invoice Management|Ariba Payables|Ariba Spend Visibility|Articulate 360|Articulate Storyline|Artifactory|Asana|Assima|Astute Business|Atento|Atex Digital Media|Atlassian Bamboo|Atlassian Jira|AtmosAI|Attendee Interactive|Aurora|Ausgezeichnet|Autodesk AutoCAD|Autodesk Construction Cloud|Autodesk Revit|Automated Image Builds With Jenkins, Packer, And Kubernetes|Avere|Aviso|Azure Analysis Services|Azure App Service|Azure Bastion|Azure Boards|Azure Container Service|Azure Content Moderator|Azure Cosmos DB|Azure DNS|Azure Databricks|Azure Dedicated SQL pool|Azure DevOps Server|Azure DevTest Labs|Azure Devops|Azure Machine Learning|Azure SQL|B2B2C|BCD PAY|BERT Language Model|BIG-IP|BIOVIA|BLAST (Basic Local Alignment Search Tool)|BMC TrueSight Operations Management|BWA (Burrows-Wheeler Aligner)|Babel|Backstage IO Developer Platform|Balsamiq|Basis Technologies|Benchling|Benchmark|Bet ...
# 🚨 Row 82, Column 'Technographics' contains invalid character(s): "|.NET|123 Reg!|1CRM|3D CAD|3D Systems|3DEXPERIENCE Platform|3Dexperience|3PL Warehouse Manager|ABAP|ADP|ADP GlobalView|ADP HRMS|ADP Payroll|AIMS Flight Operations Systems|ALIS|AMAZON ELASTIC CONTAINER SERVICE (ECS)|AMP|ANSYS|AOL|APS|ARGUS|ARI|ASP.NET|AVEVA System Platform|AWS App Runner|AWS Backup|AWS Batch|AWS CloudFormation|AWS CodeDeploy|AWS CodePipeline|AWS Command Line Interface|AWS Cost Explorer|AWS Data Lake Storage|AWS Direct Connect|AWS Glue|AWS Guardrails|AWS IoT|AWS Lambda|AWS Managed Services|AWS Trusted Advisor|Accenture Cloud Infrastructure Managed Services|Accessible360|Accruent|Accruent FAMIS 360|Accruent Meridian|Acosta|Acronis|Acronis Backup And Recovery|Action Kit|Activated Insights|Activated Insights Recruit|Activated Insights Retain|ActiveControl|AdImpact|AdRiver|Adecco|Adentro|Adobe Acrobat|Adobe Acrobat DC|Adobe Acrobat Pro|Adobe After Effects|Adobe Analytics|Adobe Campaign|Adobe Captivate|Adobe Commerce|Adobe Connect|Adobe Creative Suite|Adobe Customer Journey Analytics|Adobe DreamWeaver|Adobe Experience Manager|Adobe Experience Manager Guides|Adobe Experience Manager as a Cloud Service|Adobe GenStudio|Adobe Illustrator|Adobe InDesign|Adobe Marketing Cloud|Adobe Marketo Engage|Adobe Photoshop|Adobe Premiere Pro|Adobe Sign|Adobe XD|Advertising.com|Agile CRM|Agility Software|Aha!|Akamai Identity Cloud|Akta|Albert.ai|AlgoSec|Alianza Cloud Voice Platform|All Siemens PLM Products|Allen-Bradley|AlphaFold|AlphaSense|Altair HyperCrash|Alteryx|Altiris Asset Management Suite|Altizon|Amazon|Amazon ALB|Amazon AWS|Amazon Ad System|Amazon Business|Amazon CloudFront|Amazon CloudWatch|Amazon DSSTNE|Amazon DynamoDB|Amazon EC2|Amazon Elastic Container Registry (ECR)|Amazon Elastic Container Service For Kubernetes (Eks)|Amazon Elastic File System (EFS)|Amazon EventBridge|Amazon FSx for Lustre|Amazon Redshift|Amazon Relational Database Service (RDS)|Amazon Route 53|Amazon SageMaker|Amazon Simple Email Service (SES)|Amazon Simple Email Services (SES)|Americart|Amplitude|Anaqua|Anaqua IdeaPoint|Android|Android Interface Definition Language (AIDL)|AngularJS|AngularJS V1|Ansible|Ansys SpaceClaim|Anthos GKE on-prem|Apache 2.2|Apache 2.4|Apache Airflow|Apache Cassandra|Apache Flink|Apache Hadoop|Apache Hadoop Yarn|Apache Hive|Apache HttpComponents|Apache Kafka|Apache OpenJPA|Apache OpenMeetings|Apache Phoenix|Apache Qpid|Apache Ranger|Apache Solr|Apache Spark|Apache Sqoop|Apache Superset|Apache Tomcat|Apigee|Appian|Apple Mobile Web Clips Icon|Apple iPad|Applied Epic|Apptio|Apptio Cloudability|Aprimo|Ar-Go|Aras|Aravo|Argo|Ariba|Ariba Contract Management|Ariba Electronic Invoice Management|Ariba Payables|Arsenal|Articulate 360|Articulate Storyline|Articulate Storyline 360|Artifactory|Aruba ClearPass|Asana|Ascent|Ascentis|AspenTech|AssurX|Atex Digital Media|Ativo|Atlassian Jira|Atlassian Jira Service Management|Atlassian Opsgenie|Audacity|Audition|Aurora|Authority Labs|AutoCad Electrical|AutoRABIT|Autodesk AutoCAD|Autodesk BIM 360 Docs|Autodesk Fusion 360|Autodesk Inventor|Autodesk Revit|Automated Image Builds With Jenkins, Packer, And Kubernetes|Automation Anywhere|Autopilot|Avature|Avere|Aviso|Axon Dispatch|Axtria|Axway|Axway API Management|Axway TradeSync Integration Manager|Azure AD Application Proxy|Azure App Service|Azure Backup|Azure Bastion|Azure Content Moderator|Azure DNS|Azure Databricks|Azure Dedicated SQL pool|Azure Devops|Azure Event Hubs|Azure Kubernetes Service|Azure Machine Learning|Azure Machine Learning Studio|Azure Monitor|Azure SQL|Azure SQL Database|Azure Virtual Desktop|BCP|BERT Language Model|BIG-IP|BIG-IP Advanced WAF|BMC Control-M|BRAVO!|BSI|BV Commerce|Babel|Balance|Base SAS|Basic|Basis Technologies|Batch|Bazaarvoice|Beacon Ads|Beam|Beamery Talent Marketing|Beeline Talent Acquisition|Ben|Benchling|Benchworks|Beyond Limits|Big Tickets|BigQuery|Bing Webmater Tools|Bizagi|BlackLine Financial Close Management|Blackline|Blender|Blockchain|Bloomb ...
# 🚨 Row 99, Column 'Technographics' contains invalid character(s): "|.NET|.NET Framework|10x Genomics|123 Reg!|ABAP|ADONIS|ADP|ADP GlobalView|ADP Payroll|ALIS|AMAZON ELASTIC CONTAINER SERVICE (ECS)|AMO|AMP|AOL|APS|APSIS One|ASP.NET|ATIVA|AWS App Runner|AWS CloudTrail|AWS CodeBuild|AWS Config|AWS Device Farm|AWS Fargate|AWS Guardrails|AWS Lambda|AWS Organizations|AZURE DATA LAKE STORAGE|Absorb LMS|Accurat|Acquia Cloud|Acquia Cloud Platform|Acronis|Acronis Backup And Recovery|Activated Insights|Activated Insights Recruit|Activated Insights Retain|ActiveControl|Ad Dynamo|Ada Support|Add To Any|Adobe Acrobat DC|Adobe After Effects|Adobe Campaign|Adobe Captivate|Adobe Connect|Adobe Creative Suite|Adobe Customer Journey Analytics|Adobe DreamWeaver|Adobe Experience Cloud|Adobe Experience Manager|Adobe Experience Manager Guides|Adobe Experience Manager as a Cloud Service|Adobe GenStudio|Adobe Illustrator|Adobe InDesign|Adobe Launch|Adobe Marketing Cloud|Adobe Marketo Engage|Adobe Photoshop|Adobe Portfolio|Adobe Premiere Pro|Adobe Real-Time CDP|Adobe Sign|Adobe XD|Adoit|Advertising.com|Agile CRM|Agility Software|Ahrefs|AirMagnet|Airtable|Akamai DNS|Akamai Edge|Alation|Alianza Cloud Voice Platform|Alibaba|All Siemens PLM Products|Allen-Bradley|Alliance Gateway|Alluxio|Almond|Altair Grid Engine|Alteryx|Altiris Asset Management Suite|Amazon AWS|Amazon CloudFront|Amazon CloudWatch|Amazon Cognito|Amazon EC2|Amazon EMR|Amazon ElastiCache|Amazon Elastic Container Registry (ECR)|Amazon Elastic File System (EFS)|Amazon Redshift|Amazon Relational Database Service (RDS)|Amazon Route 53|Amazon S3|Amazon SageMaker|Amazon Simple Email Services (SES)|Americart|Anaplan|Android|Android Interface Definition Language (AIDL)|AngularJS|AngularJS V1|Ansible|Anthology|Anthos GKE on-prem|Apache Airflow|Apache Continuum|Apache Flink|Apache HBase|Apache Hadoop|Apache Hive|Apache Impala|Apache Kafka|Apache Phoenix|Apache Spark|Apache Spark Streaming|Apache Tomcat|AppDynamics|AppExchange|AppZen|Appian|Apple Mobile Web App Capable|Apple Mobile Web App Status Bar Style|Apple Mobile Web Clips Icon|Apple iPad|Applicata|Aprimo|Aras|ArchiMate|Ariba|Ariba Electronic Invoice Management|Ariba Payables|Arista Networks|Articulate 360|Articulate Storyline|Artifactory|Asana|Ascend|Ascender|AspenTech|AtData|AtData Email Intelligence|Aternity|Atex Digital Media|Atlassian Jira|Atlassian Jira Service Management|Atos|Audition|Autodesk AutoCAD|Autodesk Fusion 360|Autodesk Revit|Automated Image Builds With Jenkins, Packer, And Kubernetes|Automation Anywhere|Avalara|Avature|Avaya Equinox|Avaya IQ|Avere|Axway|Azure Analysis Services|Azure App Service|Azure Bastion|Azure Content Moderator|Azure Databricks|Azure Dedicated SQL pool|Azure DevOps Server|Azure Devops|Azure Functions|Azure Key Vault|Azure Kubernetes Service|Azure SQL|Azure Sentinel|Azure Synapse Analytics|BIG-IP|BINOCS|BIOVIA|BOARD|Backbone.js|Baidu|Basis Technologies|Basware Strategic Sourcing|Benify|Bill.com|Bing Webmater Tools|Bitbucket|Blender|Blockchain|Bloomberg|Bloomberg Tax|Blueprism|Boomi|Boomi AtomSphere|Bootbox.js|Bootstrap|BootstrapCDN|Brandwatch|Brevitas|Broadcom Service Virtualization|Brocade|C++|CA Customer Experience Manager (CEM)|CA Log Analyzer|CAKE Affiliate Marketing|CB Insights|CB Protection|CBRE ServiceInsight|CCH Tagetik|CDC|CDS MVS|CE Cart|CFML|CIARA Hardware|CIF 20/20|CKEditor|CMake|COMSOL Multiphysics|COncORDE|CTT|Cadence Allegro PCB Design|Calabrio|Canada Post|Capillary|Capital IQ|Capital One Merchant Services|Causal|Celonis|Centra|Central|Centrify|Cerner|Cerner CoPathPlus|Certain|Certeon|CheckPoint SDN|Checkmarx|Chef|Choices|Chosen|Chrome River|Cielo|Cincinnati Bell|CircleCI|Cisco Blade Servers|Cisco Catalyst|Cisco Collaboration Meeting Rooms (CMR)|Cisco IOS|Cisco Identity Services Engine|Cisco Intrusion Detection Sensor|Cisco Jabber|Cisco MXE 3500 Series|Cisco Mobility Express|Cisco Packaged Contact Center|Cisco Prime Access Registrar|Cisco SD-WAN|Cisco Session Border Controller (SBC)|Cisco TelePre ...
# 🚨 Row 147, Column 'Account Name' contains invalid character(s): 'Bundesagentur für Arbeit'
# 🚨 Row 194, Column 'Technographics' contains invalid character(s): "|.NET|123 Reg!|3D CAD|3D Systems|ABAP|ADONIS|ADP|ADP GlobalView|ADP Payroll|ADP Smart Compliance|AIMS Flight Operations Systems|ALIS|AMAZON ELASTIC CONTAINER SERVICE (ECS)|AMX Resource Management Suite|ANSYS|APS|ARGUS|ASM|ASP.NET|ATIVA|AVEVA System Platform|AWS App Runner|AWS Backup|AWS Batch|AWS Budgets|AWS CloudFormation|AWS CodeBuild|AWS CodeDeploy|AWS CodePipeline|AWS Command Line Interface|AWS Control Tower|AWS Direct Connect|AWS Elastic Beanstalk|AWS Fargate|AWS Glue|AWS IoT|AWS Lambda|AWS Managed Services|AWS Organizations|AWS Schema Conversion Tool|AWS Secrets Manager|AWS Service Catalog|AWS Step Functions|AWS Systems Manager|AWS Transfer for SFTP|AWS Trusted Advisor|Aberdeen|Accelo|Accenture Cloud Infrastructure Managed Services|Acoustic|Acronis Backup And Recovery|Activated Insights|Activated Insights Recruit|Activated Insights Retain|Active 24 Hosting|ActiveControl|Ad Dynamo|Add To Any|Adobe Acrobat|Adobe Acrobat DC|Adobe Acrobat Pro|Adobe Analytics|Adobe Campaign|Adobe Captivate|Adobe Connect|Adobe Creative Suite|Adobe Customer Journey Analytics|Adobe Experience Cloud|Adobe Experience Manager|Adobe Experience Manager Guides|Adobe Experience Manager as a Cloud Service|Adobe GenStudio|Adobe Illustrator|Adobe InDesign|Adobe Launch|Adobe Marketing Cloud|Adobe Photoshop|Adobe Portfolio|Adobe Sign|Adobe Workfront|Adobe XD|Advisory Board|Agency|Agile CRM|Agility Software|AirMediaWireless HD|Akamai DNS|Akamai Edge|Akamai HD|Akta|Albert.ai|Alchemy|Alight Worklife|All Siemens PLM Products|Allen-Bradley|Alliance Gateway|Almond|AlphaFold|AlphaSSL|Altair Grid Engine|Alteryx|Alteryx Designer|Altezza|Altiris|Altiris Asset Management Suite|Amazon|Amazon ALB|Amazon API Gateway|Amazon AWS|Amazon Athena|Amazon Aurora|Amazon CloudFront|Amazon CloudWatch|Amazon DynamoDB|Amazon EC2|Amazon Elastic Container Registry (ECR)|Amazon Elastic Container Service For Kubernetes (Eks)|Amazon Hosting|Amazon Kinesis|Amazon Neptune|Amazon Pinpoint|Amazon QuickSight|Amazon RDS for MySQL|Amazon Redshift|Amazon Relational Database Service (RDS)|Amazon Route 53|Amazon S3|Amazon SageMaker|Amazon Simple Email Service (SES)|Amazon Simple Email Services (SES)|Amazon WorkSpaces|Anaconda|Analytic Partners|Anaplan|Android|Android Interface Definition Language (AIDL)|AngularJS|AngularJS V1|Angulartics|Ansible|Anthos GKE on-prem|Apache 2.2|Apache Airflow|Apache Avro|Apache Cassandra|Apache HBase|Apache HTTP Server|Apache Hadoop|Apache Hadoop MapReduce|Apache Hive|Apache HttpComponents|Apache Iceberg|Apache Kafka|Apache NiFi|Apache OpenJPA|Apache OpenMeetings|Apache Phoenix|Apache Qpid|Apache Spark|Apache Superset|Apache Tomcat|Apg|AppExchange|Appian|Appium|Apple Mobile Web Clips Icon|Apple OS X Server|Apple iPad|Apriso|Aras|ArcGIS Online|ArcInfo|Ariba|Ariba Contract Management|Ariba Electronic Invoice Management|Ariba Payables|Ariba Procurement Solutions|Arisglobal|Articulate 360|Asana|Atex Digital Media|Atlassian Bamboo|Atlassian Jira|Aurora|Autodesk AutoCAD|Autodesk Maya|Autodesk Revit|Automation Anywhere|Avalara|Avere|AvionteBOLD|Axon Dispatch|Axtria|Axway|Axway API Management|Azure App Service|Azure Bastion|Azure Computer Vision|Azure Container Service|Azure Content Moderator|Azure DNS|Azure Databricks|Azure Devops|Azure Kubernetes Service|Azure Machine Learning|Azure SQL|Azure Virtual Desktop|BCP|BERT Language Model|BIG-IP|BIOVIA|BIOVIA Notebook|BIT|BT|BT Business Phone Systems|BarTender|Base SAS|Basic|Batch|Beam|Beeline|Beeline Contingent Workforce|Beeline SmartView Data Analytics|Benchling|Bentley|BeyondTrust|BeyondTrust Remote Support|Bitbucket|Bloomberg|Bloomberg Tax|Bonita Platform|BonitaSoft|Boomi|Boomi AtomSphere|Bootstrap|Brightcove|Brightcove Player|Broadcom|Broadcom Fabric Operating System|Broadcom IDMS|Broadcom Identity & Access|Broadcom Ops MVS|Broadcom PDSMAN|Broadcom Service Virtualization|Bruno|BugHerd|C|C++|C3 Metrics|C8 Network|CA 1|CA Audit|CA Log Analyzer|CA MIM|CA Network  ...
# 🚨 Row 216, Column 'Technographics' contains invalid character(s): "|.NET|.NET Framework|10x Genomics|123 Reg!|3D CAD|3DEXPERIENCE Platform|3Dexperience|ABB Robotics|ABC Fitness Solutions|ACORD|ADP|ADP Payroll|AI Fairness 360 Toolkit|ALIS|AMAZON ELASTIC CONTAINER SERVICE (ECS)|ANSYS|APS|ARGUS|ARI|ARMIS|ASG-Cypress|ASM|ASP.NET|ATIVA|AVEVA Historian|AVEVA System Platform|AVG|AWS App Runner|AWS CloudFormation|AWS CodePipeline|AWS Control Tower|AWS Cost Explorer|AWS Data Lake Storage|AWS Direct Connect|AWS Glue|AWS Guardrails|AWS IoT|AWS IoT Greengrass|AWS Lake Formation|AWS Lambda|AWS Organizations|AWS Secrets Manager|AWS Security Hub|AWS Service Catalog|AWS Step Functions|AWS Systems Manager|AZURE DATA LAKE STORAGE|Acropolis|Activated Insights|Activated Insights Recruit|ActiveControl|Acuity Elm|Acunetix|Ad Dynamo|Adecco|Adobe Acrobat|Adobe Acrobat DC|Adobe Acrobat Pro|Adobe Campaign|Adobe Captivate|Adobe Character Animator CC|Adobe Connect|Adobe Creative Suite|Adobe Customer Journey Analytics|Adobe Experience Manager|Adobe Experience Manager Guides|Adobe Experience Manager as a Cloud Service|Adobe Fonts|Adobe GenStudio|Adobe Illustrator|Adobe Launch|Adobe Photoshop|Adobe Real-Time CDP|Adobe Sign|Adobe Workfront|Adobe XD|Advisory Board|Agile CRM|Ahrefs|Airtable|Akamai DNS|Akamai Edge|Akta|Alation|Alation Data Catalog|Alchemy|Alianza Cloud Voice Platform|Alibaba|All Siemens PLM Products|Allen-Bradley|Almond|Altair EDEM|Alteryx|Alteryx Server|Altiris Asset Management Suite|Amazon|Amazon API Gateway|Amazon AWS|Amazon AppFlow|Amazon Athena|Amazon Aurora|Amazon Chime|Amazon CloudFront|Amazon CloudWatch|Amazon Connect|Amazon DynamoDB|Amazon EC2|Amazon EC2 Reserved Instances|Amazon EMR|Amazon Elastic Container Service For Kubernetes (Eks)|Amazon EventBridge|Amazon GuardDuty|Amazon Inspector|Amazon Kinesis|Amazon Neptune|Amazon Redshift|Amazon Relational Database Service (RDS)|Amazon Route 53|Amazon S3|Amazon SageMaker|Amazon Simple Email Service (SES)|Amazon Simple Email Services (SES)|Ambassador|Amber|Americart|Amplify|Anaplan|Anaqua IdeaPoint|AngularJS|AngularJS V1|Angulartics|Anitian FedRamp Comprehensive|Ansible|Anthos GKE on-prem|AnyLogic|Aon Ability And Skills Assessment|Aon Assessment Solution|Aon Behavioral Assessment|Aon Coding Assessment|Aon Gamified Assessment|Aon Job Simulations|Aon Remote Proctoring|Aon Video Interviewing Tool|Aon Virtual Assessment Center|Apache 2.2|Apache Airflow|Apache Atlas|Apache Avro|Apache Camel|Apache Flink|Apache HBase|Apache Hadoop|Apache Hadoop Yarn|Apache Hive|Apache HttpComponents|Apache JMeter|Apache Kafka|Apache Lucene|Apache Nutch|Apache OpenJPA|Apache OpenMeetings|Apache Phoenix|Apache Qpid|Apache Solr|Apache Spark|Apache Spark SQL|Apache Tomcat|Apache Trafodion|Apester|Apigee|Apple MacBook|Apple Mobile Web App Capable|Apple Mobile Web App Status Bar Style|Apple Mobile Web Clips Icon|Apple iPad|Aprimo|Apttus|Ar-Go|Arc|ArcSight Enterprise Security Manager|ArcSight Recon|Arcadia Data|Argo|Ariba|Ariba Contract Management|Ariba Electronic Invoice Management|Ariba Payables|Ariba Procurement Solutions|Arisglobal|Articulate 360|Articulate Storyline|Asana|Ascent|Ascentis|Ataccama|Ataccama DQ|Ataccama One|Atea Zephyr|Aternity|Atlas RFID Jovix|Atlas Resell Management|Atlassian Bamboo|Atlassian Jira|Atlassian Jira Service Management|AtmosAI|Atomic Data|AuditBoard|Aurora|Authomize|Autodesk AutoCAD|Autodesk AutoCAD Plant 3D|Autodesk BIM 360 Docs|Autodesk Build|Autodesk Maya|Autodesk Navisworks|Autodesk Revit|Automated Image Builds With Jenkins, Packer, And Kubernetes|AvePoint|AvionteBOLD|Aws Inventory|Azure Analysis Services|Azure Bastion|Azure Content Moderator|Azure DNS|Azure Databricks|Azure Dedicated SQL pool|Azure Defender|Azure Devops|Azure Machine Learning|Azure Monitor|Azure SQL|Azure Synapse Analytics|BCP|BERT Language Model|BIM 360|BIOVIA|BIOVIA Notebook|BRAVO!|Babel|Base SAS|Basis Technologies|Beeline Contingent Workforce|Benchling|BigQuery|Bing Webmater Tools|BlackLine Financial Close Managem ...
# 🚨 Row 226, Column 'Technographics' contains invalid character(s): '|.NET|ASP.NET|AWS Glue|Adobe Analytics|Adobe Creative Suite|Adobe Experience Cloud|Adobe Experience Manager|Adobe Launch|Adobe Marketing Cloud|Adobe Marketo Engage|Adobe Workfront|Adobe XD|Airtable|Akamai Bot Manager|Akamai DNS|Akamai Edge|Akamai mPulse|Alteryx|Alteryx Designer|Amazon ALB|Amazon AWS|Amazon S3|Anaplan|AngularJS|Animate On Scroll|Ansible|Apache JMeter|Apache Kafka|Apache Spark|Apache Storm|AppDynamics|Appium|Apple Mobile Web App Capable|Apple Mobile Web App Status Bar Style|Apptio|Archibus|Artifactory|Asana|Ativo|Atlassian Jira|AuditBoard|Autodesk AutoCAD|Azure DNS|Azure Databricks|Azure Devops|Azure Kubernetes Service|Azure Monitor|Azure Sentinel|BeyondTrust Remote Support|Bing Webmater Tools|Bitbucket|Bitcoin|Blackline|Blockchain|Bloomberg|Boomerang|Bootstrap|C#|C++|COBOL|CallTrackingMetrics|Canva|Capital IQ|Celonis|Chainalysis|Chrome River|CircleCI|Cisco Webex|Citrix|Citrix NetScaler|Cloudflare|Cloudflare Bot Management|Cloudflare DNS|Collibra|Content Type Options|Core-JS|Cvent|CyberArk|DMARC|Databricks|Datadog|Dataiku|Denodo|Digicert SSL|Django Language|Docker|DocuSign|Doubleclick.net|Dow Jones|Elastic Kibana|Elasticsearch|Element UI|Everest Technologies|Expensify|Extreme Networks|Facebook Page Administration|Facebook Pixel|Facebook Sharer|FactSet|Figma|Fiserv|Forcepoint|GTreasury|Getty Images|Git|GitHub Copilot|GitLab|GitLab CI|Github|Github Actions|Global Site Tag|Go|Google|Google Ads|Google Analytics|Google Cloud Platform|Google Hosted Angular Material|Google Kubernetes Engine (GKE)|Google Maps|Google Marketing Platform|Google Search Central|Google Tag Manager|Gradle|Grafana|GraphQL|H2O Webserver|HCL Notes|HTML|HTML 5 Specific Tags|HTML5 Doctype|Hammer Js|Hazelcast|IBM Cognos Analytics|IBM Cognos Analytics with Watson|IBM Db2|IBM MQ|IBM Planning Analytics|IBM z/OS Operating System|Infoblox|Informatica|Investis|Ionic Framework|Ivalua|JSON|JSON-LD|JUnit|Jakarta EE|Jasmine|Java|JavaScript|Javascript Defer|Jenkins|Jupyter|K2F|Kerberos|Kubernetes|Kyriba|LexisNexis|LinkedIn Ads|LinkedIn Insight Tag|Linux|Liquibase|Loopio|MATLAB|Markit|Max Width|Medallia|Memcached|MicroStrategy|Microsoft|Microsoft 365|Microsoft Access|Microsoft Advertising|Microsoft Azure|Microsoft Dynamics|Microsoft Excel|Microsoft Exchange|Microsoft Intune|Microsoft Outlook|Microsoft PowerPoint|Microsoft SQL Server|Microsoft SharePoint|Microsoft Teams|Microsoft Word|Min Width|MongoDB|Moogsoft|Mosaic|Murex|MySQL|Neo4j|New Relic|Node.js|NumPy|Okta|OneTrust|Open Graph|OpenID Connect|Optanon|Oracle Database|Oracle Enterprise Manager|Oracle Exadata Database Machine|Oracle HCM Cloud|Oracle NoSQL|Oracle cloud|PHP|Palo Alto Firewalls|Pentaho|Perl|Picture Element|Ping Identity|Plotly|Pluralsight Skills|PortSwigger Burp Suite|PostgreSQL|Postman|Prometheus|Proofpoint|Pwc|PyScript|PyTorch|Python|QlikView|Qualtrics|Qualys|Quant|Qvidian|RSA SecurID Suite|RabbitMQ|Ranorex|Redis|Redux|Refinitiv|Refinitiv Eikon|RequireJS|RocketDocs|Ruby|RxJS|S&P Capital IQ|SAS|SPF|SS&C|SSL by Default|SailPoint|SailPoint IdentityIQ|SailPoint IdentityNow|Salesforce Service Cloud|Saviynt|Scala|Schema|Securonix|Selenium|ServiceNow|Simple Machines Forum|SirionLabs|Slick JS|Smarsh|Smartsheet|Snowflake|Social Intelligence|SolarWinds|SonarQube|Sovos|Sparql|Splunk|Spock|Spring Boot|Spring Cloud|Spring Framework|Srcset|Stardog|Stata|Streamlit|Strict-Transport-Security|Subhub|Subversion|Sybase|Tableau|Targetprocess|TeamCity|TensorFlow|Teradata|Teradata Vantage|Trello|Twitter Cards|TyMetrix 360°|TypeScript|UPS|UiPath|Unified Modeling Language|Unix|UserWay|VMware|Veracode|Viewport Meta|Visier|Visual Studio Code|Vue|WAI-ARIA|Webex Panel|Webpack|Windows 11|Wiz|Wiz Cloud Security Platform|X-Frame-Options|XSLT|Yardi|ZURB Foundation|Zendesk|Zoom|Zscaler|gRPC|iManage|iPhone / Mobile Compatible|jQuery|jQuery UI|jQuery UI Mouse|mPulse|scikit-learn|vSphere|'
# 🚨 Row 230, Column 'Technographics' contains invalid character(s): "|.NET|.NET 5|10x Genomics|123 Reg!|3D Systems|ADP|ADP Payroll|ADT Access Control|AIMS Flight Operations Systems|ALIS|AMI|AMO|AMP|APC|APL|APS|ASP.NET|ATIVA|AVEVA System Platform|AWS App Runner|AWS CloudFormation|AWS CodeBuild|AWS CodeDeploy|AWS Fargate|AWS Glue|AWS Guardrails|AWS Key Management Service|AWS Lambda|AWS Secrets Manager|AWS Security Hub|AWS Step Functions|AWS WAF|AZURE DATA LAKE STORAGE|AbbVie|Abbott Instrument Manager|Abbott M2000 Realtime System|Acronis|Acronis Backup And Recovery|Activated Insights|Activated Insights Recruit|Activated Insights Retain|ActiveControl|Acuity Elm|Adobe Acrobat|Adobe Acrobat DC|Adobe Acrobat Pro|Adobe Audience Manager|Adobe Campaign|Adobe Captivate|Adobe Connect|Adobe Content Repository eXtreme|Adobe Customer Journey Analytics|Adobe Dynamic Media Classic|Adobe Experience Cloud|Adobe Experience Manager|Adobe Experience Manager Guides|Adobe Experience Manager as a Cloud Service|Adobe GenStudio|Adobe Illustrator|Adobe InDesign|Adobe Marketing Cloud|Adobe Marketo Engage|Adobe Photoshop|Adobe Premiere Pro|Adobe Real-Time CDP|Adobe Sign|Adobe Workfront|Adobe XD|Advanced Vendor Management|Advisory Board|Adyen|Afterpay|Agile CRM|Agilent SLIMS|Agilent Technologies|Agility Software|Akamai DNS|Akamai Edge|Akamai HD|Alation|Alation Data Catalog|Albert.ai|All Siemens PLM Products|Alliance Gateway|Almond|Alterian|Alteryx|Alteryx Designer|Altezza|Altiris Asset Management Suite|Altium|Altium Designer|Amazon|Amazon ALB|Amazon AWS|Amazon AWS Identity And Access Management (IAM)|Amazon Athena|Amazon Business|Amazon CloudFront|Amazon CloudWatch|Amazon EC2|Amazon Elastic Container Service For Kubernetes (Eks)|Amazon GuardDuty|Amazon Neptune|Amazon Redshift|Amazon Route 53|Amazon S3|Amazon SageMaker|Amazon Simple Email Service (SES)|Amazon Simple Email Services (SES)|Amazon Textract|Amplience|Android Interface Definition Language (AIDL)|Android Studio|AngularJS|AngularJS V1|Animate On Scroll|Anomali|Ansible|Anthos GKE on-prem|Apache 2.4|Apache Airflow|Apache HBase|Apache Hadoop|Apache Hive|Apache Kafka|Apache MXNet on AWS|Apache Phoenix|Apache Sling|Apache Spark|Apache Spark SQL|Apache Tomcat|Apache Traffic Server|Apigee|Appfigures|Apple Mobile Web App Capable|Apple Mobile Web App Status Bar Style|Apple Mobile Web Clips Icon|Apple iPad|Apple iPhone|Applicata|Applied Systems|Apttus|Aras|Arduino|Arena PLM|Ariba|Ariba Electronic Invoice Management|Ariba Payables|Articulate 360|Articulate Storyline|Asana|Ascent|Ascentis|Atex Digital Media|Atlan|Atlan Data Catalog|Atlassian Jira|Atlassian Jira Service Management|AutoDesSys|AutoSys Workload Automation|Autodesk AutoCAD|Autodesk Revit|Automate|Automated Image Builds With Jenkins, Packer, And Kubernetes|Automatr|Azure Analysis Services|Azure Bastion|Azure Content Moderator|Azure Databricks|Azure Dedicated SQL pool|Azure DevOps Server|Azure Devops|Azure Functions|Azure Key Vault|Azure Logic Apps|Azure Pipelines|Azure SQL|BCP|BIG-IP|BIG-IP Advanced WAF|BIG-IP Local Traffic Manager|BIOVIA|BSG|BSI|BT|BT Business Phone Systems|Babel|Backbone.js|Balsamiq|Base SAS|Basis|Basis Technologies|Beeline Talent Acquisition|Benchling|BeyondTrust|BeyondTrust Privileged Session Manager|BigQuery|BlackLine Financial Close Management|Blackberry 5|Blackline|Blackmagic Design|Bloomberg|Bloomberg Tax|BluJay Solutions Transportation GTN|Blue Coat|Blue Prism|Blue Yonder|Blue Yonder Luminate|Blujay|Blujay Transportation Management|Boomi|Bootbox.js|Bootstrap|BootstrapCDN|Boto 3|Boulevard Software|Boundary|Brandwatch|Braze|Brevitas|Bridge|Brightcove|Brightcove Player|Broadcom Service Virtualization|Bruno|C|C++|CA Customer Experience Manager (CEM)|CA Project Portfolio Management (PPM)|CAKE Affiliate Marketing|CB Insights|CDC|CDD Vault Inventory|CDS MVS|CFML|CGI Tapestry|CIARA Hardware|COGZ|CPGSuite|CSL|CVS|Calendly|Canada Post|Canonical|Canva|Capital One Merchant Services|Carina|Carto|Causal|Cegid Talent Acquisition|Censys|Centr ...
# 🚨 Row 233, Column 'Technographics' contains invalid character(s): "|.NET|.NET Framework|10x Genomics|123 Reg!|3D CAD|3D Systems|ABAP|AD Fusion|ADP|ADP Payroll|ALIS|AMAZON ELASTIC CONTAINER SERVICE (ECS)|ANSYS|AON Hewitt|APS|ARGUS|ASG-Cypress|ASM|ASP.NET|AT&T Global Network Client|AT&T IP Toll-Free|AT&T Managed Internet Service (MIS)|AT&T Managed Threat Detection and Response Service|AT&T Network-Based IP Remote Access|ATIVA|ATT|AVEVA System Platform|AWS Amplify|AWS App Runner|AWS Batch|AWS CloudFormation|AWS CodeBuild|AWS CodeDeploy|AWS CodePipeline|AWS Copilot|AWS Data Pipeline|AWS Database Migration Service|AWS Elastic Beanstalk|AWS Fargate|AWS Glue|AWS Key Management Service|AWS Lambda|AWS Migration Hub|AWS Multi-Factor Authentication|AWS Secrets Manager|AWS Service Catalog|AWS Step Functions|AWS Systems Manager|AZURE FILES|Accenture Cloud Infrastructure Managed Services|Activated Insights|Activated Insights Recruit|Activated Insights Retain|ActiveControl|AdImpact|Adobe Acrobat|Adobe Acrobat DC|Adobe Acrobat Pro|Adobe After Effects|Adobe Campaign|Adobe Captivate|Adobe Creative Suite|Adobe Customer Journey Analytics|Adobe Document Cloud|Adobe Experience Cloud|Adobe Experience Manager|Adobe Experience Manager Guides|Adobe Experience Manager as a Cloud Service|Adobe Express|Adobe GenStudio|Adobe Illustrator|Adobe InDesign|Adobe Journey Optimizer|Adobe Launch|Adobe Marketing Cloud|Adobe Marketo Engage|Adobe Photoshop|Adobe Premiere Pro|Adobe Real-Time CDP|Adobe Sign|Adobe Target|Adobe Workfront|Adobe XD|Agile CRM|Agilent OpenLab|Agilent SLIMS|Agility Software|Akamai DNS|Akamai Edge|Akamai Identity Cloud|Alianza Cloud Voice Platform|Alibaba|All Hours|All Siemens PLM Products|Almond|AlphaSSL|Altair HyperMesh|Alteryx|Altiris Asset Management Suite|Altium|Amazon|Amazon ALB|Amazon API Gateway|Amazon AWS|Amazon AppFlow|Amazon Athena|Amazon CloudFront|Amazon CloudWatch|Amazon Cognito|Amazon Connect|Amazon DynamoDB|Amazon EC2|Amazon EMR|Amazon Elastic Container Service For Kubernetes (Eks)|Amazon Elastic File System (EFS)|Amazon EventBridge|Amazon GuardDuty|Amazon Inspector|Amazon Kinesis|Amazon MSK|Amazon Neptune|Amazon QuickSight|Amazon Redshift|Amazon Relational Database Service (RDS)|Amazon Route 53|Amazon S3|Amazon SageMaker|Amazon Simple Email Service (SES)|Amazon Simple Email Services (SES)|Amazon Simple Notification Service (SNS)|Amazon Textract|American Express|Americart|Anaplan|Anaqua|Anaqua IdeaPoint|Android|Android Interface Definition Language (AIDL)|AngularJS|AngularJS V1|Ansible|Ant Design|Anthos GKE on-prem|Apache ActiveMQ|Apache Airflow|Apache Cassandra|Apache Flink|Apache Hadoop|Apache Hive|Apache JMeter|Apache Kafka|Apache Phoenix|Apache Spark|Apache Spark MLlib|Apache Tomcat|Apache Traffic Server|AppDynamics|Appboy|Appium|Apple Final Cut Pro|Apple MacBook|Apple Mobile Web App Capable|Apple Mobile Web Clips Startup|Apple iPad|Apple iPhone|Applitools|Ar-Go|Aras|Aravo|Arc|ArchiMate|Argo|Ariba|Ariba Contract Management|Ariba Electronic Invoice Management|Ariba Payables|Ariba Procurement Solutions|Arsenal|Articulate 360|Articulate Storyline|Artifactory|Asana|AspenTech|Atempo|Atex Digital Media|Atlassian Jira|Atos|AuditBoard|Audition|Aurora|Auth0|AutoCad Electrical|Autodesk AutoCAD|Autodesk AutoCAD Plant 3D|Autodesk Fusion 360|Autodesk Inventor|Autodesk Revit|Automate|Automated Image Builds With Jenkins, Packer, And Kubernetes|AutomatedQA|Automatr|AvePoint|Aviso|Azure Bastion|Azure Boards|Azure Computer Vision|Azure Container Service|Azure Content Delivery Network|Azure Content Moderator|Azure DNS|Azure Databricks|Azure Dedicated SQL pool|Azure DevOps Server|Azure Devops|Azure Key Vault|Azure Kubernetes Service|Azure Logic Apps|Azure Monitor|Azure Monitor Application Insights|Azure Pipelines|Azure Policy|Azure SQL|Azure Search|Azure Sentinel|Azure Synapse Analytics|BIG-IP|BIOVIA Notebook|BMC Control-M|BMC Middleware Management|BMC Numara|BMC Remedy|BMC Remedy ARS|BMC Remedy Help Desk|BMC Remedy Magic|BOARD|Babel|Baidu|Bal ...
# 🚨 Row 263, Column 'Technographics' contains invalid character(s): "|.NET|.NET 5|123 Reg!|A10 Defend|A10 Networks|ADP|ADP Celergo|ADP Payroll|ADTRAN|AFAS ERP|AG Grid|AMAZON ELASTIC CONTAINER SERVICE (ECS)|ASP.NET|AT Internet|AT&T Global Network Client|AT&T IP Toll-Free|AT&T Managed Internet Service (MIS)|AT&T Managed Threat Detection and Response Service|AT&T Network-Based IP Remote Access|ATT|AWS App Runner|AWS Batch|AWS CodePipeline|AWS Elastic Beanstalk|AWS Glue|AWS Lambda|AWS Step Functions|ActiveControl|Adobe Acrobat|Adobe Campaign|Adobe Customer Journey Analytics|Adobe Experience Cloud|Adobe Experience Manager|Adobe Experience Manager Guides|Adobe Experience Manager as a Cloud Service|Adobe GenStudio|Adobe Marketing Cloud|Adobe Marketo Engage|Adobe Sign|Adobe Workfront|Advent Software|Agile CRM|Alcatel Lucent|Alianza Cloud Voice Platform|Alteryx|Altiris Asset Management Suite|Amazon|Amazon AWS|Amazon CloudFront|Amazon CloudWatch|Amazon DynamoDB|Amazon EC2|Amazon Elastic Container Service For Kubernetes (Eks)|Amazon Kinesis|Amazon MSK|Amazon Machine Image|Amazon QuickSight|Amazon Redshift|Amazon Route 53|Amazon S3|Amdocs|American Express Global Business Travel|AngularJS|AngularJS V1|Ansible|Anthos GKE on-prem|Apache Ignite|Apache JMeter|Apache Kafka|Apache Spark|AppViewX|Apple Mobile Web App Capable|Apple Mobile Web App Status Bar Style|Apple Mobile Web Clips Icon|Appspace|Arista NG Firewall|Arista Networks|Asure Software|Atlassian Jira|AuditBoard|Aurora|AutoRABIT|Automattic|Axon Dispatch|Azure Bastion|Azure Content Moderator|Azure DNS|Azure Devops|Azure Monitor|Azure SQL|BCP|BIG-IP|BOARD|Batch|Behavox|BeyondTrust|BeyondTrust Privileged Remote Access|BeyondTrust Privileged Session Manager|Bitbucket|Bitcoin|Bloomberg|Bloomberg Tax|Bloomberg Terminal|Box|BrightSign|Brightcove|Brightcove Player|BroadSoft|Bruno|BugHerd|C|C#|C++|CAMPUS|CB Protection|CFML|CIARA Hardware|CItrix Gateway|Calero|Calix|Cambium|Canada Post|Canva|Capital IQ|CenturyLink|Ciena CN|Cisco 5500|Cisco Application Centric Infrastructure|Cisco Catalyst|Cisco Catalyst Switches|Cisco Collaboration Meeting Rooms (CMR)|Cisco IOS|Cisco Intrusion Detection Sensor|Cisco MXE 3500 Series|Cisco Mobility Express|Cisco Nexus|Cisco Nexus Switches|Cisco Prime Access Registrar|Cisco SD-WAN|Cisco Session Border Controller (SBC)|Cisco TelePresence Video Communication Server Expressway (VCS -E)|Cisco UCS Servers|Cisco Unified Communications Manager|Cisco Unified Communications Manager (CallManager)|Cisco Unified Computing System|Cisco Unified Intelligent Contact Management Enterprise|Cisco Unified Survivable Remote Site Telephony (SRST)|Cisco VoIP|Cisco Webex|Cisco Webex Connect|Citrix|Citrix ADC|Citrix DaaS|Citrix NetScaler|Citrix ShareFile|Citrix Virtual Apps and Desktops|Cloudflare|Cloudflare Application Security and Performance|Cloudflare Bot Management|Cloudflare CDN|Cloudflare DNS|Codebase|Coherent Path|Cohesity Data Cloud|Cohesity DataProtect|ComTech Satellite Modems|Concur|Concur Purchase Request|Condeco|Confluence|Confluent|Content Type Options|Copado|Core-JS|CorpAxe|Crestron|CrowdStrike Falcon X|Crowdstrike|Crowdstrike Falcon|CyberArk|Cyberark Privileged Access Manager|D3 Security|DAV|DMARC|DNS Prefetch|Darktrace|DataTables|Datadog|Datadog Database Monitoring|Datadog Infrastructure Monitoring|Datadog Log Management|Datadog Service Catalog|Dcom|Dealogic|Delta Lake|Divi|Docker|DocuSign|Doubleclick.net|Driven Data|Dynatrace|Dynatrace Application Monitoring|ECMAScript Shims|ETSY|Easyway|Elastic Stack|Elasticsearch|Eloqua Marketing Automation|Energy Group Hosting|EnterpriseDB (EDB)|Entrust|Enverus|Equinix|Equinix Metal|Es6 Promise|Exadata Cloud@Customer|ExtraHop Reveal(x)|Extrahop|Extron|F5 Networks|F5 SSL Orchestrator|F5 Silverline DDoS Protection|Facebook Page Administration|Facebook-SDK|FactSet|Factiva|Fidessa|Fieldbook|Figma|Finastra|Finastra Global PAYplus|First Visit Home Care|Fitvids.js|Fives Group|FlashArray//X|Font Awesome|Forms|Fortinet|Fortinet FortiPortal|Four|F ...
# 🚨 Row 288, Column 'Technographics' contains invalid character(s): "|.NET|123 Reg!|1Password|ABAP|ADP|ADP Celergo|ADP Payroll|ADP Streamline|ADP WorkForce Now|ADT Access Control|AIC|ALIS|AMAZON ELASTIC CONTAINER SERVICE (ECS)|AMP|ANSYS Fluent|APS|ASP.NET|ATT|ATT Dns|AVEVA System Platform|AWS App Runner|AWS AppSync|AWS CloudTrail|AWS Command Line Interface|AWS Glue|AWS IoT|AWS Lake Formation|AWS Lambda|AWS Managed Services|AWS Organizations|AWS Secrets Manager|AWS Security Hub|AWS Systems Manager|Abila Fund|AccelerationVMS|Acoustic|Acronis Backup And Recovery|Activated Insights|ActiveControl|AdImpact|Adobe Acrobat|Adobe Acrobat DC|Adobe Acrobat Pro|Adobe Campaign|Adobe Captivate|Adobe Connect|Adobe Creative Suite|Adobe Customer Journey Analytics|Adobe Experience Manager Guides|Adobe Experience Manager as a Cloud Service|Adobe GenStudio|Adobe Illustrator|Adobe Photoshop|Adobe Portfolio|Adobe Premiere Pro|Adobe Sign|Adobe Workfront|Adobe XD|Agari|Agile CRM|Agilent SLIMS|Akta|Alation|Alianza Cloud Voice Platform|Alibaba|All Hours|AlphaFold|Alteryx|Altiris Asset Management Suite|Amazon|Amazon AWS|Amazon Athena|Amazon CloudWatch|Amazon DynamoDB|Amazon EC2|Amazon Elastic Container Registry (ECR)|Amazon Elastic Container Service|Amazon Elastic Container Service For Kubernetes (Eks)|Amazon Elastic File System (EFS)|Amazon RDS for MySQL|Amazon Route 53|Amazon S3|Amazon SageMaker|Amazon Simple Email Service (SES)|Amazon Simple Email Services (SES)|American Express|Americart|Analytic Partners|Android|AngularJS|AngularJS V1|Anomali|Ansible|Anthos GKE on-prem|Anybill|Apache 2.2|Apache 2.4|Apache Airflow|Apache Avro|Apache Hadoop|Apache Hadoop Yarn|Apache Hive|Apache HttpComponents|Apache Hudi|Apache Kafka|Apache OpenJPA|Apache OpenMeetings|Apache Phoenix|Apache Qpid|Apache Spark|Apache Trafodion|Apigee|Appian|Apple Final Cut Pro|Apple Mobile Web App Capable|Apple Mobile Web App Status Bar Style|Apple Mobile Web Clips Icon|Apple Mobile Web Clips Startup|Apple iPad|Apptio|Apptio Targetprocess|Apptitude|Aravo|Archer|Archer Regulatory & Corporate Compliance Management|Archer Risk Management|Ariba|Ariba Contract Management|Ariba Electronic Invoice Management|Ariba Payables|Arista Networks|Articulate 360|Articulate Rise 360|Articulate Storyline|Articulate Storyline 360|Asana|Astute Business|Atea Zephyr|Atlas RFID Jovix|Atlas Resell Management|Atlassian Jira|Atlassian Jira Service Management|AutoDock|Autodesk AutoCAD|Autodesk Revit|Axonify|Azure Bastion|Azure Container Service|Azure Content Moderator|Azure DNS|Azure Databricks|Azure DevOps Server|Azure Devops|Azure Monitor|Azure SQL|Azure Search|Azure Sentinel|BRAT|Babel|Backlog|Balsamiq|Base SAS|Batavi|Benchling|Bing Webmater Tools|Bitbucket|Blackmagic Davinci Resolve|Blockchain|BlueBird|BootstrapCDN|Brady|Brightcove|Brightidea|Broadcom Service Virtualization|Bruker Timstof|Bruno|Business Wire|Byte Loan Origination System|C|C#|C++|CA CMDB|CAKE Affiliate Marketing|CATS|CB Protection|CDC|CDS MVS|CFML|CIARA Hardware|CLOUDBEES CD|COGZ|COMET|COMSOL Multiphysics|CS Stars|CSP|CTT|Cadence|Canada Post|Canva|Capital One Merchant Services|Causal|Celeritas|Ceridian|Cerner|ChatGPT Enterprise|Cilium|Cincinnati Bell|Cisco Application Centric Infrastructure|Cisco Collaboration Meeting Rooms (CMR)|Cisco IOS|Cisco Intrusion Detection Sensor|Cisco IronPort|Cisco MXE 3500 Series|Cisco Mobility Express|Cisco Nexus|Cisco Nexus Switches|Cisco Prime Access Registrar|Cisco Session Border Controller (SBC)|Cisco TelePresence Video Communication Server Expressway (VCS -E)|Cisco Unified Intelligent Contact Management Enterprise|Cisco Unified Survivable Remote Site Telephony (SRST)|Cisco Webex Connect|Cision|Citrix|Citus Data|Clark|Class Portfolio|Classnames|Clinical Ink|CloudBees|CloudBees Jenkins|CloudHealth|CloudNine Concordance|Cloudera Manager|Cloudflare|Cloudflare Bot Management|Codeship|Cognex|ColdForm|Collibra|Colombia|Como|CompTIA|Concur|Concur Purchase Request|Concur Travel|Confluent|Content Type Options|Conveyor|Cor ...
# ...
# 🚨 Row 1001, Column 'Account Name' contains invalid character(s): 'Aldi Süd'
# 🚨 Row 1052, Column 'Technographics' contains invalid character(s): '|.NET|123 Reg!|3DEXPERIENCE Platform|ALIS|AMO|ANSYS|APS|ASM|ASP.NET|AT Internet|AVADA|AVEVA System Platform|Ab Initio|ActiveControl|AcyMailing|AddEvent|Adobe Creative Suite|Adobe Fonts|Adobe XD|Ahrefs|Aiida|Akamai DNS|Alianza Cloud Voice Platform|AlphaFold|Altair FEKO|Altair Grid Engine|Altair HyperCrash|Altair RADIOSS|Altium|Amazon S3|Android|AngularJS|AngularJS V1|Animate On Scroll|Ansible|Apache 2.4|Apache HTTP Server|Apache Spark|Apple Mobile Web App Capable|Apple Mobile Web Clips Icon|Arduino|Arduino IDE|Argo|Argo CD|Articulate Storyline|Atlas RFID Jovix|Atlas Resell Management|Atos|Audacity|Autodesk AutoCAD|Autodesk Maya|Autodesk Navisworks|Autodesk Revit|Avaya Equinox|BERT Language Model|BIG-IP|BIOVIA|Benchmark|Bing Webmater Tools|Blackmagic Davinci Resolve|Bootstrap|Boundary|Bruno|C|C#|C++|CA Customer Experience Manager (CEM)|CATIA|CB Protection|CIARA Hardware|CMake|Cadence|Cadence Spectre Simulation|Calameo|Canonical|Canva|Cart Functionality|Cegid|Centreon|Ceph|Cerner|Chart.js|CheckPoint SDN|Chef|ChemDraw|Cisco Webex|Cisive|Classic ASP|Clef|Cloudera Manager|Cobalt|Cobbler|CodeIgniter|Colorbox|Column Shortcodes|Conserv|Contact Form 7|Content Type Options|Cookie Notice|Criteria|D3.js|DC/OS|DNN|DataTables|Dcom|Debian|Dell EMC IDPA|Dell Encryption|Dell Fluid File System|Dell PowerSwitch Data Center Switches|Dext|DigDash|Django CSRF|Django Language|Docker|Dolmen|Doubleclick.net|Download Monitor|Dublin Core|ENOVIA|Eclipse IDE|Edge Delta|Efficy|Elementor|EmbedPlus|Engagez|Ennov Regulatory Suite|EnterpriseDB (EDB)|Epic Cadence|Epicor Eclipse|Esprit|Exadata Cloud@Customer|FACTORY|Facebook CDN|Facebook Domain Insights|Facebook Measurement|Facebook Page Administration|Facebook Sharer|Facebook-SDK|Fama|Feko|Figma|First Visit Home Care|Fitvids.js|Flexpod|Flexslider|Fluence|Font Awesome|Fortinet|Fortran|Four|Framed|G2|GE Proficy Smart Factory|GE Proficy Smart Factory MES|GNU BASH|GOOGLE CLOUD AI PLATFORM|GTranslate|Gale|Geant4|Getty Images|Git|GitLab|Github|Global Site Tag|Gomez|Google AI|Google API|Google Analytics|Google Cloud TPU|Google Fonts|Google Hosted Libraries|Google Hosted jQuery|Google Maps|Google Marketing Platform|Google Search Central|Google Tag Manager|Google Translate Widget|Google Universal Analytics|GotU|Grafana|Gstatic Google Static Content|HP Business Availability Center (BAC)|HP-UX|HPE OneView|HTML|HTML Tidy|HTML5 Doctype|HTML5 Media|HTML5Shiv|Hadoop Distributed File System (HDFS)|HarePoint|HashiCorp Terraform|Helm Package Manager|High Radius|Hirschmann|Horizon 7|Hover Intent|Hugging Face|IBM Maximo|IBM Z Workload Scheduler|ICP-MS|IE PNG Fix|IP Exchange|ISIS Papyrus|ISN|ImageJ|Impos|Indeed|Infinite Scroll|Infor XA|Instagram API|Intel VTune|Internet Information Services (IIS)|JSON|JSON-LD|JW Player|Jakarta EE|Java|JavaScript|Jenkins|Jinja2|Joomla|Juniper Networks|JustiFi|KVM|Keras|Kerberos|KeyShot|Klaxoon|Kubernetes|Kyber|LAMMPS|LS-DYNA|LabOS|LabVIEW|Lattice|Lattice Radiant|Lazysizes|Lightbox|Lightcast|LinkedIn API|Linkedin Follow Company Plugin|Linux|Linux Containers (LXC)|Linux Kernel|Live Writer Support|LoadDNS|Loupe|Ludovic|MATLAB|MODX|Magnific Popup|Make|MariaDB|Mastercam|MathJax|MathWorks|Matomo|Matplotlib|Maya HTT Structural Analysis Toolkit (SATK)|MediaElement.js|Mermaid|Meta Quest|Micro Focus Business Availability Center|Micro Focus Business Process Monitor|Micro Focus Network Node Manager|Micro Focus Real User Monitoring|Microdata|Microsoft|Microsoft 365|Microsoft Azure Spatial Anchors|Microsoft BPOS|Microsoft Dev Box|Microsoft DirectX|Microsoft Enterprise Project Management|Microsoft Entra ID|Microsoft Hyper-V Server|Microsoft Machine Learning Server|Microsoft Power BI|Microsoft Power Platform APIs|Microsoft PowerPoint|Microsoft Remote Desktop Protocol (RDP)|Microsoft SQL Server|Microsoft SharePoint|Microsoft Sharepoint Enterprise|Microsoft Sharepoint Foundation|Microsoft Sharepoint Server 2010|Microsoft Visio|Microsoft Visual Studio| ...
# 🚨 Row 1078, Column 'Account Name' contains invalid character(s): 'Stadt München'
# 🚨 Row 1132, Column 'Account Name' contains invalid character(s): 'Le Gouvernement Du Grand-Duché de Luxembourg'
# 🚨 Row 1149, Column 'Account Name' contains invalid character(s): 'Steiermärkische Krankenanstalten'
# 🚨 Row 1172, Column 'Account Name' contains invalid character(s): 'Lantmäteriet-GOV'
# 🚨 Row 1178, Column 'Account Name' contains invalid character(s): 'Region Jönköpings'
# 🚨 Row 1185, Column 'Account Name' contains invalid character(s): 'Universitäts-Krankenhaus Eppendorf'
# 🚨 Row 1201, Column 'Account Name' contains invalid character(s): 'Landesverwaltung Österreich'
# 🚨 Row 1212, Column 'Account Name' contains invalid character(s): 'GEMDAT OÖ GmbH Co KG'
# 🚨 Row 1278, Column 'Account Name' contains invalid character(s): 'Knünz GmbH'
# 🚨 Row 1296, Column 'Technographics' contains invalid character(s): "|123 Reg!|A10 Networks|AMAZON ELASTIC CONTAINER SERVICE (ECS)|ARGUS|AVEVA Operations Control|AVEVA System Platform|AWS App Runner|Aberdeen|Activated Insights|ActiveControl|Adobe Acrobat|Adobe Acrobat DC|Adobe Acrobat Pro|Adobe Analytics|Adobe Audience Manager|Adobe Campaign|Adobe Connect|Adobe Creative Suite|Adobe Customer Journey Analytics|Adobe Experience Cloud|Adobe Experience Manager|Adobe Experience Manager Guides|Adobe Experience Manager as a Cloud Service|Adobe GenStudio|Adobe Launch|Adobe Marketing Cloud|Adobe Sign|Akamai Edge|Albert.ai|Alianza Cloud Voice Platform|AlphaFold|Altiris Asset Management Suite|Amazon|Amazon ALB|Amazon AWS|Amazon CloudFront|Amazon Route 53|Amazon S3|Amazon SageMaker|Amazon Simple Email Services (SES)|Apache 2.2|Apache HTTP Server|Apache Phoenix|Apple Mobile Web App Capable|Apple Mobile Web App Status Bar Style|Apple Mobile Web Clips Icon|Aras|Ariba|Ariba Payables|AspenTech|Aurora|Autodesk AutoCAD|Avere|Batavi|Beacon Ads|Box|Bruno|CA Audit|CA Service Management|CAKE Affiliate Marketing|CDC|CFML|CIARA Hardware|CLOUD DATAPREP|Canada Post|Carina|Cerebro|Cerner|Cherwell Software|Cisco Webex Connect|Citrix NetScaler|Clarify|Clark|Cloudflare|Cloudflare Bot Management|ClovisApp|Codebase|Cognito Forms|Como|Concur|Concur Purchase Request|Content Type Options|Core-JS|Coupa Global Compliance|Culpepper|D3 Security|DMARC|DUERP|Dakota|Dcom|Debian|Device Width|Digicert SSL|Directors Desk|DocuSign|Documentum xCP|Drupal|Dublin Core|Eaton|Eclipse IDE|Element UI|Elwood|Emerson Ups|EndNote|Es6 Promise|FOUNDATION|Facebook For Websites|Facebook Page Administration|Facebook Sharer|Factbook|Fastly|Fastly Hosted|Fling|Flint|Four|GE Proficy Smart Factory|GE Proficy Smart Factory MES|Garland|GastroPlus|Git|GlobalSign|GoTo Meeting|GoToWebinar|Google|Google API|Google Cloud DNS|Google Cloud Platform|Google Cloud Traffic Director|Google Cloud VPC Service Controls|Google Cloud VPN|Google Document AI|Google Fonts|Google Search Central|HP PA-RISC|HTML 5 Specific Tags|HTML5 Doctype|Hammer Js|HarePoint|Hiawatha|Hickory|Huawei FusionCube|I-Cell|IBM Unica|ICP-MS|Ibexa Content|Indio|Informa|Instagram API|Interchange|Internet Information Services (IIS)|JMP|Jasper|JavaScript|Javascript Defer|Kinaxis|LARVOL|LUIS|Lano|Let's Encrypt|LinkedIn Ads|LiveRamp|Lob|Lodash|Logmein|LoraWAN|MADS|Madison Logic|Mailgun|Manhattan Contact Center|Manhattan SCALE|Maryville|MassHunter|Max Width|Maya HTT Structural Analysis Toolkit (SATK)|Mentimeter|MetCal|Microdata|Microdata For Google Shopping|Microlab STAR|Microsoft|Microsoft 365|Microsoft 365 Copilot|Microsoft Azure|Microsoft Azure Europe West Region|Microsoft Azure Spatial Anchors|Microsoft Azure US North Region|Microsoft BPOS|Microsoft Copilot|Microsoft Dev Box|Microsoft DirectX|Microsoft Dynamics 365 Customer Voice|Microsoft Entra ID|Microsoft Excel|Microsoft Exchange|Microsoft Exchange Online|Microsoft OneDrive|Microsoft Power Automate|Microsoft Power BI|Microsoft Power Platform APIs|Microsoft PowerPoint|Microsoft Remote Desktop Protocol (RDP)|Microsoft Sharepoint Enterprise|Microsoft Visual Studio|Microsoft WTL|Microsoft Windows Deployment Services (WDS)|Microsoft Word|Min Width|Mobile Non Scaleable Content|Mobile Optimized|Multinet|NFrance|NetSuite Commerce|Nevada|Office 365 Mail|Open Graph|OpenText Extended ECM Platform|OutlookSoft|Outset|P2 Excalibur|PAVE|PHP|Peakon|Peninsula Fiber Network|Perkinelmer|Phoenix|Polycom RMX Series|PowerHouse|Premier|Providence|PyTorch|Python|QlikView|Qliktech|Quince|RME|Relatia|Respond|Resy OS|Rhombus|S1|SAP AI Core|SAP AI Launchpad|SAP Advanced Track and Trace|SAP Analytics Cloud|SAP BTP for Supply Chain|SAP BW/4HANA|SAP Billing and Revenue Innovation Management|SAP Business Planning and Consolidation|SAP Business Technology Platform|SAP Cash Management|SAP Cloud for Travel and Expense|SAP Commodity Management|SAP Controlling (CO)|SAP Convergent Charging (CC)|SAP Customer Activity Repository| ...
# 🚨 Row 1297, Column 'Account Name' contains invalid character(s): 'Topvita Investment S.à r.l.'
# 🚨 Row 1308, Column 'Technographics' contains invalid character(s): '|.NET Framework|123 Reg!|3D CAD|ANSYS|ANSYS Fluent|ANSYS HFSS|ARGUS|ASM|ASP.NET|AVEVA System Platform|AWS App Runner|AWS Direct Connect|AWS Guardrails|Ab Initio|Accelo|Access Workspace|Acoustic|ActiveControl|AddThis|Adobe Acrobat|Adobe Acrobat DC|Adobe Acrobat Pro|Adobe Active Content|Adobe Bridge|Adobe Campaign|Adobe Captivate|Adobe Customer Journey Analytics|Adobe Experience Manager|Adobe Experience Manager Guides|Adobe Experience Manager as a Cloud Service|Adobe Fonts|Adobe GenStudio|Adobe Illustrator|Adobe InDesign|Adobe Photoshop|Adobe Premiere Pro|Adobe Sign|Adobe XD|Agile CRM|Alianza Cloud Voice Platform|Alias Concept|All Hours|All Siemens PLM Products|Allen-Bradley|Alliance Gateway|AlphaFold|Altair HyperCrash|Alteryx|Altiris Asset Management Suite|Altium|Altium Designer|Amazon AWS|Amazon CloudFront|Amazon CloudWatch|Amazon Route 53|Amazon S3|Americart|AngularJS|AngularJS V1|Anitian FedRamp Comprehensive|Ansible|Ansys Maxwell|Anthos GKE on-prem|Apache 2.2|Apache Cassandra|Apache Groovy|Apache HBase|Apache HTTP Server|Apache HttpComponents|Apache OpenJPA|Apache OpenMeetings|Apache Phoenix|Apache Qpid|Apache Tomcat|Apollo CRM|Apple Mobile Web Clips Icon|ArcGIS Online|ArcInfo|Argo|Argo CD|Ariba|Ariba Contract Management|Ariba Electronic Invoice Management|Ariba Payables|Ariba Procurement Solutions|Arista NG Firewall|Arista Networks|Arista Switches|Articulate 360|Articulate Storyline|Asana|Aspen Plus|Atlas RFID Jovix|Atlas Resell Management|Atlassian Jira|Atos|AutoCad Electrical|Autodesk AutoCAD|Autodesk AutoCAD LT|Autodesk CFD|Autodesk Civil 3D|Autodesk Flow Production Tracking|Autodesk Fusion 360|Autodesk Inventor|Autodesk PDMC|Autodesk Point Layout|Autodesk Revit|Axis Video Management Software|Azure AI Services|Azure Bastion|Azure Content Moderator|Azure DNS|Azure Devops|Azure Machine Learning|Azure Network Watcher|Azure Policy|Azure Private Link|Azure SQL|BA Insight|BIG-IP|BIM 360|BIM Collaborate Pro|BLAST (Basic Local Alignment Search Tool)|Bentley|Bentley Hec-Pack|Bentley OpenFlows SewerGEMS|Bitbucket|Bitly|BlackBerry UEM|Blackberry 5|Blackberry Unified Endpoint Management|Blender|Blurb|Boomi|Bootstrap|BootstrapCDN|Boundary|Box|Bridge|British Telecom MPLS Network|C|C++|CA EPIC for z/VSE|CAE Flight Operations Solutions|CAMWorks|CAS genesisWorld|CATIA|CB Protection|CFEngine|CFML|CIARA Hardware|COGZ|COMSOL Multiphysics|CUDA|Cadence|Caldera|Calypso|Canonical|Capital One Merchant Services|Carbonblack|Cas|Chainer|ChatGPT|ChatGPT Enterprise|Check_MK|Chef|ChemDraw|Cint|Cisco ACE Application Control Engine|Cisco Collaboration Meeting Rooms (CMR)|Cisco IOS|Cisco Intrusion Detection Sensor|Cisco MXE 3500 Series|Cisco Mobility Express|Cisco Prime Access Registrar|Cisco Session Border Controller (SBC)|Cisco TelePresence Video Communication Server Expressway (VCS -E)|Cisco Unified Intelligent Contact Management Enterprise|Cisco Unified Survivable Remote Site Telephony (SRST)|Cisco Webex|Cisco Webex Connect|Citrix|Citrix Endpoint Management|Citrix ShareFile|CliftonStrengths|Cloud Load Balancing|CoSchedule|Codebase|Cohesity DataProtect|CompTIA|Comparably|Concur|Concur Purchase Request|Confluent|ControlLogix|Craft CMS|Creatio|Criteria|Crowdstrike|Crowdstrike Falcon|DHTML|DISYSTEM BASE ERP|DMARC|Dassault DELMIA|Dassault Systemes|Dcom|Dell PowerEdge|Dell PowerEdge Servers|Dell PowerScale|Denodo|DevonWay|Django Language|Docker|DocuSign|Documentum D2|Documentum xCP|Dojo Toolkit|Dot|Doubleclick.net|Dropbox|Dundas BI|Emercury|EndNote|EnterpriseDB (EDB)|Entrust|Es6 Promise|Everbridge|Exadata Cloud@Customer|Experian Employer Services|Exposure Events|FACTS|FARO SCENE|FOUNDATION|Facebook Measurement|Facebook Page Administration|Fedora|FileMaker|FileMaker Pro|FileVault|First Visit Home Care|Flexpod|Font Awesome|Fortran|FoundationDB|Four|Fourth|Frontrange|Fusion Manage|G2|GNU BASH|GROMACS|GSAP|GT STRUDL|GTreasury|Ganglia|Gaussian 16|Geant4|Gemini|Git|GitLab|GitLab CI|Github|Globa ...
# 🚨 Row 1347, Column 'Account Name' contains invalid character(s): 'Julius Bär'
# 🚨 Row 1429, Column 'Account Name' contains invalid character(s): 'Università degli Studi di Brescia'
# 🚨 Row 1430, Column 'Account Name' contains invalid character(s): 'Förster IT-Dienstleistungen GmbH'
# 🚨 Row 1438, Column 'Account Name' contains invalid character(s): 'Crédito y Caución'
# 🚨 Row 1497, Column 'Account Name' contains invalid character(s): 'Klinikverbund Südwest'
# 🚨 Row 1512, Column 'Account Name' contains invalid character(s): 'Université Bretagne Sud'
# 🚨 Row 1546, Column 'Account Name' contains invalid character(s): 'Bund Österreich'
# 🚨 Row 1589, Column 'Account Name' contains invalid character(s): 'Gebrüder Weiss'
# 🚨 Row 1611, Column 'Account Name' contains invalid character(s): 'Land Niederösterreich'
# 🚨 Row 1678, Column 'Account Name' contains invalid character(s): 'M. Ciencia e innovación'
# 🚨 Row 1689, Column 'Account Name' contains invalid character(s): 'Zürich Kanton'
# 🚨 Row 1690, Column 'Account Name' contains invalid character(s): 'Clay Topco S.à r.l.'
# 🚨 Row 1712, Column 'Account Name' contains invalid character(s): 'Zürich Stadt'
# 🚨 Row 1729, Column 'Account Name' contains invalid character(s): 'Gilfoyle Investment S.à r.l.'
# 🚨 Row 1785, Column 'Account Name' contains invalid character(s): "Institut Català d'Investigació Química"
# 🚨 Row 1814, Column 'Account Name' contains invalid character(s): 'Metsäliitto Osuuskunta'
# 🚨 Row 1822, Column 'Account Name' contains invalid character(s): 'Barmherzige Brüder'
# 🚨 Row 1827, Column 'Account Name' contains invalid character(s): 'Università degli Studi di Catania'
# 🚨 Row 1869, Column 'Account Name' contains invalid character(s): "Ministère de l'Économie"
# 🚨 Row 1880, Column 'Account Name' contains invalid character(s): 'MULTIVAC Sepp Haggenmüller SE & Co. KG'
# 🚨 Row 1909, Column 'Account Name' contains invalid character(s): 'St Franziskus Stiftung Münster'
# 🚨 Row 2069, Column 'Account Name' contains invalid character(s): 'Riddle Holdco S.à r.l.'
# 🚨 Row 2073, Column 'Account Name' contains invalid character(s): 'Instituto Português de Oncologia'
# 🚨 Row 2108, Column 'Account Name' contains invalid character(s): 'DEUTSCHE APOTHEKER- UND ÄRZTEBANK EG'
# 🚨 Row 2111, Column 'Account Name' contains invalid character(s): 'Società Estense Servizi Ambientali Spa'
# 🚨 Row 2116, Column 'Account Name' contains invalid character(s): 'Universitätsmedizin der Johannes Gutenberg-Universität Mainz'
# 🚨 Row 2139, Column 'Account Name' contains invalid character(s): 'Gouvernement de la Province de Québec'
# 🚨 Row 2142, Column 'Account Name' contains invalid character(s): 'OÖGH'
# 🚨 Row 2166, Column 'Account Name' contains invalid character(s): 'Agence Nationale des Fréquences'
# 🚨 Row 2167, Column 'Account Name' contains invalid character(s): 'France Médias Monde'
# 🚨 Row 2201, Column 'Account Name' contains invalid character(s): 'ETELÄ-POHJANMAAN SAIRAANHOITOPIIRIN KUNTAYHTYMÄ'

# %%
import pandas as pd
import csv
import re
import unicodedata

# ========= Load raw file robustly =========
in_path = "/Applications/WorkDataSets/Demandbase_techno.csv"
out_path = "/Applications/WorkDataSets/Demandbase_techno_F5_READY_FINAL.csv"

# Load file as raw text and repair column lengths
with open(in_path, 'r', encoding='utf-8-sig', errors='ignore') as f:
    sample = next(csv.reader(f))
    expected_cols = len(sample)

repaired = []
with open(in_path, 'r', encoding='utf-8-sig', errors='ignore') as f:
    reader = csv.reader(f)
    for row in reader:
        if len(row) > expected_cols:
            row = row[:expected_cols]
        elif len(row) < expected_cols:
            row += [""] * (expected_cols - len(row))
        repaired.append(row)

# Convert to DataFrame
df = pd.DataFrame(repaired[1:], columns=repaired[0])

# ========= Normalize Unicode to ASCII safely =========
def normalize_ascii(value):
    if pd.isna(value):
        return ""
    # Remove non-ASCII characters
    value = unicodedata.normalize('NFKD', str(value)).encode('ascii', 'ignore').decode('ascii')
    # Remove leftover control characters
    value = re.sub(r'[\x00-\x1F\x7F]+', ' ', value)
    # Strip extra whitespace
    return value.strip()

df = df.applymap(normalize_ascii)

# ========= Clean Column Names =========
df.columns = [
    re.sub(r'[^A-Za-z0-9_]+', '_', col.strip().lower()) or f"column_{i+1}"
    for i, col in enumerate(df.columns)
]

# ========= Clean Technographics Field =========
def split_technographics(text):
    text = text.strip().strip('|," ')
    # Replace pipes with commas
    items = [t.strip() for t in text.split('|') if t.strip()]
    return ", ".join(items)

if "technographics" in df.columns:
    df["technographics"] = df["technographics"].apply(split_technographics)

# ========= Escape commas only when needed =========
for col in df.columns:
    df[col] = df[col].apply(lambda v: f'"{v}"' if "," in v and not (v.startswith('"') and v.endswith('"')) else v)

# ========= Final Save =========
df.to_csv(out_path, index=False, encoding="utf-8-sig")
print("✅ CLEANED FILE READY:", out_path)
print("Preview:")
print(df.head(5).to_string())
# Out:
# /var/folders/9p/ktbdntkn6p388k364f6v6n500000gn/T/ipykernel_33729/2851910828.py:39: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(normalize_ascii)
# ✅ CLEANED FILE READY: /Applications/WorkDataSets/Demandbase_techno_F5_READY_FINAL.csv
# Preview:
#                        account_name         journey_stage engaged_known_people                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 0  ACCENTURE PUBLIC LIMITED COMPANY  Known Contact Action                    0  ".NET, .NET 5, .NET Framework, 100TB, 11:11 Systems, 123 Reg!, 1CRM, 1WorldSync, 360Plus, 3CX, 3CX Phone System, 3D CAD, 3D Systems, 3DEXPERIENCE Platform, 3Dexperience, 3Scale API Management, 3T Logistics, 3scale, 84.51 Insights, AB Initio Data Quality Environment, AB Tasty, ABAP, ABB 800xA, ABC Fitness Solutions, ABINIT, ACBS, ACCELQ, ACI Base24, ACI Base24-eps, ACI Worldwide, AD Fusion, ADManager Plus, ADP, ADP Celergo, ADP GlobalView, ADP HR, ADP Payroll, ADT Access Control, ADTRAN, ADVA Optical, AFS Analytics, AG Grid, AIMS Flight Operations Systems, ALFABET, ALIS, AMAZON ELASTIC CONTAINER SERVICE (ECS), AMC Technology, AMI, AMP, AMS Billing, AMS Insurance, ANSYS, AODocs, APS, ARGUS, ARGUS Enterprise, ARMIS, ASG Zeke, ASG-Cypress, ASM, ASP.NET, AT Internet, AT&T Global Network Client, AT&T IP Toll-Free, AT&T Managed Internet Service (MIS), AT&T Managed Threat Detection and Response Service, AT&T Network-Based IP Remote Access, ATG Web Commerce, ATIVA, ATT, AUTOSAR, AVEV InTouch HMI, AVEVA MES, AVEVA NET, AVEVA Operations Control, AVEVA PI System, AVEVA System Platform, AWS Amplify, AWS App Runner, AWS AppSync, AWS Auto Scaling, AWS Backup, AWS Batch, AWS Certificate Manager, AWS CloudFormation, AWS CloudTrail, AWS CodeBuild, AWS CodeCommit, AWS CodeDeploy, AWS CodePipeline, AWS Command Line Interface, AWS Control Tower, AWS Cost Explorer, AWS Data Lake Storage, AWS Database Migration Service, AWS Device Farm, AWS Direct Connect, AWS Elastic Beanstalk, AWS Fargate, AWS Global Accelerator, AWS Glue, AWS GovCloud, AWS IoT, AWS IoT Core, AWS IoT Greengrass, AWS IoT Things Graph, AWS Lake Formation, AWS Lambda, AWS Managed Services, AWS Marketplace, AWS Mobile Services, AWS Organizations, AWS Schema Conversion Tool, AWS Secrets Manager, AWS Security Hub, AWS Service Catalog, AWS Shield, AWS Snowball, AWS Step Functions, AWS Systems Manager, AWS Transit Gateway, AWS Trusted Advisor, AWS WAF, AYLIEN, AZURE DATA LAKE STORAGE, Ab Initio, Abacus, Aberdeen, Absorb LMS, Academy, Accenture Cloud Infrastructure Managed Services, Accenture myConcerto, Accruent FAMIS 360, Accurate Background, Achilles, Aconex, Acronis, Acronis Backup And Recovery, Actifio, ActionIQ, Activated Insights, Active 24 Hosting, Active Campaign, Active Risk, ActiveBatch Workload Automation, ActiveControl, Activevos, Actuate BIRT Spreadsheet, Acturis, Acumatica, Acumatica Distribution Edition, Acunetix, Ad Dynamo, AdEspresso, Addi, Address Intelligence, Adecco, Adledge, Adobe Acrobat, Adobe Acrobat DC, Adobe Acrobat Pro, Adobe Advertising DSP, Adobe After Effects, Adobe Analytics, Adobe Animate, Adobe Audience Manager, Adobe Campaign, Adobe Campaign Classic, Adobe Captivate, Adobe Character Animator CC, Adobe Commerce, Adobe Connect, Adobe Content Repository eXtreme, Adobe Creative Suite, Adobe Customer Journey Analytics, Adobe Discover, Adobe DreamWeaver, Adobe Edge, Adobe Experience Cloud, Adobe Experience Manager, Adobe Experience Manager Forms, Adobe Experience Manager Guides, Adobe Experience Manager Sites, Adobe Experience Manager as a Cloud Service, Adobe Express, Adobe FrameMaker, Adobe GenStudio, Adobe Illustrator, Adobe InDesign, Adobe Launch, Adobe Marketing Cloud, Adobe Marketo Engage, Adobe Photoshop, Adobe Portfolio, Adobe Premiere Pro, Adobe Real-Time CDP, Adobe RoboHelp, Adobe Sign, Adobe Target, Adobe Workfront, Adobe XD, Adsp, Adyen, Aerohive Networks, Aetna, Agency, Agent Image, Agile CRM, AgilePoint, Agility CMS, Agility Software, Agiloft, Ahrefs, Airtable, Aito, Akamai Content Delivery Network (Cdn), Akamai DNS, Akamai HD, Akamai Image & Video Manager, Akamai Rum, Akeneo, Alation, Alation Data Catalog, Albert.ai, Alcatel Lucent, Alertus, Alex Solutions, Alfresco Content Services, AlgoSec, Algolia, Algonomy, Alias Concept, Alibaba, Alibaba Cloud Container Service for Kubernetes (ACK), All Siemens PLM Products, AllegroServe, Allen-Bradley, Alliance Gateway, AlphaSSL ...
# 1                        Servicenow  Known Contact Action                   13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 2                   "Kyndryl, Inc."  Known Contact Action                    6                                                                        ".NET, .NET 5, .NET Framework, 123 Reg!, 1Password, 3D Systems, 3DEXPERIENCE Platform, 3Scale API Management, 3scale, 4project, 6sense, A10 Networks, AB Initio Data Quality Environment, ABAP, ABC Fitness Solutions, ABINIT, ACCELQ, ACI Worldwide, ACL Analytics, ACLS, AD Fusion, ADP, ADP Payroll, ADT Access Control, AG Grid, ALIS, AMD Radeon, AMO, AMP, AMS Insurance, ANSYS, ANSYS Fluent, ANSYS Icepak, ANTLR, AP Images, API Suite, APS, ARMIS, ASG-Cypress, ASG-TMON, ASM, ASP.NET, AT Internet, AT&T Global Network Client, AT&T IP Toll-Free, AT&T Managed Internet Service (MIS), AT&T Managed Threat Detection and Response Service, AT&T Network-Based IP Remote Access, ATIVA, ATT, AVADA, AVEVA PI System, AWS Amplify, AWS App Mesh, AWS App Runner, AWS Backup, AWS Batch, AWS Cloud9, AWS CloudFormation, AWS CloudTrail, AWS CodeBuild, AWS CodeCommit, AWS CodeDeploy, AWS CodePipeline, AWS CodeStar, AWS Config, AWS Control Tower, AWS Cost Explorer, AWS Data Lake Storage, AWS Database Migration Service, AWS Direct Connect, AWS Fargate, AWS Glue, AWS GovCloud, AWS Guardrails, AWS IoT, AWS Key Management Service, AWS Lake Formation, AWS Lambda, AWS Machine Learning, AWS Managed Services, AWS Marketplace, AWS Migration Hub, AWS Nitro System, AWS Organizations, AWS Secrets Manager, AWS Security Hub, AWS Service Catalog, AWS Shield, AWS Step Functions, AWS Systems Manager, AWS Trusted Advisor, AWS WAF, AZURE DATA LAKE STORAGE, Ab Initio, Abbott Instrument Manager, Abbott M2000 Realtime System, Absorb LMS, Accenture Cloud Infrastructure Managed Services, AccessData, Achilles, Acosta Group, Acoustic, Acquia, Acrolinx, Action Kit, ActivTrak, Activated Insights, Active 24, Active Dataguard, Active-X, ActiveControl, Activiti, Actuate BIRT Spreadsheet, Acunetix, Ad Dynamo, AdEspresso, AdImpact, Ada Support, AddThis, Adenza Group, Adobe Acrobat, Adobe Acrobat DC, Adobe Acrobat Pro, Adobe After Effects, Adobe Analytics, Adobe Audience Manager, Adobe Campaign, Adobe Campaign Classic, Adobe Captivate, Adobe Character Animator CC, Adobe Commerce, Adobe Content Repository eXtreme, Adobe Creative Suite, Adobe Customer Journey Analytics, Adobe DreamWeaver, Adobe Experience Cloud, Adobe Experience Manager, Adobe Experience Manager Forms, Adobe Experience Manager Guides, Adobe Experience Manager as a Cloud Service, Adobe Fonts, Adobe FrameMaker, Adobe GenStudio, Adobe Illustrator, Adobe InDesign, Adobe Journey Optimizer, Adobe Launch, Adobe Learning Manager, Adobe Marketing Cloud, Adobe Marketo Engage, Adobe Photoshop, Adobe Portfolio, Adobe Premiere Pro, Adobe Real-Time CDP, Adobe Sign, Adobe Target, Adobe Workfront, Adobe XD, Adstra, Adverity, Adversarial Robustness Toolbox, Aegir, Affinity Designer, Agency, Agile CRM, Agility CMS, Agility Software, Aha!, Ahrefs, Airbyte, Airtable, Akamai Bot Manager, Akamai Content Delivery Network (Cdn), Akamai DNS, Akamai Edge, Akamai HD, Akita, Alation, Alation Data Catalog, Albert.ai, Alchemer, Algolia, Alibaba, Alibaba Cloud, All Hours, All Siemens PLM Products, Alliance Gateway, Almond, AlphaSSL, Alteon Network Load Balancer, Alteryx, Altiris Asset Management Suite, Altium, Altium Designer, Amadeus, Amadeus Airline Platform, Amazon, Amazon API Gateway, Amazon AWS, Amazon AWS Identity And Access Management (IAM), Amazon Alexa, Amazon AppFlow, Amazon Athena, Amazon Aurora, Amazon CloudFront, Amazon CloudWatch, Amazon Comprehend, Amazon Connect, Amazon DynamoDB, Amazon EC2 Auto Scaling, Amazon EMR, Amazon ElastiCache, Amazon Elastic Container Service, Amazon Elastic File System (EFS), Amazon EventBridge, Amazon GuardDuty, Amazon Hosting, Amazon Inspector, Amazon Kendra, Amazon Kinesis, Amazon Kinesis Data Firehose, Amazon MSK, Amazon Machine Image, Amazon Macie, Amazon Polly, Amazon QuickSight, Amazon RDS for MySQL, Amazon Redshift, Amazon Relational Database Service (RDS), Amaz ...
# 3                         Arrow ECS  Known Contact Action                   99                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 4            "Salesforce.com, inc."  Known Contact Action                    1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ".NET, .NET Framework, 123 Reg!, 2Win!, ABAP, ADP, ADP GlobalView, ADP HRMS, ADP Payroll, ADP Streamline, AMC Technology, AMP, AMS Insurance, ANSYS, APS, ARGUS, ASG-Cypress, ASP.NET, AT&T Global Network Client, AT&T IP Toll-Free, AT&T Managed Internet Service (MIS), AT&T Managed Threat Detection and Response Service, AT&T Network-Based IP Remote Access, ATIVA, ATT, AWS App Runner, AWS AppSync, AWS Auto Scaling, AWS Certificate Manager, AWS CloudFormation, AWS CodeBuild, AWS CodeCommit, AWS CodePipelin ...
