# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt

df = pd.read_csv('/Applications/WorkDataSets/DataStore/Demandbase CDP 4.0/DemandbaseDataCDP2.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 477720 entries, 0 to 477719
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             477720 non-null  int64
#  1   Account Name           477720 non-null  object
#  2   First Name             5628 non-null    object
#  3   Last Name              5630 non-null    object
#  4   Title                  0 non-null       float64
#  5   Buying Role            3893 non-null    object
#  6   Type                   477720 non-null  object
#  7   Details                477720 non-null  object
#  8   Engagement Minutes     477720 non-null  float64
#  9   Activity Date          477720 non-null  object
#  10  Job Title              4042 non-null    object
#  11  Citrix Events Opt-Out  0 non-null       float64
#  12  Ispartner              5630 non-null    object
#  13  Account Number         0 non-null       float64
#  14  Party Number           5469 non-null    object
#  15  Territory              0 non-null       float64
#  16  Fatigue Level          5637 non-null    object
#  17  Party Name             0 non-null       float64
#  18  CustomerId_NAR         477720 non-null  object
#  19  source_file            477720 non-null  object
#  20  CustomerId_NAR_norm    477720 non-null  int64
# dtypes: float64(6), int64(2), object(13)
# memory usage: 76.5+ MB

# %%
df2 = pd.read_csv('/Applications/WorkDataSets/Most Recent Updates.csv')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18631 entries, 0 to 18630
# Data columns (total 8 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Account Territory Account Number / Name (AR)  18631 non-null  object
#  1   Account Territory Customer ID / Name          18631 non-null  object
#  2   Tech Plays Tech Play Category                 18631 non-null  object
#  3   Tech Plays Tech Play Type Label               18631 non-null  object
#  4   Tech Play Status History New Value            18631 non-null  object
#  5   Tech Play Status History Old Value            15171 non-null  object
#  6   Tech Play Status History Date Start Date      18631 non-null  object
#  7   Tech Play Status History Days In Status       18631 non-null  object
# dtypes: object(8)
# memory usage: 1.1+ MB

# %%
import pandas as pd
import re

# Step 1: Load both datasets fresh
print("=== STEP 1: Loading Datasets ===")
df = pd.read_csv('/Applications/WorkDataSets/DataStore/Demandbase CDP 4.0/DemandbaseDataCDP2.csv')
df2 = pd.read_csv('/Applications/WorkDataSets/Most Recent Updates.csv')

print(f"df (contacts): {df.shape}")
print(f"df2 (tech plays): {df2.shape}")

# Step 2: Find all F5 tech plays in df2
print("\n=== STEP 2: Finding F5 Tech Plays in df2 ===")

# Look for F5 in tech play columns
f5_plays = df2[
    (df2['Tech Plays Tech Play Type Label'].str.contains('F5', case=False, na=False)) |
    (df2['Tech Plays Tech Play Category'].str.contains('F5', case=False, na=False))
]

print(f"F5 tech play records found: {len(f5_plays)}")

# Step 3: Extract customer IDs from F5 plays  
print("\n=== STEP 3: Extracting Customer IDs from F5 Plays ===")

# Parse the Account Territory Customer ID / Name to get IDs
def extract_customer_id(account_string):
    if pd.isna(account_string):
        return None
    account_string = str(account_string).strip()
    # Pattern: H-CIT-[number] / [name]
    match = re.search(r'H-CIT-(\d+)', account_string)
    if match:
        return match.group(1)
    return None

f5_plays['Customer_ID'] = f5_plays['Account Territory Customer ID / Name'].apply(extract_customer_id)
f5_customer_ids = set(f5_plays['Customer_ID'].dropna())

print(f"Unique F5 customer IDs extracted: {len(f5_customer_ids)}")
print(f"Sample F5 customer IDs: {list(f5_customer_ids)[:10]}")

# Step 4: Find matching activities in df using those IDs
print("\n=== STEP 4: Finding Matching Activities in df ===")

# Parse Account Name in df to get customer IDs for matching
df['Customer_ID'] = df['Account Name'].apply(extract_customer_id)
df_customer_ids = set(df['Customer_ID'].dropna())

print(f"Customer IDs available in df: {len(df_customer_ids)}")

# Find matches
matching_ids = f5_customer_ids.intersection(df_customer_ids)
print(f"Matching customer IDs: {len(matching_ids)}")

if len(matching_ids) > 0:
    # Filter df for F5 account activities
    f5_activities = df[df['Customer_ID'].isin(matching_ids)]
    
    print(f"F5 account activities found: {len(f5_activities)}")
    print(f"Unique F5 accounts: {len(f5_activities['Account Name'].unique())}")
    
    # Show sample
    print(f"\nSample F5 activities:")
    sample_cols = ['Account Name', 'First Name', 'Last Name', 'Job Title']
    print(f5_activities[sample_cols].head(10))

else:
    print("No matching customer IDs found - let's check the formats...")
    print(f"Sample Account Names in df: {df['Account Name'].dropna().head(5).tolist()}")
    print(f"Sample Account Names in df2: {f5_plays['Account Territory Customer ID / Name'].dropna().head(5).tolist()}")
# Out:
# === STEP 1: Loading Datasets ===
# df (contacts): (477720, 21)
# df2 (tech plays): (18631, 8)
#
# === STEP 2: Finding F5 Tech Plays in df2 ===
# F5 tech play records found: 2651
#
# === STEP 3: Extracting Customer IDs from F5 Plays ===
# Unique F5 customer IDs extracted: 2293
# Sample F5 customer IDs: ['52036066', '45742293', '45311894', '45643196', '51409667', '25269600', '14160900', '51925419', '36977900', '50478071']
#
# === STEP 4: Finding Matching Activities in df ===
# Customer IDs available in df: 0
# Matching customer IDs: 0
# No matching customer IDs found - let's check the formats...
# Sample Account Names in df: ['Defense Logistics Agency', 'State Street Bank & Trust', 'Retail Business Services, LLC', 'The Christ Hospital', 'SoCura GmbH EU']
# Sample Account Names in df2: ["H-CIT-46557659 / The Queen's Health Systems", 'H-CIT-39861700 / DNB Nor ASA', 'H-CIT-45612028 / Fred Hutchinson Cancer Center', 'H-CIT-48365577 / Bundesagentur für Arbeit', "H-CIT-45203307 / Seattle Children's Healthcare System"]
# /var/folders/9p/ktbdntkn6p388k364f6v6n500000gn/T/ipykernel_52401/2610062480.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f5_plays['Customer_ID'] = f5_plays['Account Territory Customer ID / Name'].apply(extract_customer_id)

# %%
# Step 3 (Fixed): Parse BOTH account columns in df2 to extract customer IDs
print("\n=== STEP 3 (FIXED): Parsing Both Account Columns in df2 ===")

def extract_customer_id_enhanced(account_string):
    if pd.isna(account_string):
        return None
    account_string = str(account_string).strip()
    # Pattern: H-CIT-[number] / [name] or just [number]
    match = re.search(r'H-CIT-(\d+)', account_string)
    if match:
        return match.group(1)
    # Try to find standalone numbers
    match = re.search(r'(\d{7,})', account_string)  # 7+ digits
    if match:
        return match.group(1)
    return None

# Parse both account columns
print("Parsing 'Account Territory Account Number / Name (AR)'...")
f5_plays['Customer_ID_Col0'] = f5_plays['Account Territory Account Number / Name (AR)'].apply(extract_customer_id_enhanced)

print("Parsing 'Account Territory Customer ID / Name'...")  
f5_plays['Customer_ID_Col1'] = f5_plays['Account Territory Customer ID / Name'].apply(extract_customer_id_enhanced)

# Combine IDs from both columns
all_f5_ids = set()
all_f5_ids.update(f5_plays['Customer_ID_Col0'].dropna())
all_f5_ids.update(f5_plays['Customer_ID_Col1'].dropna())

print(f"Total unique F5 customer IDs from both columns: {len(all_f5_ids)}")
print(f"Sample combined F5 customer IDs: {list(all_f5_ids)[:10]}")

# Step 4 (Updated): Check df formats and try multiple matching approaches
print("\n=== STEP 4 (UPDATED): Enhanced Matching with df ===")

# Check what format df Account Names have
print("Sample Account Names in df:")
sample_df_accounts = df['Account Name'].dropna().head(10)
for i, name in enumerate(sample_df_accounts):
    print(f"  {i}: {name}")

# Try multiple parsing approaches for df
df['Customer_ID_Method1'] = df['Account Name'].apply(extract_customer_id_enhanced)

# Also try parsing any numeric codes that might be embedded
def find_any_numeric_id(text):
    if pd.isna(text):
        return None
    # Look for any sequence of 7+ digits
    matches = re.findall(r'\d{7,}', str(text))
    return matches[0] if matches else None

df['Customer_ID_Method2'] = df['Account Name'].apply(find_any_numeric_id)

# Check what we got
method1_ids = set(df['Customer_ID_Method1'].dropna())
method2_ids = set(df['Customer_ID_Method2'].dropna())

print(f"Customer IDs found in df (Method 1): {len(method1_ids)}")
print(f"Customer IDs found in df (Method 2): {len(method2_ids)}")

# Try matching with both methods
matches1 = all_f5_ids.intersection(method1_ids)
matches2 = all_f5_ids.intersection(method2_ids)

print(f"Matches with Method 1: {len(matches1)}")
print(f"Matches with Method 2: {len(matches2)}")

all_matches = matches1.union(matches2)
print(f"Total unique matches: {len(all_matches)}")

if len(all_matches) > 0:
    print(f"Sample matching IDs: {list(all_matches)[:10]}")
    
    # Get F5 activities using all matching methods
    f5_activities = df[
        (df['Customer_ID_Method1'].isin(all_matches)) |
        (df['Customer_ID_Method2'].isin(all_matches))
    ]
    
    print(f"\nF5 account activities found: {len(f5_activities)}")
    
else:
    print("Still no matches. Let's examine the data more closely...")
    print(f"\nF5 IDs sample: {list(all_f5_ids)[:5]}")
    print(f"DF Method1 IDs sample: {list(method1_ids)[:5] if method1_ids else 'None'}")
    print(f"DF Method2 IDs sample: {list(method2_ids)[:5] if method2_ids else 'None'}")
# Out:
# === STEP 3 (FIXED): Parsing Both Account Columns in df2 ===
# Parsing 'Account Territory Account Number / Name (AR)'...
# Parsing 'Account Territory Customer ID / Name'...
# Total unique F5 customer IDs from both columns: 2621
# Sample combined F5 customer IDs: ['52036066', '45742293', '45311894', '45643196', '48142562', '51409667', '25269600', '14160900', '51925419', '36977900']
#
# === STEP 4 (UPDATED): Enhanced Matching with df ===
# Sample Account Names in df:
#   0: Defense Logistics Agency
#   1: State Street Bank & Trust
#   2: Retail Business Services, LLC
#   3: The Christ Hospital
#   4: SoCura GmbH EU
#   5: State Street Bank & Trust
#   6: CDW Corporation
#   7: Defense Logistics Agency
#   8: Defense Logistics Agency
#   9: The Christ Hospital
# /var/folders/9p/ktbdntkn6p388k364f6v6n500000gn/T/ipykernel_52401/2392707198.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f5_plays['Customer_ID_Col0'] = f5_plays['Account Territory Account Number / Name (AR)'].apply(extract_customer_id_enhanced)
# /var/folders/9p/ktbdntkn6p388k364f6v6n500000gn/T/ipykernel_52401/2392707198.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f5_plays['Customer_ID_Col1'] = f5_plays['Account Territory Customer ID / Name'].apply(extract_customer_id_enhanced)
# Customer IDs found in df (Method 1): 0
# Customer IDs found in df (Method 2): 0
# Matches with Method 1: 0
# Matches with Method 2: 0
# Total unique matches: 0
# Still no matches. Let's examine the data more closely...
#
# F5 IDs sample: ['52036066', '45742293', '45311894', '45643196', '48142562']
# DF Method1 IDs sample: None
# DF Method2 IDs sample: None

# %%
# Step 4 (FIXED): Normalize account numbers in df dataset
print("\n=== STEP 4 (FIXED): Finding and Normalizing Account Numbers in df ===")

# Check all columns in df that might contain account numbers
print("Checking all columns in df for potential account numbers...")
potential_id_columns = []

for col in df.columns:
    if any(keyword in col.lower() for keyword in ['account', 'number', 'id', 'customer']):
        potential_id_columns.append(col)

print(f"Potential ID columns in df: {potential_id_columns}")

# Function to normalize account numbers (remove letters, dashes, keep only digits)
def normalize_account_number(text):
    if pd.isna(text):
        return None
    # Convert to string and remove all non-digits
    normalized = re.sub(r'[^\d]', '', str(text))
    # Return only if it's a reasonable length (6+ digits)
    return normalized if len(normalized) >= 6 else None

# Apply normalization to potential ID columns
normalized_ids = set()

for col in potential_id_columns:
    print(f"\nChecking column: {col}")
    if col in df.columns:
        # Show sample values
        sample_vals = df[col].dropna().head(10)
        print(f"  Sample values: {sample_vals.tolist()}")
        
        # Normalize
        df[f'{col}_normalized'] = df[col].apply(normalize_account_number)
        col_ids = set(df[f'{col}_normalized'].dropna())
        
        print(f"  Normalized IDs found: {len(col_ids)}")
        if col_ids:
            print(f"  Sample normalized: {list(col_ids)[:5]}")
            normalized_ids.update(col_ids)

print(f"\nTotal normalized IDs from df: {len(normalized_ids)}")

# Also check if there are any embedded numbers in Account Name
print(f"\nAlso checking for embedded numbers in Account Name...")
df['Account_Name_numbers'] = df['Account Name'].apply(normalize_account_number)
account_name_ids = set(df['Account_Name_numbers'].dropna())
print(f"IDs from Account Name: {len(account_name_ids)}")

# Combine all normalized IDs
all_df_ids = normalized_ids.union(account_name_ids)
print(f"Total unique normalized IDs in df: {len(all_df_ids)}")

# Now try matching with F5 IDs
print(f"\n=== MATCHING ===")
print(f"F5 IDs: {len(all_f5_ids)}")
print(f"DF normalized IDs: {len(all_df_ids)}")

matches = all_f5_ids.intersection(all_df_ids)
print(f"MATCHES FOUND: {len(matches)}")

if len(matches) > 0:
    print(f"Matching IDs: {list(matches)}")
    
    # Find F5 activities
    mask = pd.Series(False, index=df.index)
    for col in df.columns:
        if col.endswith('_normalized'):
            mask = mask | df[col].isin(matches)
    
    f5_activities = df[mask]
    
    print(f"\n✅ SUCCESS!")
    print(f"F5 account activities found: {len(f5_activities)}")
    print(f"Unique accounts: {len(f5_activities['Account Name'].unique())}")
    
    # Show sample
    sample_cols = ['Account Name', 'First Name', 'Last Name', 'Job Title']
    available_cols = [col for col in sample_cols if col in f5_activities.columns]
    print(f"\nSample F5 activities:")
    print(f5_activities[available_cols].head(10))
    
else:
    print("Still no matches after normalization")
    print(f"F5 sample: {list(all_f5_ids)[:5]}")
    print(f"DF sample: {list(all_df_ids)[:5] if all_df_ids else 'No normalized IDs found'}")
# Out:
# === STEP 4 (FIXED): Finding and Normalizing Account Numbers in df ===
# Checking all columns in df for potential account numbers...
# Potential ID columns in df: ['Account Name', 'Account Number', 'Party Number', 'CustomerId_NAR', 'CustomerId_NAR_norm', 'Customer_ID', 'Customer_ID_Method1', 'Customer_ID_Method2']
#
# Checking column: Account Name
#   Sample values: ['Defense Logistics Agency', 'State Street Bank & Trust', 'Retail Business Services, LLC', 'The Christ Hospital', 'SoCura GmbH EU', 'State Street Bank & Trust', 'CDW Corporation', 'Defense Logistics Agency', 'Defense Logistics Agency', 'The Christ Hospital']
#   Normalized IDs found: 0
#
# Checking column: Account Number
#   Sample values: []
#   Normalized IDs found: 0
#
# Checking column: Party Number
#   Sample values: ['P_0034z00003G8kUFAAZ', 'P_0034z00002wuvMWAAY', 'P_0034z00003GAwNoAAL', 'P_003600000286zciAAA', 'P_0034z00002ocozdAAA', 'P_0034z00002wuvMWAAY', 'P_0034z00003G9mwkAAB', 'P_0034z00003G8kUFAAZ', 'P_0034z00003G8kUFAAZ', 'P_0034z00002gr2fHAAQ']
#   Normalized IDs found: 333
#   Sample normalized: ['1000039945', '00340000377', '00360000017', '463910', '465807']
#
# Checking column: CustomerId_NAR
#   Sample values: ['H-CIT-52486027', 'H-CIT-45791385', 'H-CIT-45178234', 'H-CIT-16480400', 'H-CIT-52661623', 'H-CIT-45791385', 'H-CIT-40690200', 'H-CIT-52486027', 'H-CIT-52486027', 'H-CIT-16480400']
#   Normalized IDs found: 428
#   Sample normalized: ['45546387', '46006693', '45643196', '49798157', '36977900']
#
# Checking column: CustomerId_NAR_norm
#   Sample values: [52486027, 45791385, 45178234, 16480400, 52661623, 45791385, 40690200, 52486027, 52486027, 16480400]
#   Normalized IDs found: 428
#   Sample normalized: ['45546387', '46006693', '45643196', '49798157', '36977900']
#
# Checking column: Customer_ID
#   Sample values: []
#   Normalized IDs found: 0
#
# Checking column: Customer_ID_Method1
#   Sample values: []
#   Normalized IDs found: 0
#
# Checking column: Customer_ID_Method2
#   Sample values: []
#   Normalized IDs found: 0
#
# Total normalized IDs from df: 761
#
# Also checking for embedded numbers in Account Name...
# IDs from Account Name: 0
# Total unique normalized IDs in df: 761
#
# === MATCHING ===
# F5 IDs: 2621
# DF normalized IDs: 761
# MATCHES FOUND: 425
# Matching IDs: ['45546387', '46006693', '45643196', '49798157', '36977900', '45339641', '45763022', '45879462', '50047425', '46894680', '45742823', '45178234', '45434248', '45485361', '16561500', '48774819', '45802553', '24729900', '20807800', '47224946', '45183963', '45766521', '40827800', '45796028', '46443142', '45223674', '48764053', '46072124', '45657167', '52486027', '45202259', '47212206', '38849700', '50817788', '45999113', '36853200', '46859623', '50157373', '51684406', '45802860', '45356397', '16480400', '45407326', '47576308', '12476500', '45757038', '110108', '51324770', '52444117', '51957245', '45761696', '49749902', '18295600', '45468407', '45888722', '45908789', '45966610', '45250108', '50966899', '50281459', '45139618', '52069707', '50501675', '49468198', '45924870', '119097', '45641266', '45592683', '51255761', '45967656', '45616792', '45256560', '
# 6                CDW Corporation     Rakesh   Nimmala               NaN
# 7       Defense Logistics Agency    Gregory  Bozovich             Buyer
# 8       Defense Logistics Agency    Gregory  Bozovich             Buyer
# 9            The Christ Hospital      Jason    Begley  Network Engineer

# %%
# Extract all normalized IDs from df
print("=== EXTRACTING ALL NORMALIZED IDs FROM df ===")

# Combine all normalized ID sets
all_df_normalized_ids = set()

# From Party Number (normalized)
party_ids = set(df['Party Number_normalized'].dropna())
print(f"Party Number normalized IDs: {len(party_ids)}")

# From CustomerId_NAR (normalized) 
customer_nar_ids = set(df['CustomerId_NAR_normalized'].dropna())
print(f"CustomerId_NAR normalized IDs: {len(customer_nar_ids)}")

# From CustomerId_NAR_norm (already clean)
customer_nar_norm_ids = set(df['CustomerId_NAR_norm'].dropna().astype(str))
print(f"CustomerId_NAR_norm IDs: {len(customer_nar_norm_ids)}")

# Combine all
all_df_normalized_ids = party_ids.union(customer_nar_ids).union(customer_nar_norm_ids)
print(f"Total unique normalized IDs in df: {len(all_df_normalized_ids)}")

# Now match with F5 IDs
print(f"\n=== MATCHING F5 IDs WITH df IDs ===")
print(f"F5 customer IDs: {len(all_f5_ids)}")
print(f"DF normalized IDs: {len(all_df_normalized_ids)}")

# Convert F5 IDs to string for consistent matching
all_f5_ids_str = {str(id) for id in all_f5_ids}

matches = all_f5_ids_str.intersection(all_df_normalized_ids)
print(f"🎯 MATCHES FOUND: {len(matches)}")

if len(matches) > 0:
    print(f"Matching IDs: {sorted(list(matches))}")
    
    # Create filter mask for F5 activities
    f5_mask = (
        (df['Party Number_normalized'].isin(matches)) |
        (df['CustomerId_NAR_normalized'].isin(matches)) |
        (df['CustomerId_NAR_norm'].astype(str).isin(matches))
    )
    
    f5_activities = df[f5_mask]
    
    print(f"\n✅ SUCCESS! F5 COMPETITIVE OPPORTUNITIES FOUND!")
    print(f"F5 account activities: {len(f5_activities)}")
    print(f"Unique F5 accounts: {len(f5_activities['Account Name'].unique())}")
    
    # Filter for records with contact names
    f5_contacts = f5_activities[
        (f5_activities['First Name'].notna()) & 
        (f5_activities['Last Name'].notna()) &
        (f5_activities['First Name'] != '') & 
        (f5_activities['Last Name'] != '')
    ]
    
    print(f"F5 activities with contact names: {len(f5_contacts)}")
    
    # Save the results
    output_dir = '/Applications/WorkDataSets/DataStore/'
    import os
    os.makedirs(output_dir, exist_ok=True)
    
    filename = 'F5_competitive_opportunities_FINAL.csv'
    filepath = os.path.join(output_dir, filename)
    f5_contacts.to_csv(filepath, index=False)
    
    print(f"\n📁 Saved: {filename}")
    print(f"📊 Records: {len(f5_contacts)}")
    print(f"🏢 Organizations: {len(f5_contacts['Account Name'].unique())}")
    
    # Show sample
    sample_cols = ['Account Name', 'First Name', 'Last Name', 'Job Title', 'Buying Role']
    print(f"\n👤 Sample F5 competitive contacts:")
    print(f5_contacts[sample_cols].head(10))
    
    # Show top accounts
    print(f"\n🏢 Top F5 accounts by activity:")
    print(f5_contacts['Account Name'].value_counts().head(15))

else:
    print("No matches found")
    print(f"F5 sample: {list(all_f5_ids_str)[:10]}")
817', '47212206', '47224946', '47235483', '47274475', '47286035', '47308365', '47346861', '47349908', '47371909', '47380555', '47404552', '47424042', '47470544', '47472730', '47484565', '47520398', '47576308', '47620302', '47622638', '47625838', '47630449', '47648993', '47672665', '47672922', '47694678', '47702324', '47728516', '47730718', '47869204', '47922426', '48083519', '48120080', '48124150', '48157481', '48161480', '48365577', '48376211', '48426406', '48440121', '48603740', '48647934', '48693436', '48700548', '48736771', '48764053', '48774819', '48807053', '48883823', '48923690', '48949565', '49002288', '49074728', '49076819', '49141050', '49196500', '49270231', '49276656', '49442358', '49456011', '49468198', '494945 ...
#
# ✅ SUCCESS! F5 COMPETITIVE OPPORTUNITIES FOUND!
# F5 account activities: 448275
# Unique F5 accounts: 453
# F5 activities with contact names: 5620
#
# 📁 Saved: F5_competitive_opportunities_FINAL.csv
# 📊 Records: 5620
# 🏢 Organizations: 240
#
# 👤 Sample F5 competitive contacts:
#                     Account Name First Name Last Name         Job Title  \
# 0       Defense Logistics Agency    Gregory  Bozovich             Buyer
# 1      State Street Bank & Trust     Anurag     Gupta               NaN
# 2  Retail Business Services, LLC    Bhaskar       Rao               NaN
# 3            The Christ Hospital      Brian    Daniel               CTO
# 4                 SoCura GmbH EU    Michael     Hundt               NaN
# 5      State Street Bank & Trust     Anurag     Gupta               NaN
# 6                CDW Corporation     Rakesh   Nimmala               NaN
# 7       Defense Logistics Agency    Gregory  Bozovich             Buyer
# 8       Defense Logistics Agency    Gregory  Bozovich             Buyer
# 9            The Christ Hospital      Jason    Begley  Network Engineer
#
#             Buying Role
# 0           PROCUREMENT
# 1                   NaN
# 2                   NaN
# 3                   CIO
# 4      DEVOPS_TECHNICAL
# 5                   NaN
# 6                   NaN
# 7           PROCUREMENT
# 8           PROCUREMENT
# 9  NETWORKING_TECHNICAL
#
# 🏢 Top F5 accounts by activity:
# Account Name
# Defense Logistics Agency                         1255
# The Christ Hospital                               938
# State Street Bank & Trust                         198
# Benevis LLC                                       161
# IT-Dienstleistungszentrum Berlin                  136
# Banco Bilbao Vizcaya Argentaria S.A.               94
# Genpact India Pvt. Ltd                             89
# COMPUTACENTER PLC                                  87
# Kyndryl/Care New England                           87
# John Muir Medical Center                           86
# AstraZeneca UK Non- R & D                          63
# Airbus Canada Limited Partnership                  61
# City of Toronto                                    57
# PSNI                                               53
# General Dynamics Information Technology, Inc.      44
# Name: count, dtype: int64

# %%
# Get F5 stage information from the original tech plays
print("=== F5 ACCOUNT STAGES ANALYSIS ===")

# Show what stage/status columns we have in f5_plays
stage_columns = [col for col in f5_plays.columns if 'status' in col.lower() or 'stage' in col.lower()]
print(f"Stage/Status columns available: {stage_columns}")

# Look at the current status values
if 'Tech Play Status History New Value' in f5_plays.columns:
    current_statuses = f5_plays['Tech Play Status History New Value'].value_counts()
    print(f"\n📊 Current F5 Account Stages:")
    print(current_statuses)

# Get organization names and their stages
f5_accounts_with_stages = f5_plays[[
    'Account Territory Customer ID / Name',
    'Customer_ID_Col0', 'Customer_ID_Col1',
    'Tech Plays Tech Play Category',
    'Tech Plays Tech Play Type Label',
    'Tech Play Status History New Value',
    'Tech Play Status History Old Value'
]].copy()

# Parse organization names from the account territory field
def extract_org_name(account_string):
    if pd.isna(account_string):
        return None
    account_string = str(account_string).strip()
    # Pattern: H-CIT-[number] / [organization name]
    match = re.search(r'H-CIT-\d+\s*/\s*(.+)', account_string)
    if match:
        return match.group(1).strip()
    return account_string

f5_accounts_with_stages['Organization_Name'] = f5_accounts_with_stages['Account Territory Customer ID / Name'].apply(extract_org_name)

# Show stages by organization
print(f"\n🏢 F5 Account Stages by Organization:")
stage_summary = f5_accounts_with_stages.groupby(['Organization_Name', 'Tech Play Status History New Value']).size().unstack(fill_value=0)
print(stage_summary.head(15))

# Create a summary of accounts by stage
print(f"\n📋 F5 Accounts Summary by Stage:")
stage_counts = f5_accounts_with_stages.groupby('Tech Play Status History New Value')['Organization_Name'].nunique()
print(stage_counts)

# Save the stage information
output_dir = '/Applications/WorkDataSets/DataSets/DataStore/'
stage_filename = 'F5_accounts_by_stage.csv'
stage_filepath = os.path.join(output_dir, stage_filename)

f5_accounts_with_stages.to_csv(stage_filepath, index=False)

print(f"\n💾 Saved F5 account stage information:")
print(f"📁 Filename: {stage_filename}")
print(f"📊 Records: {len(f5_accounts_with_stages)}")

# Show sample of stages
print(f"\n📋 Sample F5 account stages:")
sample_cols = ['Organization_Name', 'Tech Plays Tech Play Type Label', 'Tech Play Status History New Value']
print(f5_accounts_with_stages[sample_cols].drop_duplicates().head(15))

# Create a master list of F5 accounts with stage and contact count
print(f"\n🎯 Master F5 Account List with Stages and Contact Counts:")

# Get contact counts per account from our F5 activities
f5_contact_counts = f5_contacts['Account Name'].value_counts()

# Match organizations between datasets and create summary
f5_master_list = []
for org in f5_accounts_with_stages['Organization_Name'].unique():
    if pd.notna(org):
        # Get stage for this org
        org_stages = f5_accounts_with_stages[f5_accounts_with_stages['Organization_Name'] == org]['Tech Play Status History New Value'].unique()
        stage = ', '.join([str(s) for s in org_stages if pd.notna(s)])
        
        # Get contact count (try exact match first, then partial)
        contact_count = 0
        if org in f5_contact_counts:
            contact_count = f5_contact_counts[org]
        else:
            # Try partial matching
            for account_name in f5_contact_counts.index:
                if org.lower() in account_name.lower() or account_name.lower() in org.lower():
                    contact_count += f5_contact_counts[account_name]
        
        f5_master_list.append({
            'Organization': org,
            'Stage': stage,
            'Contact_Count': contact_count,
            'Has_Contacts': 'Yes' if contact_count > 0 else 'No'
        })

# Convert to DataFrame and save
f5_master_df = pd.DataFrame(f5_master_list)
f5_master_df = f5_master_df.sort_values('Contact_Count', ascending=False)

master_filename = 'F5_master_account_list_with_stages.csv'
master_filepath = os.path.join(output_dir, master_filename)
f5_master_df.to_csv(master_filepath, index=False)

print(f"\n💾 Saved F5 Master Account List:")
print(f"📁 Filename: {master_filename}")
print(f"📊 Organizations: {len(f5_master_df)}")

print(f"\n🏆 Top F5 Opportunities (with contacts and stages):")
print(f5_master_df[f5_master_df['Contact_Count'] > 0].head(20))
# Out:
# === F5 ACCOUNT STAGES ANALYSIS ===
# Organization_Name
# 1199 Seiu League Training and Upgrading Fund                              0
# 2M-IT                                                                     0
# 3M Corporation                                                            0
# 50Hertz Transmission                                                      0
# 888 Holdings                                                              0
# A-45370165 / Harris Williams and Company                                  0
# A-45779555 / AXEMBLE GROUP                                                0
# A-45940676 / match.com international ltd                                  0
# A-46863192 / ISRO Satellite Centre                                        0
# A-50342386 / Connectria Hosting                                           0
# A-50420611 / Enfo Zipper AB                                               0
# A-50594902 / Q8 Italia                                                    0
# A-50915834 / Techgate plc                                                 0
# A-51103789 / QUICKTHINK CLOUD LTD                                         0
# A-51131153 / Serit It Partner Møre AS                                     0
#
# Tech Play Status History New Value            Rejected - Solution Failure
# Organization_Name
# 1199 Seiu League Training and Upgrading Fund                            0
# 2M-IT                                                                   0
# 3M Corporation                                                          0
# 50Hertz Transmission                                                    0
# 888 Holdings                                                            0
# A-45370165 / Harris Williams and Company                                0
# A-45779555 / AXEMBLE GROUP                                              0
# A-45940676 / match.com international ltd                                0
# A-46863192 / ISRO Satellite Centre                                      0
# A-50342386 / Connectria Hosting                                         0
# A-50420611 / Enfo Zipper AB                                             0
# A-50594902 / Q8 Italia                                                  0
# A-50915834 / Techgate plc                                               0
# A-51103789 / QUICKTHINK CLOUD LTD                                       0
# A-51131153 / Serit It Partner Møre AS                                   0
#
# 📋 F5 Accounts Summary by Stage:
# Tech Play Status History New Value
# Customer - Deferred to Sy26       170
# Customer Deferred to SY26         106
# Initial Adoption                   37
# Mass Rollout                       25
# Non-Dispositioned                 221
# On-Hold - Need Exec Engagement     78
# On-Hold - Waiting on RFE            2
# Play does not Apply               771
# Presentation                      164
# Proof of Concept                   34
# Qualification                     541
# Rejected                           59
# Rejected - Customer Rejection     330
# Rejected - Solution Failure         8
# Name: Organization_Name, dtype: int64
#
# 💾 Saved F5 account stage information:
# 📁 Filename: F5_accounts_by_stage.csv
# 📊 Records: 2651
#
# 📋 Sample F5 account stages:
#                              Organization_Name  \
# 7                   The Queen's Health Systems
# 11                                 DNB Nor ASA
# 17               Fred Hutchinson Cancer Center
# 28                    Bundesagentur für Arbeit
# 33        Seattle Children's Healthcare System
# 44                      Hawai`i Pacific Health
# 53                                  AIMS, INC.
# 54                 Cook County Burea of Health
# 62                  Simpson Thacher & Bartlett
# 69                                 Swiss Re AG
# 105                         Jacobs Engineering
# 134                              Salling Group
# 139                       Fidelity Investments
# 155                            Dominion Energy
# 163  General Dynamics - Aerospace - Gulfstream
#
#     Tech Plays Tech Play Type Label Tech Play Status History New Value
# 7                  Takeout - F5/ADC        Customer - Deferred to Sy26
# 11                 Takeout - F5/ADC      Rejected - Customer Rejection
# 17                 Takeout - F5/ADC      Rejected - Customer Rejection
# 28                 Takeout - F5/ADC                Play does not Apply
# 33                 Takeout - F5/ADC                       Presentation
# 44                 Takeout - F5/ADC                Play does not Apply
# 53                 Takeout - F5/ADC                Play does not Apply
# 54                 Takeout - F5/ADC                Play does not Apply
# 62                 Takeout - F5/ADC                       Presentation
# 69                 Takeout - F5/ADC     On-Hold - Need Exec Engagement
# 105                Takeout - F5/ADC        Customer - Deferred to Sy26
# 134                Takeout - F5/ADC        Customer - Deferred to Sy26
# 139                Takeout - F5/ADC                  Non-Dispositioned
# 155                Takeout - F5/ADC      Rejected - Customer Rejection
# 163                Takeout - F5/ADC        Customer - Deferred to Sy26
#
# 🎯 Master F5 Account List with Stages and Contact Counts:
#
# 💾 Saved F5 Master Account List:
# 📁 Filename: F5_master_account_list_with_stages.csv
# 📊 Organizations: 2386
#
# 🏆 Top F5 Opportunities (with contacts and stages):
#                               Organization                           Stage  \
# 1516  DLA - Defense Logistics Agency (DLA)                   Qualification
# 216                    The Christ Hospital     Customer - Deferred to Sy26
# 388                 Genpact India Pvt. Ltd             Play does not Apply
# 96                       COMPUTACENTER PLC   Rejected - Customer Rejection
# 1425              John Muir Medical Center       Customer Deferred to SY26
# 2202                           AstraZeneca                    Presentation
# 193      Airbus Canada Limited Partnership     Customer - Deferred to Sy26
# 1600       CAN - Toronto - City of Toronto                   Qualification
# 236                                   PSNI  On-Hold - Need Exec Engagement
# 2265                                   ITV                   Qualification
# 611                       Statens Vegvesen     Customer - Deferred to Sy26
# 219                   First Merchants Bank     Customer - Deferred to Sy26
# 540                                  Roche     Customer - Deferred to Sy26
# 1730                       CDW Corporation   Rejected - Customer Rejection
# 353                               Vodafone  On-Hold - Need Exec Engagement
# 155         Sisters of Mercy Health System                    Presentation
# 830     TMF SERVICES INDIA PRIVATE LIMITED                   Qualification
# 1732                               Nemours             Play does not Apply
# 1023                           Capital One  On-Hold - Need Exec Engagement
# 836       New Residential Investment Corp.                    Presentation
#
#       Contact_Count Has_Contacts
# 1516           1255          Yes
# 216             938          Yes
# 388              89          Yes
# 96               87          Yes
# 1425             86          Yes
# 2202             63          Yes
# 193              61          Yes
# 1600             57          Yes
# 236              53          Yes
# 2265             44          Yes
# 611              44          Yes
# 219              41          Yes
# 540              41          Yes
# 1730             40          Yes
# 353              37          Yes
# 155              37          Yes
# 830              34          Yes
# 1732             33          Yes
# 1023             32          Yes
# 836              30          Yes

# %%
# Create Account Name + Stage mapping
print("=== F5 ACCOUNT NAMES WITH THEIR STAGES ===")

# Get unique F5 account names from our contacts dataset
f5_account_names = f5_contacts['Account Name'].unique()
print(f"F5 accounts with contacts: {len(f5_account_names)}")

# Create mapping of account name to stage
account_stage_mapping = {}

for account_name in f5_account_names:
    # Try to find matching organization in the stage data
    account_stage = "Stage Unknown"
    
    # First try exact match
    matching_orgs = f5_accounts_with_stages[
        f5_accounts_with_stages['Organization_Name'] == account_name
    ]
    
    # If no exact match, try partial matching
    if len(matching_orgs) == 0:
        for org_name in f5_accounts_with_stages['Organization_Name'].dropna():
            if (account_name.lower() in org_name.lower()) or (org_name.lower() in account_name.lower()):
                matching_orgs = f5_accounts_with_stages[
                    f5_accounts_with_stages['Organization_Name'] == org_name
                ]
                break
    
    # Get the stage
    if len(matching_orgs) > 0:
        stages = matching_orgs['Tech Play Status History New Value'].dropna().unique()
        if len(stages) > 0:
            account_stage = ', '.join([str(s) for s in stages])
    
    account_stage_mapping[account_name] = account_stage

# Create clean output
print(f"\n📋 F5 ACCOUNT NAMES AND THEIR STAGES:")
print("-" * 100)
print(f"{'ACCOUNT NAME':<50} | {'STAGE':<30} | {'CONTACTS'}")
print("-" * 100)

# Get contact counts
contact_counts = f5_contacts['Account Name'].value_counts()

for account_name in sorted(account_stage_mapping.keys()):
    stage = account_stage_mapping[account_name]
    contact_count = contact_counts.get(account_name, 0)
    print(f"{account_name:<50} | {stage:<30} | {contact_count}")

# Also create a DataFrame for easy export
account_stage_df = pd.DataFrame([
    {
        'Account_Name': account_name,
        'Stage': stage,
        'Contact_Count': contact_counts.get(account_name, 0)
    }
    for account_name, stage in account_stage_mapping.items()
])

# Sort by contact count (highest first)
account_stage_df = account_stage_df.sort_values('Contact_Count', ascending=False)

# Save it
output_dir = '/Applications/WorkDataSets/DataSets/DataStore/'
stage_mapping_filename = 'F5_account_names_with_stages.csv'
stage_mapping_filepath = os.path.join(output_dir, stage_mapping_filename)

account_stage_df.to_csv(stage_mapping_filepath, index=False)

print(f"\n💾 Saved account-stage mapping:")
print(f"📁 Filename: {stage_mapping_filename}")
print(f"📊 Accounts: {len(account_stage_df)}")

# Show summary by stage
print(f"\n📊 SUMMARY BY STAGE:")
stage_summary = account_stage_df['Stage'].value_counts()
for stage, count in stage_summary.items():
    print(f"{stage}: {count} accounts")

print(f"\n🏆 TOP F5 ACCOUNTS (by contact count):")
print(account_stage_df.head(15).to_string(index=False))
# Out:
# === F5 ACCOUNT NAMES WITH THEIR STAGES ===
# F5 accounts with contacts: 240
#
# 📋 F5 ACCOUNT NAMES AND THEIR STAGES:
# ----------------------------------------------------------------------------------------------------
# ACCOUNT NAME                                       | STAGE                          | CONTACTS
# ----------------------------------------------------------------------------------------------------
# 3M Company                                         | Stage Unknown                  | 28
# 50Hertz Transmission GmbH                          | Presentation                   | 7
# ADT US                                             | Play does not Apply            | 14
# AMAP : Association de Moyens Assurance des Personnes | Stage Unknown                  | 4
# AbbVie Inc                                         | Rejected - Customer Rejection  | 10
# Abbott Laboratories                                | Stage Unknown                  | 12
# Adani Enterprises Ltd.                             | Stage Unknown                  | 2
# Administrative Offices of the Pennsylvania Courts  | Customer - Deferred to Sy26    | 2
# Advanced Micro Devices (AMD)                       | On-Hold - Need Exec Engagement | 4
# Airbus Canada Limited Partnership                  | Customer - Deferred to Sy26    | 61
# Allen Overy Shearman Sterling LLP                  | Stage Unknown                  | 13
# Allitude S.p.A.                                    | Presentation                   | 5
# Allstate Insurance Company                         | Customer - Deferred to Sy26    | 5
# Amadeus Data Processing GmbH                       | Qualification                  | 7
# American Electric Power Co                         | Qualification                  | 3
# American National Insurance Co                     | Stage Unknown                  | 4
# Amgen Inc                                          | Qualification                  | 4
# Archer Daniels Midland Company                     | Stage Unknown                  | 4
# AstraZeneca UK Non- R & D                          | Presentation                   | 63
# Atruvia AG                                         | Stage Unknown                  | 5
# Sisters of Mercy Health Systems                    | Presentation                   | 37
# Skatteetaten                                       | Presentation                   | 20
# SoCura GmbH EU                                     | Rejected - Customer Rejection  | 2
# SpartanNash                                        | Qualification                  | 29
# Springfield Clinic                                 | Play does not Apply            | 25
# St. Joseph Hospital                                | Qualification                  | 1
# Stanford Health Care                               | Stage Unknown                  | 3
# Staples Inc                                        | Stage Unknown                  | 10
# Star India Pvt. Ltd.                               | Stage Unknown                  | 30
# State Of Utah - Its                                | On-Hold - Need Exec Engagement | 19
# State Street Bank & Trust                          | Stage Unknown                  | 198
# State of California Department of Public Health    | Stage Unknown                  | 2
# State of California Department of Technology Services | Stage Unknown                  | 2
# State of California Office of Emergency Services(OES) | Stage Unknown                  | 2
# State of Mississippi Dept of Human Services        | Customer - Deferred to Sy26    | 26
# Statens vegvesen                                   | Customer - Deferred to Sy26    | 44
# Steiermaerkische Krankenanstalten Ges.m.b.H.       | Stage Unknown                  | 9
# Stryker Corporation                                | Qualification                  | 7
# Suburban Propane                                   | Customer - Deferred to Sy26    | 4
# Sutherland Global Services Inc.                    | Stage Unknown                  | 2
# T-Mobile Wireless, USA                             | On-Hold - Need Exec Engagement | 13
# TMF SERVICES INDIA PRIVATE LIMITED                 | Qualification                  | 34
# TOTAL QUALITY LOGISTICS                            | Qualification                  | 4
# Target Corporation                                 | Qualification                  | 11
# Texas Children's Hospital                          | Customer - Deferred to Sy26    | 13
# The Boeing Company                                 | Rejected - Customer Rejection  | 10
# The Christ Hospital                                | Customer - Deferred to Sy26    | 938
# The Estee Lauder Companies Inc.                    | On-Hold - Need Exec Engagement, Play does not Apply | 4
# The Freeman Companies                              | Stage Unknown                  | 3
# The Manufacturers Life Insurance Company           | Stage Unknown                  | 1
# The Methodist Hospital                             | Customer - Deferred to Sy26    | 5
# The Nemours Foundation                             | Play does not Apply            | 33
# Thomas Jefferson University Hospital               | Presentation                   | 1
# Trinity Health                                     | Customer - Deferred to Sy26, Play does not Apply | 8
# Truist                                             | Rejected - Customer Rejection  | 9
# U.S. Department of Homeland Security (DHS) Leidos  | Presentation                   | 29
# UBS AG London Branch                               | Qualification                  | 7
# UC Health                                          | Stage Unknown                  | 5
# UCB Pharma                                         | Qualification                  | 1
# UMC Groningen                                      | On-Hold - Need Exec Engagement | 5
# US Department of Justice - Drug Enforcement Administration | Stage Unknown                  | 10
# USAA                                               | On-Hold - Need Exec Engagement | 9
# UW Medicine IT Services                            | Stage Unknown                  | 21
# Universitatsklinikum Ulm - Zentrale Einrichtung Informations- und Komm | Play does not Apply, Presentation | 10
# University of Iowa Hospitals, College of Medicine  | Stage Unknown                  | 19
# University of Northumbria                          | Stage Unknown                  | 2
# V-TServices                                        | Stage Unknown                  | 4
# Valero Energy Corporation                          | Proof of Concept               | 20
# Vinzenzgruppe                                      | Qualification                  | 7
# Vodafone Group Services Limited                    | On-Hold - Need Exec Engagement | 37
# Vulcan Materials Company                           | Customer - Deferred to Sy26    | 28
# WV United Health System                            | Stage Unknown                  | 8
# Westinghouse Electric Company                      | Stage Unknown                  | 6
# eBay Inc                                           | Play does not Apply, Qualification | 6
#
# 💾 Saved account-stage mapping:
# 📁 Filename: F5_account_names_with_stages.csv
# 📊 Accounts: 240
#
# 📊 SUMMARY BY STAGE:
# Stage Unknown: 98 accounts
# Qualification: 42 accounts
# Customer - Deferred to Sy26: 21 accounts
# Presentation: 20 accounts
# Play does not Apply: 18 accounts
# On-Hold - Need Exec Engagement: 17 accounts
# Rejected - Customer Rejection: 10 accounts
# Play does not Apply, Qualification: 4 accounts
# Proof of Concept: 2 accounts
# Initial Adoption: 2 accounts
# Customer Deferred to SY26: 1 accounts
# Mass Rollout: 1 accounts
# Play does not Apply, Presentation: 1 accounts
# Customer Deferred to SY26, Presentation: 1 accounts
# Customer - Deferred to Sy26, Play does not Apply: 1 accounts
# On-Hold - Need Exec Engagement, Play does not Apply: 1 accounts
#
# 🏆 TOP F5 ACCOUNTS (by contact count):
#                                  Account_Name                          Stage  Contact_Count
#                      Defense Logistics Agency                  Qualification           1255
#                           The Christ Hospital    Customer - Deferred to Sy26            938
#                     State Street Bank & Trust                  Stage Unknown            198
#                                   Benevis LLC                  Stage Unknown            161
#              IT-Dienstleistungszentrum Berlin                  Stage Unknown            136
#          Banco Bilbao Vizcaya Argentaria S.A.                  Stage Unknown             94
#                        Genpact India Pvt. Ltd            Play does not Apply             89
#                             COMPUTACENTER PLC  Rejected - Customer Rejection             87
#                      Kyndryl/Care New England                  Stage Unknown             87
#                      John Muir Medical Center      Customer Deferred to SY26             86
#                     AstraZeneca UK Non- R & D                   Presentation             63
#             Airbus Canada Limited Partnership    Customer - Deferred to Sy26             61
#                               City of Toronto                  Qualification             57
#                                          PSNI On-Hold - Need Exec Engagement             53
# General Dynamics Information Technology, Inc.                  Stage Unknown             44

# %%
# Create and display the F5 account-stage CSV
print("=== F5 ACCOUNTS WITH STAGES - CSV FORMAT ===")

# Create the DataFrame with account names and stages
account_stage_df = pd.DataFrame([
    {
        'Account_Name': account_name,
        'Stage': stage,
        'Contact_Count': contact_counts.get(account_name, 0)
    }
    for account_name, stage in account_stage_mapping.items()
])

# Sort by contact count (highest first)
account_stage_df = account_stage_df.sort_values('Contact_Count', ascending=False)

# Print CSV format
print("Account_Name,Stage,Contact_Count")
for _, row in account_stage_df.iterrows():
    # Clean any commas in account names or stages for proper CSV format
    account_clean = str(row['Account_Name']).replace(',', ';')
    stage_clean = str(row['Stage']).replace(',', ';')
    print(f'"{account_clean}","{stage_clean}",{row["Contact_Count"]}')

# Save as CSV file
output_dir = '/Applications/WorkDataSets/DataStore/'
import os
os.makedirs(output_dir, exist_ok=True)

csv_filename = 'F5_account_stages.csv'
csv_filepath = os.path.join(output_dir, csv_filename)

account_stage_df.to_csv(csv_filepath, index=False)

print(f"\n💾 CSV SAVED:")
print(f"📁 File: {csv_filename}")
print(f"📍 Path: {csv_filepath}")
print(f"📊 Total F5 accounts: {len(account_stage_df)}")
print(f"🏢 Accounts with contacts: {len(account_stage_df[account_stage_df['Contact_Count'] > 0])}")

# Quick stats
print(f"\n📈 QUICK STATS:")
print(f"Total F5 accounts: {len(account_stage_df)}")
print(f"Total contacts across all accounts: {account_stage_df['Contact_Count'].sum()}")
print(f"Average contacts per account: {account_stage_df['Contact_Count'].mean():.1f}")
# Out:
# === F5 ACCOUNTS WITH STAGES - CSV FORMAT ===
# Account_Name,Stage,Contact_Count
# "Defense Logistics Agency","Qualification",1255
# "The Christ Hospital","Customer - Deferred to Sy26",938
# "State Street Bank & Trust","Stage Unknown",198
# "Benevis LLC","Stage Unknown",161
# "IT-Dienstleistungszentrum Berlin","Stage Unknown",136
# "Banco Bilbao Vizcaya Argentaria S.A.","Stage Unknown",94
# "Genpact India Pvt. Ltd","Play does not Apply",89
# "COMPUTACENTER PLC","Rejected - Customer Rejection",87
# "Kyndryl/Care New England","Stage Unknown",87
# "John Muir Medical Center","Customer Deferred to SY26",86
# "AstraZeneca UK Non- R & D","Presentation",63
# "Airbus Canada Limited Partnership","Customer - Deferred to Sy26",61
# "City of Toronto","Qualification",57
# "PSNI","On-Hold - Need Exec Engagement",53
# "General Dynamics Information Technology; Inc.","Stage Unknown",44
# "Statens vegvesen","Customer - Deferred to Sy26",44
# "ITV Services Limited","Qualification",44
# "Nationwide Insurance Allied Network Services","Stage Unknown",43
# "First Merchants Bank","Customer - Deferred to Sy26",41
# "F. Hoffmann La Roche AG","Customer - Deferred to Sy26",41
# "CDW Corporation","Rejected - Customer Rejection",40
# "Sisters of Mercy Health Systems","Presentation",37
# "Vodafone Group Services Limited","On-Hold - Need Exec Engagement",37
# "Bob's Discount Furniture","Stage Unknown",37
# "Oregon State Treasury","Stage Unknown",36
# "TMF SERVICES INDIA PRIVATE LIMITED","Qualification",34
# "The Nemours Foundation","Play does not Apply",33
# "Canadian Imperial Bank of Commerce","Stage Unknown",32
# "Capital One","On-Hold - Need Exec Engagement",32
# "ConocoPhillips","Stage Unknown",30
# "New Residential Investment Corp","Presentation",30
# "Star India Pvt. Ltd.","Stage Unknown",30
# "U.S. Department of Homeland Security (DHS) Leidos","Presentation",29
# "SpartanNash","Qualification",29
# "Miami-Dade County","Play does not Apply",29
# "Raymond James and Associates","Stage Unknown",29
# "Vulcan Materials Company","Customer - Deferred to Sy26",28
# "3M Company","Stage Unknown",28
# "State of Mississippi Dept of Human Services","Customer - Deferred to Sy26",26
# "Kommunit","Qualification",26
# "Domestic & General Insurance PLC.","Stage Unknown",26
# "Helse Vest IKT AS","Play does not Apply",25
# "Springfield Clinic","Play does not Apply",25
# "Equifax; Inc.","Stage Unknown",24
# "RTX Corporation","Stage Unknown",23
# "IQEQ","Stage Unknown",22
# "UW Medicine IT Services","Stage Unknown",21
# "Skatteetaten","Presentation",20
# "JP Morgan Services India Pvt Ltd","Stage Unknown",20
# "Valero Energy Corporation","Proof of Concept",20
# "Cincinnati Children's Hospital Medical Center","Qualification",19
# "N.C. Dept of Transportation","Stage Unknown",19
# "University of Iowa Hospitals; College of Medicine","Stage Unknown",19
# "Ericsson AB","Qualification",19
# "Office for Standards in Education","Stage Unknown",19
# "National Grid","Qualification",19
# "Naval Nuclear Lab","Qualification",19
# "State Of Utah - Its","On-Hold - Need Exec Engagement",19
# "Diehl Aviation Laupheim GmbH","Stage Unknown",17
# "Illinois Dept. of Central Management Services","Stage Unknown",17
# "Banca d'Italia","Presentation",17
# "Deutsche Bahn AG","Presentation",15
# "Owens & Minor Medical; Inc.","Qualification",15
# "Covenant Health","Qualification",15
# "Charter Court Financial Services (CCFS)","Stage Unknown",14
# "ADT US","Play does not Apply",14
# "Department of Energy OCIO","Presentation",14
# "BioNTech AG","Stage Unknown",14
# "Texas Children's Hospital","Customer - Deferred to Sy26",13
# "Guggenheim Services LLC","Stage Unknown",13
# "Allen Overy Shearman Sterling LLP","Stage Unknown",13
# "T-Mobile Wireless; USA","On-Hold - Need Exec Engagement",13
# "Kongsberg Defence & Aerospace AS","Presentation",12
# "McLane Company","Presentation",12
# "Broward Health","Mass Rollout",12
# "Abbott Laboratories","Stage Unknown",12
# "Target Corporation","Qualification",11
# "H. Lundbeck A/S","Play does not Apply",11
# "PODS Enterprises; LLC","Stage Unknown",11
# "Fritz Egger GmbH & Co KG","Qualification",11
# "Regions Bank","Stage Unknown",11
# "Landeskrankenhaus Andernach","Stage Unknown",11
# "First Citizens Bank & Trust Company","On-Hold - Need Exec Engagement",11
# "AbbVie Inc","Rejected - Customer Rejection",10
# "Staples Inc","Stage Unknown",10
# "Jones Day","Rejected - Customer Rejection",10
# "US Department of Justice - Drug Enforcement Administration","Stage Unknown",10
# "The Boeing Company","Rejected - Customer Rejection",10
# "Universitatsklinikum Ulm - Zentrale Einrichtung Informations- und Komm","Play does not Apply; Presentation",10
# "KBC Group","Initial Adoption",10
# "USAA","On-Hold - Need Exec Engagement",9
# "Steiermaerkische Krankenanstalten Ges.m.b.H.","Stage Unknown",9
# "Retail Business Services; LLC","Stage Unknown",9
# "McGladrey; Inc.","Qualification",9
# "Magistrat Der Stadt Wien","Customer Deferred to SY26; Presentation",9
# "Truist","Rejected - Customer Rejection",9
# "CRC Insurance Services; Inc.","Stage Unknown",9
# "Banner Bank","Stage Unknown",8
# "Emerson","Play does not Apply",8
# "WV United Health System","Stage Unknown",8
# "Trinity Health","Customer - Deferred to Sy26; Play does not Apply",8
# "Kiewit Construction","On-Hold - Need Exec Engagement",8
# "50Hertz Transmission GmbH","Presentation",7
# "ISTEKKI OY","Presentation",7
# "UBS AG London Branch","Qualification",7
# "Mayo Foundation for Medical Education and Research","Stage Unknown",7
# "Piedmont Hospital","Stage Unknown",7
# "Stryker Corporation","Qualification",7
# "Amadeus Data Processing GmbH","Qualification",7
# "Deluxe Corporation","Presentation",7
# "Kootenai Health","Stage Unknown",7
# "Erasmus MC","On-Hold - Need Exec Engagement",7
# "Vinzenzgruppe","Qualification",7
# "Marks & Spencer plc","Stage Unknown",7
# "Comune di Milano","Presentation",7
# "Hydro Quebec","Stage Unknown",6
# "Eli Lilly Group UK","Stage Unknown",6
# "Robert Bosch GmbH","On-Hold - Need Exec Engagement",6
# "Boehringer Ingelheim GmbH","Stage Unknown",6
# "Kanton Thurgau","Qualification",6
# "Westinghouse Electric Company","Stage Unknown",6
# "Gemeente Den Haag","Play does not Apply",6
# "Cleary Gottlieb Steen & Hamilton","On-Hold - Need Exec Engagement",6
# "eBay Inc","Play does not Apply; Qualification",6
# "IT des Bezirks Oberbayern GmbH","Stage Unknown",6
# "Banque de Luxembourg","Stage Unknown",5
# "UMC Groningen","On-Hold - Need Exec Engagement",5
# "Allstate Insurance Company","Customer - Deferred to Sy26",5
# "Hessische Zentrale für Datenverarbeitung","Initial Adoption",5
# "Allitude S.p.A.","Presentation",5
# "General Health System","Qualification",5
# "ORPEA","Presentation",5
# "Istituto nazionale per l'assicurazione contro gliinfortuni sul lavoro","Stage Unknown",5
# "Lockton Companies","Customer - Deferred to Sy26",5
# "Securitas Intelligent Services AB","Stage Unknown",5
# "Federal Emergency Management Agency (FEMA)","On-Hold - Need Exec Engagement",5
# "Kinder Morgan","Presentation",5
# "UC Health","Stage Unknown",5
# "Bayhealth","Play does not Apply",5
# "SEB","Presentation",5
# "The Methodist Hospital","Customer - Deferred to Sy26",5
# "Compagnie Financière Richemont SA","Stage Unknown",5
# "Emil Frey AG","Play does not Apply",5
# "OrthoCarolina","Qualification",5
# "Atruvia AG","Stage Unknown",5
# "Humana Inc","Play does not Apply",4
# "Renown Health","Proof of Concept",4
# "JPMorgan Chase","Stage Unknown",4
# "Suburban Propane","Customer - Deferred to Sy26",4
# "Amgen Inc","Qualification",4
# "Ipca Laboratories Ltd","Stage Unknown",4
# "Krones AG","Rejected - Customer Rejection",4
# "Bundesanstalt für Finanzdienstleistungsaufsicht","Stage Unknown",4
# "V-TServices","Stage Unknown",4
# "Fortifikationsverket","Qualification",4
# "Försäkringskassan","Stage Unknown",4
# "American National Insurance Co","Stage Unknown",4
# "Archer Daniels Midland Company","Stage Unknown",4
# "Avaloq Sourcing (Europe) AG","Stage Unknown",4
# "PeaceHealth","Customer - Deferred to Sy26",4
# "AMAP : Association de Moyens Assurance des Personnes","Stage Unknown",4
# "Migrationsverket","Stage Unknown",4
# "Advanced Micro Devices (AMD)","On-Hold - Need Exec Engagement",4
# "Lower Colorado River Authority","Qualification",4
# "The Estee Lauder Companies Inc.","On-Hold - Need Exec Engagement; Play does not Apply",4
# "Federal Student Aid (FSA)","Qualification",4
# "Bundesagentur für Arbeit","Play does not Apply; Qualification",4
# "TOTAL QUALITY LOGISTICS","Qualification",4
# "CommonSpirit Health","Stage Unknown",3
# "Stanford Health Care","Stage Unknown",3
# "MGM Resorts INTL Operations (516)","Stage Unknown",3
# "Deutsche Bundesbank","Play does not Apply",3
# "The Freeman Companies","Stage Unknown",3
# "NRG Energy; Inc.","Play does not Apply",3
# "Securian Financial","Qualification",3
# "Baker Tilly Virchow Krause; LLP","Stage Unknown",3
# "MAZARS","Qualification",3
# "DS SMITH PLC","Qualification",3
# "Geisinger System Services","Stage Unknown",3
# "GREEN Customer","Qualification",3
# "Epiq","Stage Unknown",3
# "Consolidated Communications Holdings; Inc.","Play does not Apply; Qualification",3
# "OhioHealth Corporation","Stage Unknown",3
# "American Electric Power Co","Qualification",3
# "Children's Hospital of The Kings Daughters","Qualification",3
# "PepsiCo Inc","On-Hold - Need Exec Engagement",3
# "International Paper Corporation","Play does not Apply",3
# "Huntington Bancshares Incorporated","Stage Unknown",3
# "Mizuho Securities Co.; Ltd.","Stage Unknown",3
# "Hydro One Networks Inc.","Play does not Apply; Qualification",2
# "Novartis","On-Hold - Need Exec Engagement",2
# "Laboratory Corp. of America Holdings","Stage Unknown",2
# "KSB SE & Co. KGaA","Stage Unknown",2
# "PORR Aktiengesellschaft","Customer - Deferred to Sy26",2
# "Sutherland Global Services Inc.","Stage Unknown",2
# "Döhler GmbH","Qualification",2
# "Jennison Associates (Subsidiary of Prudential)","Qualification",2
# "Penske Truck Leasing","Stage Unknown",2
# "State of California Department of Technology Services","Stage Unknown",2
# "DVD PARTICIPATIONS","Stage Unknown",2
# "Jacobs Engineering Group Inc.","Customer - Deferred to Sy26",2
# "Parnassia Groep B.V.","Stage Unknown",2
# "University of Northumbria","Stage Unknown",2
# "Federated Investors","Stage Unknown",2
# "SoCura GmbH EU","Rejected - Customer Rejection",2
# "State of California Office of Emergency Services(OES)","Stage Unknown",2
# "Politie EU Cloud","On-Hold - Need Exec Engagement",2
# "Pragmatic Consulting Inc.","Stage Unknown",2
# "BrightSpeed","Play does not Apply",2
# "Dane County Dept of Administration","Stage Unknown",2
# "British Petroleum","Qualification",2
# "State of California Department of Public Health","Stage Unknown",2
# "Jacksonville Electric Authority (JEA)","Customer - Deferred to Sy26",2
# "GISS","Stage Unknown",2
# "CSX Corporation","Play does not Apply",2
# "Children's Hospital","Customer - Deferred to Sy26",2
# "Adani Enterprises Ltd.","Stage Unknown",2
# "Administrative Offices of the Pennsylvania Courts","Customer - Deferred to Sy26",2
# "Thomas Jefferson University Hospital","Presentation",1
# "Duly Health and Care","Stage Unknown",1
# "DOD - Defense Advanced Research Proj Agcy (DARPA)","Play does not Apply",1
# "Landeshauptstadt München IT@M Landeshauptstadt München IT@MM","Qualification",1
# "Home Depot","Customer - Deferred to Sy26",1
# "DXP Enterprises","Qualification",1
# "Community Hospitals of Indiana","Stage Unknown",1
# "The Manufacturers Life Insurance Company","Stage Unknown",1
# "Bundesamt für Informatik und Telekommunikation BIT","Stage Unknown",1
# "Bandhan Bank Ltd","Stage Unknown",1
# "Lexzau; Scharbau GmbH & Co. KG","Qualification",1
# "Little Company of Mary Health Care","Qualification",1
# "St. Joseph Hospital","Qualification",1
# "UCB Pharma","Qualification",1
# "Bullhorn; Inc.","Presentation",1
# "ENI S.p.A.","Rejected - Customer Rejection",1
# "S.O.N.J.A. N.V.","Stage Unknown",1
# "Bonneville Power Administration","Stage Unknown",1
# "K&L Gates LLP","Customer - Deferred to Sy26",1
# "ITC Infotech India Limited","Stage Unknown",1
# "SSM Health Care","Customer - Deferred to Sy26",1
# "Cision","Rejected - Customer Rejection",1
#
# 💾 CSV SAVED:
# 📁 File: F5_account_stages.csv
# 📍 Path: /Applications/WorkDataSets/DataStore/F5_account_stages.csv
# 📊 Total F5 accounts: 240
# 🏢 Accounts with contacts: 240
#
# 📈 QUICK STATS:
# Total F5 accounts: 240
# Total contacts across all accounts: 5620
# Average contacts per account: 23.4
