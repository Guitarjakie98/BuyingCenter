# %%
# Core
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning / Stats
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# %% [markdown]
# Project:
# Stakehholder
# Date:
# objective:

# %%
# Read a CSV from local file system
df = pd.read_csv("/Applications/WorkDataSets/DataStore/OracleContactData3_SalesAffinity.csv")

# %%
#only rows where account_segmentation == "CITRIX_ENTERPRISE"
filtered_account_df = df[df["account_segmentation"] == "CITRIX_ENTERPRISE"].copy()

# %%
# List of GEO values to keep
geo_keep = [
    "CE DACH IND DEVELOP ADM1", "CE DACH IND DEVELOP ADM2",
    "CE DACH IND GROW AE1", "CE DACH IND GROW AE2",
    "CE DACH IND RETAIN AM1", "CE DACH IND RETAIN AM2",
    "CE DACH IND RETAIN AM3", "CE DACH IND RETAIN AM4", "CE DACH IND RETAIN AM5",
    "CE DACH PUB DEVELOP ADM1", "CE DACH PUB GROW AE1", "CE DACH PUB GROW AE2",
    "CE DACH PUB RETAIN AM1", "CE DACH PUB RETAIN AM2", "CE DACH PUB RETAIN AM3",
    "CE DACH PUB RETAIN AM4", "CE DACH PUB RETAIN AM5", "CE DACH PUB RETAIN AM6",
    "CE DK GROW AE1", "CE DK RETAIN AM1", "CE FI RETAIN AM2", "CE NO GROW AE2",
    "CE NORDICS DEVELOP ADM1", "CE NORDICS DEVELOP ADM2",
    "CE SE GROW AE3", "CE SE RETAIN AM3",
    "Healthcare DEVELOP ADM1", "Healthcare DEVELOP ADM2", "Healthcare DEVELOP ADM3",
    "Healthcare RETAIN AM1", "Healthcare RETAIN AM2", "Healthcare RETAIN AM3",
    "Healthcare RETAIN AM4", "Healthcare RETAIN AM5", "Healthcare RETAIN AM6",
    "India ENT AE1", "India ENT AE2", "India ENT AE3", "International Enterprise",
    "NA ENT DEVELOP ADM1", "NA ENT DEVELOP ADM2", "NA ENT DEVELOP ADM3",
    "NA ENT DEVELOP ADM4", "NA ENT DEVELOP ADM5", "NA ENT DEVELOP ADM6",
    "NA ENT DEVELOP ADM7", "NA ENT DEVELOP ADM8", "NA ENT DEVELOP ADM9",
    "NA ENT GROW-A AE1", "NA ENT GROW-A AE2", "NA ENT GROW-A AE3", "NA ENT GROW-A AE4",
    "NA ENT GROW-A AE6", "NA ENT GROW-A AE7", "NA ENT GROW-B AE1", "NA ENT GROW-B AE2",
    "NA ENT GROW-B AE4", "NA ENT GROW-B AE5", "NA ENT GROW-B AE6", "NA ENT GROW-B AE7",
    "NA ENT GROW-C AE1", "NA ENT GROW-C AE2", "NA ENT GROW-C AE3", "NA ENT GROW-C AE4",
    "NA ENT GROW-C AE5", "NA ENT GROW-C AE6", "NA ENT GROW-D AE1", "NA ENT GROW-D AE2",
    "NA ENT GROW-D AE3", "NA ENT GROW-D AE6", "NA ENT GROW-D AE7",
    "NA ENT RETAIN AM1", "NA ENT RETAIN AM2", "NA ENT RETAIN AM3", "NA ENT RETAIN AM4",
    "NA ENT RETAIN AM5", "NA ENT RETAIN AM6", "NA ENT RETAIN AM7",
    "NA ENT RETAIN AM8", "NA ENT RETAIN AM9",
    "NA PUB AE1", "NA PUB AE2", "NA PUB AE3", "NA PUB AE4", "NA PUB AE5",
    "NA PUB AE7", "NA PUB AE8", "NA PUB AE10", "NA PUB AE11",
    "WE ES DEVELOP ADM1", "WE ES GROW AE1", "WE ES RETAIN AM1",
    "WE FR DEVELOP ADM1", "WE FR GROW AE1", "WE FR RETAIN AM1",
    "WE FR RETAIN AM2", "WE FR RETAIN AM3", "WE IT DEVELOP ADM1", "WE IT RETAIN AM1",
    "WE NL DEVELOP ADM1", "WE NL GROW AE1", "WE NL RETAIN AM1",
    "WE UKI DEVELOP ADM1", "WE UKI DEVELOP ADM2",
    "WE UKI GROW AE1", "WE UKI GROW AE2",
    "WE UKI RETAIN AM1", "WE UKI RETAIN AM2",
    "WE UKI RETAIN AM3", "WE UKI RETAIN AM4"
]

# Filter to only keep rows with these GEOs
filtered_df = df[df["GEO"].isin(geo_keep)].copy()

# Save to same folder

print(f"Rows kept: {len(filtered_df)} / {len(df)} total")
# Out:
# ➡️ Rows kept: 84264 / 378786 total

# %%
# Step 1: Get your unique master NAR list
master_nars = (
    filtered_df["CustomerId_NAR"]
    .dropna()
    .drop_duplicates()
)
# Step 2: Keep only contact rows that belong to those NARs
filtered_contacts = filtered_df[filtered_df["CustomerId_NAR"].isin(master_nars)].copy()

# Step 3: Save the final dataset
print(f"Rows kept: {len(filtered_contacts)} / {len(filtered_df)} total after NAR filtering")
# Out:
# Rows kept: 84264 / 84264 total after NAR filtering

# %% [markdown]
# WADE"S REQUEST

# %%
AccSeries = pd.Series([
"CIT-51552627",
"CIT-45796028",
"CIT-51676087",
"CIT-51259630",
"CIT-17183700",
"CIT-50016510",
"CIT-39751600",
"CIT-45160265",
"CIT-46185326",
"CIT-50094600",
"CIT-45380968",
"CIT-51959616",
"CIT-45468407",
"CIT-45863369",
"CIT-29361400",
"CIT-45128424",
"CIT-50089975",
"CIT-24113900",
"CIT-45397281",
"CIT-45750850",
"CIT-48673365",
"CIT-45541103",
"CIT-45757869",
"CIT-51947488",
"CIT-45096219",
"CIT-47625838",
"CIT-45541129",
"CIT-52396640",
"CIT-47622638",
"CIT-51107942",
"CIT-46443142",
"CIT-45783112",
"CIT-39745700",
"CIT-50211024",
"CIT-47346861",
"CIT-48282773",
"CIT-51503589",
"CIT-26267500",
"CIT-52692031",
"CIT-45275012",
"CIT-45697182",
"CIT-45456483",
"CIT-48440121",
"CIT-47744710",
"CIT-47744710",
"CIT-45586350",
"CIT-17633400",
"CIT-45113961",
"CIT-52599872",
"CIT-31100900",
"CIT-45796911",
"CIT-45503315",
"CIT-45745194",
"CIT-39627900",
"CIT-50583826",
"CIT-46645258",
"CIT-45849256",
"CIT-27538000",
"CIT-45802860",
"CIT-49392965",
"CIT-49392965",
"CIT-47732964",
"CIT-47732964",
"CIT-47732964",
"CIT-47942308",
"CIT-52540065",
"CIT-45242854",
"CIT-51362186",
"CIT-41251100",
"CIT-119935HQ",
"CIT-51255761",
"CIT-45246310",
"CIT-49535979",
"CIT-74358HQ",
"CIT-23749100",
"CIT-45888412",
"CIT-45089561",
"CIT-45739941",
"CIT-45739941",
"CIT-45999113",
"CIT-50717994",
"CIT-50817788",
"CIT-49385978",
"CIT-51934HQ",
"CIT-46040955",
"CIT-46040955",
"CIT-51596346",
"CIT-51136239",
"CIT-37031700",
"CIT-45577716",
"CIT-48603740",
"CIT-50153927",
"CIT-65217HQ",
"CIT-47702324",
"CIT-50306359",
"CIT-51999825",
"CIT-46542769",
"CIT-45263537",
"CIT-45560449",
"CIT-45503521"])
# Step 1. Clean the CustomerId_NAR column by removing prefixes like "A-" or "H-"
df["CustomerId_NAR_Clean"] = df["CustomerId_NAR"].str.replace(r"^[A-Z]-", "", regex=True)

# %%
# Step 1. Clean CustomerId_NAR (remove prefixes like "A-" or "H-")
df["CustomerId_NAR_Clean"] = df["CustomerId_NAR"].str.replace(r"^[A-Z]-", "", regex=True).str.strip()

# Step 2. Define exec roles
exec_roles = [
    "IT_EXECUTIVE",
    "CLOUD_AND_INFRA_EXEC",
    "CIO",
    "SECURITY_EXECUTIVE",
    "LOB_EXECUTIVE",
    "KEY_DECISION_MAKER"
]

# Step 3. GEOs to keep (paste your geo_keep list here)
geo_keep = [ "CE DACH IND DEVELOP ADM1", "CE DACH IND DEVELOP ADM2",
    "CE DACH IND GROW AE1", "CE DACH IND GROW AE2",
    "CE DACH IND RETAIN AM1", "CE DACH IND RETAIN AM2",
    "CE DACH IND RETAIN AM3", "CE DACH IND RETAIN AM4", "CE DACH IND RETAIN AM5",
    "CE DACH PUB DEVELOP ADM1", "CE DACH PUB GROW AE1", "CE DACH PUB GROW AE2",
    "CE DACH PUB RETAIN AM1", "CE DACH PUB RETAIN AM2", "CE DACH PUB RETAIN AM3",
    "CE DACH PUB RETAIN AM4", "CE DACH PUB RETAIN AM5", "CE DACH PUB RETAIN AM6",
    "CE DK GROW AE1", "CE DK RETAIN AM1", "CE FI RETAIN AM2", "CE NO GROW AE2",
    "CE NORDICS DEVELOP ADM1", "CE NORDICS DEVELOP ADM2",
    "CE SE GROW AE3", "CE SE RETAIN AM3",
    "Healthcare DEVELOP ADM1", "Healthcare DEVELOP ADM2", "Healthcare DEVELOP ADM3",
    "Healthcare RETAIN AM1", "Healthcare RETAIN AM2", "Healthcare RETAIN AM3",
    "Healthcare RETAIN AM4", "Healthcare RETAIN AM5", "Healthcare RETAIN AM6",
    "India ENT AE1", "India ENT AE2", "India ENT AE3", "International Enterprise",
    "NA ENT DEVELOP ADM1", "NA ENT DEVELOP ADM2", "NA ENT DEVELOP ADM3",
    "NA ENT DEVELOP ADM4", "NA ENT DEVELOP ADM5", "NA ENT DEVELOP ADM6",
    "NA ENT DEVELOP ADM7", "NA ENT DEVELOP ADM8", "NA ENT DEVELOP ADM9",
    "NA ENT GROW-A AE1", "NA ENT GROW-A AE2", "NA ENT GROW-A AE3", "NA ENT GROW-A AE4",
    "NA ENT GROW-A AE6", "NA ENT GROW-A AE7", "NA ENT GROW-B AE1", "NA ENT GROW-B AE2",
    "NA ENT GROW-B AE4", "NA ENT GROW-B AE5", "NA ENT GROW-B AE6", "NA ENT GROW-B AE7",
    "NA ENT GROW-C AE1", "NA ENT GROW-C AE2", "NA ENT GROW-C AE3", "NA ENT GROW-C AE4",
    "NA ENT GROW-C AE5", "NA ENT GROW-C AE6", "NA ENT GROW-D AE1", "NA ENT GROW-D AE2",
    "NA ENT GROW-D AE3", "NA ENT GROW-D AE6", "NA ENT GROW-D AE7",
    "NA ENT RETAIN AM1", "NA ENT RETAIN AM2", "NA ENT RETAIN AM3", "NA ENT RETAIN AM4",
    "NA ENT RETAIN AM5", "NA ENT RETAIN AM6", "NA ENT RETAIN AM7",
    "NA ENT RETAIN AM8", "NA ENT RETAIN AM9",
    "NA PUB AE1", "NA PUB AE2", "NA PUB AE3", "NA PUB AE4", "NA PUB AE5",
    "NA PUB AE7", "NA PUB AE8", "NA PUB AE10", "NA PUB AE11",
    "WE ES DEVELOP ADM1", "WE ES GROW AE1", "WE ES RETAIN AM1",
    "WE FR DEVELOP ADM1", "WE FR GROW AE1", "WE FR RETAIN AM1",
    "WE FR RETAIN AM2", "WE FR RETAIN AM3", "WE IT DEVELOP ADM1", "WE IT RETAIN AM1",
    "WE NL DEVELOP ADM1", "WE NL GROW AE1", "WE NL RETAIN AM1",
    "WE UKI DEVELOP ADM1", "WE UKI DEVELOP ADM2",
    "WE UKI GROW AE1", "WE UKI GROW AE2",
    "WE UKI RETAIN AM1", "WE UKI RETAIN AM2",
    "WE UKI RETAIN AM3", "WE UKI RETAIN AM4"
]

# Step 4. Final filtered dataset
filtered_df = df[
    (df["CustomerId_NAR_Clean"].isin(AccSeries)) &
    (df["sales_buying_role_code"].str.strip().isin(exec_roles)) &
    (df["do_not_contact_flag"].str.upper() == "N") &
    (df["do_not_email_flag"].str.upper() == "N") &
    (df["GEO"].isin(geo_keep))
].copy()

# Step 5. Sort & save
filtered_df.sort_values(by=["CustomerId_NAR_Clean", "sales_buying_role_code"], inplace=True)

output_path = "/Applications/WorkDataSets/WadeList2.csv"
filtered_df.to_csv(output_path, index=False)

print(f"✅ {len(filtered_df)} rows saved to {output_path}")
print(filtered_df[["CustomerId_NAR_Clean", "sales_buying_role_code", "GEO", "person_name"]].head(10))
# Out:
# ✅ 875 rows saved to /Applications/WorkDataSets/WadeList2.csv
#        CustomerId_NAR_Clean sales_buying_role_code                    GEO      person_name
# 5655           CIT-110108HQ                    CIO  Healthcare RETAIN AM4        Cris Ross
# 147354         CIT-110108HQ                    CIO  Healthcare RETAIN AM4  Vish Anantraman
# 225418         CIT-110108HQ                    CIO  Healthcare RETAIN AM4      Tony Rubino
# 61203          CIT-110108HQ   CLOUD_AND_INFRA_EXEC  Healthcare RETAIN AM4     Steve Branda
# 354485         CIT-110108HQ   CLOUD_AND_INFRA_EXEC  Healthcare RETAIN AM4  Robert Yankosky
# 63171          CIT-110108HQ           IT_EXECUTIVE  Healthcare RETAIN AM4        Art Pfund
# 117341         CIT-110108HQ           IT_EXECUTIVE  Healthcare RETAIN AM4      Robert Hill
# 196018         CIT-110108HQ           IT_EXECUTIVE  Healthcare RETAIN AM4      Dave McGraw
# 344563         CIT-110108HQ           IT_EXECUTIVE  Healthcare RETAIN AM4        Art Pfund
# ...

# %%
TechPlayHisto = pd.read_csv("/Applications/WorkDataSets/DataStore/TechPlayHisto3.csv")
# Display the column names cleanly
print("🧱 Columns in TechPlayHisto:")
for col in TechPlayHisto.columns:
    print("-", col)
# Out:
# 🧱 Columns in TechPlayHisto:
# - oracle_account_id
# - company_name
# - customer_id
# - vw_account_name
# - account_segmentation
# - line_of_business
# - parent_party_number
# - partner_of_record
# - city
# - country
# - tech_play_type_label
# - tech_play_category
# - from_stage
# - to_stage
# - from_stage_date
# - to_stage_date
# - days_in_stage

# %%
# Load your data
TechPlayHisto = pd.read_csv("/Applications/WorkDataSets/DataStore/TechPlayHisto3.csv")

# Step 1. Clean up and prepare
TechPlayHisto["from_stage"] = TechPlayHisto["from_stage"].astype(str).str.strip().str.lower()
TechPlayHisto["tech_play_type_label"] = TechPlayHisto["tech_play_type_label"].astype(str).str.strip()
TechPlayHisto["from_stage_date"] = pd.to_datetime(TechPlayHisto["from_stage_date"], errors="coerce")

# Step 2. Sort chronologically to identify latest stage per customer + tech play
TechPlayHisto = TechPlayHisto.sort_values(["customer_id", "tech_play_type_label", "from_stage_date"], ascending=[True, True, False])

# Step 3. Keep only the most recent stage per customer and tech play
latest_stage = (
    TechPlayHisto.groupby(["customer_id", "tech_play_type_label"], as_index=False)
    .first()[["customer_id", "tech_play_type_label", "from_stage", "from_stage_date",
              "company_name", "account_segmentation", "line_of_business",
              "parent_party_number", "partner_of_record", "city", "country"]]
)

# Step 4. Filter for desired stages
target_stages = ["on-hold", "qualification", "presentation"]
filtered_accounts = latest_stage[latest_stage["from_stage"].isin(target_stages)]

# Step 5. Inspect results
print(f"✅ {len(filtered_accounts)} accounts remain after stage filtering.")
print(filtered_accounts.head(10))
# Out:
# ✅ 6145 accounts remain after stage filtering.
#        customer_id tech_play_type_label     from_stage from_stage_date                      company_name        account_segmentation            line_of_business parent_party_number  \
# 11  A-CIT-45919026    Takeout - Horizon  qualification      2024-08-21             Hyundai Motor Company  CITRIX_REPRESENTED_MARKETS       MINING & CONSTRUCTION                None
# 13  A-CIT-45919026                  nan  qualification      2024-08-21             Hyundai Motor Company  CITRIX_REPRESENTED_MARKETS       MINING & CONSTRUCTION                None
# 14  A-CIT-45919026            uberAgent  qualification      2024-08-21             Hyundai Motor Company  CITRIX_REPRESENTED_MARKETS       MINING & CONSTRUCTION                None
# 19  A-CIT-47127725    Takeout - Horizon  qualification      2024-08-21  Lotte Data Communication Company  CITRIX_REPRESENTED_MARKETS            SERVICES - OTHER                None
# ...

# %%
filtered_df

print("🧱 Columns in TechPlayHisto:")
for col in filtered_df:
    print("-", col)
# Out:
# 🧱 Columns in TechPlayHisto:
# - party_number
# - email_address
# - person_name
# - party_unique_name
# - department_code
# - do_not_contact_flag
# - do_not_email_flag
# - do_not_mail_flag
# - job_title
# - job_title_code
# - sales_buying_role_code
# - sales_affinity_code
# - company_name
# - account_type
# - country
# - state
# - city
# - line_of_business
# - CustomerId_NAR
# - CustomerName_NAR
# - account_segmentation
# - total_arr
# - ats_owner
# - ae_owner
# - GEO
# - CustomerId_NAR_Clean
# - customer_id
# - from_stage
# - from_stage_date

# %%
import pandas as pd

contacts_df = pd.read_csv("/Applications/WorkDataSets/WadeList2.csv")
TechPlayHisto = pd.read_csv("/Applications/WorkDataSets/DataStore/TechPlayHisto3.csv")

print("Contacts:", contacts_df.columns.tolist()[:15])
print("TechPlayHisto:", TechPlayHisto.columns.tolist()[:15])
# Out:
# Contacts: ['party_number', 'email_address', 'person_name', 'party_unique_name', 'department_code', 'do_not_contact_flag', 'do_not_email_flag', 'do_not_mail_flag', 'job_title', 'job_title_code', 'sales_buying_role_code', 'sales_affinity_code', 'company_name', 'account_type', 'country']
# TechPlayHisto: ['oracle_account_id', 'company_name', 'customer_id', 'vw_account_name', 'account_segmentation', 'line_of_business', 'parent_party_number', 'partner_of_record', 'city', 'country', 'tech_play_type_label', 'tech_play_category', 'from_stage', 'to_stage', 'from_stage_date']

# %%
contacts_df["CustomerId_NAR"] = contacts_df["CustomerId_NAR"].astype(str).str.strip()
TechPlayHisto["customer_id"] = TechPlayHisto["customer_id"].astype(str).str.strip()

print("Contacts_df key sample:", contacts_df["CustomerId_NAR"].head(3).tolist())
print("TechPlayHisto key sample:", TechPlayHisto["customer_id"].head(3).tolist())
# Out:
# Contacts_df key sample: ['H-CIT-110108HQ', 'H-CIT-110108HQ', 'H-CIT-110108HQ']
# TechPlayHisto key sample: ['H-CIT-49266926', 'H-CIT-49266926', 'H-CIT-49266926']

# %%
common = set(contacts_df["CustomerId_NAR"]) & set(TechPlayHisto["customer_id"])
print(f"🔗 Found {len(common)} overlapping Customer NAR IDs")
# Out:
# 🔗 Found 217 overlapping Customer NAR IDs

# %%
common = set(contacts_df["CustomerId_NAR"]) & set(TechPlayHisto["customer_id"])
print(f"🔗 Found {len(common)} overlapping Customer NAR IDs")
# Out:
# 🔗 Found 217 overlapping Customer NAR IDs

# %%
target_stages = ["on-hold", "qualification", "presentation"]
TechPlayHisto["from_stage"] = TechPlayHisto["from_stage"].astype(str).str.lower().str.strip()
stage_filtered = TechPlayHisto[TechPlayHisto["from_stage"].isin(target_stages)].copy()
print(f"✅ {len(stage_filtered)} rows remain after stage filtering ({stage_filtered['customer_id'].nunique()} unique accounts)")
# Out:
# ✅ 6763 rows remain after stage filtering (1697 unique accounts)

# %%
target_stages = ["on-hold", "qualification", "presentation"]

# %%
TechPlayHisto["from_stage"] = TechPlayHisto["from_stage"].astype(str).str.lower().str.strip()

# %%
stage_filtered = TechPlayHisto[TechPlayHisto["from_stage"].isin(target_stages)].copy()

# %%
print(f"✅ {len(stage_filtered)} rows remain after stage filtering ({stage_filtered['customer_id'].nunique()} unique accounts)")
# Out:
# ✅ 6763 rows remain after stage filtering (1697 unique accounts)

# %%
filtered_contacts = contacts_df[
    contacts_df["CustomerId_NAR"].isin(stage_filtered["customer_id"])
].copy()

print(f"✅ {len(filtered_contacts)} contacts belong to accounts in On-Hold, Qualification, or Presentation stages.")
print(f"({filtered_contacts['CustomerId_NAR'].nunique()} unique accounts in contacts dataset)")
# Out:
# ✅ 778 contacts belong to accounts in On-Hold, Qualification, or Presentation stages.
# (185 unique accounts in contacts dataset)

# %%
contacts_stage_enriched = filtered_contacts.merge(
    stage_filtered[["customer_id", "tech_play_type_label", "from_stage", "from_stage_date"]],
    left_on="CustomerId_NAR",
    right_on="customer_id",
    how="left"
)

print(f"✅ Enriched dataset now has {len(contacts_stage_enriched)} rows")
print(contacts_stage_enriched[["CustomerId_NAR", "person_name", "email_address", "from_stage", "tech_play_type_label"]].head(10))
# Out:
# ✅ Enriched dataset now has 4091 rows
#    CustomerId_NAR      person_name                   email_address    from_stage tech_play_type_label
# 0  H-CIT-110108HQ        Cris Ross       ross.christopher@mayo.edu  presentation     Takeout - F5/ADC
# 1  H-CIT-110108HQ  Vish Anantraman  anantraman.vishwanath@mayo.edu  presentation     Takeout - F5/ADC
# 2  H-CIT-110108HQ      Tony Rubino         rubino.anthony@mayo.edu  presentation     Takeout - F5/ADC
# 3  H-CIT-110108HQ     Steve Branda          branda.steven@mayo.edu  presentation     Takeout - F5/ADC
# 4  H-CIT-110108HQ  Robert Yankosky        yankosky.robert@mayo.edu  presentation     Takeout - F5/ADC
# 5  H-CIT-110108HQ        Art Pfund           pfund.arthur@mayo.edu  presentation     Takeout - F5/ADC
# 6  H-CIT-110108HQ      Robert Hill           hill.robert1@mayo.edu  presentation     Takeout - F5/ADC
# 7  H-CIT-110108HQ      Dave McGraw          mcgraw.thomas@mayo.edu  presentation     Takeout - F5/ADC
# ...

# %%
# Define the specific Tech Play and target stages
target_play = "takeout - horizon"
target_stages = ["on-hold", "qualification", "presentation"]

# Normalize text for reliable matching
TechPlayHisto["from_stage"] = TechPlayHisto["from_stage"].astype(str).str.lower().str.strip()
TechPlayHisto["tech_play_type_label"] = TechPlayHisto["tech_play_type_label"].astype(str).str.lower().str.strip()

# Filter for exact Tech Play and target stages
stage_filtered = TechPlayHisto[
    (TechPlayHisto["from_stage"].isin(target_stages)) &
    (TechPlayHisto["tech_play_type_label"] == target_play)
].copy()

print(f"✅ {len(stage_filtered)} rows remain for '{target_play}' in target stages "
      f"({stage_filtered['customer_id'].nunique()} unique accounts)")
# Out:
# ✅ 395 rows remain for 'takeout - horizon' in target stages (376 unique accounts)

# %%
filtered_contacts = contacts_df[
    contacts_df["CustomerId_NAR"].isin(stage_filtered["customer_id"])
].copy()

print(f"✅ {len(filtered_contacts)} contacts belong to '{target_play}' accounts "
      f"in On-Hold, Qualification, or Presentation stages.")
# Out:
# ✅ 614 contacts belong to 'takeout - horizon' accounts in On-Hold, Qualification, or Presentation stages.

# %%
print("🧱 Columns in contacts_enriched:")
for col in filtered_contacts.columns:
    print("-", col)
# Out:
# 🧱 Columns in contacts_enriched:
# - party_number
# - email_address
# - person_name
# - party_unique_name
# - department_code
# - do_not_contact_flag
# - do_not_email_flag
# - do_not_mail_flag
# - job_title
# - job_title_code
# - sales_buying_role_code
# - sales_affinity_code
# - company_name
# - account_type
# - country
# - state
# - city
# - line_of_business
# - CustomerId_NAR
# - CustomerName_NAR
# - account_segmentation
# - total_arr
# - ats_owner
# - ae_owner
# - GEO
# - CustomerId_NAR_Clean

# %%
output_path = "/Applications/WorkDataSets/WadeList_TakeoutHorizon.csv"

filtered_contacts.to_csv(output_path, index=False)

print(f"💾 Export complete! File saved to: {output_path}")
# Out:
# 💾 Export complete! File saved to: /Applications/WorkDataSets/WadeList_TakeoutHorizon.csv

# %%
# Step 1. Merge stage and play info into your contacts
contacts_enriched = filtered_contacts.merge(
    stage_filtered[
        [
            "customer_id",
            "tech_play_type_label",
            "from_stage",
            "from_stage_date",
            "to_stage",
            "to_stage_date",
            "account_segmentation",
            "line_of_business",
            "partner_of_record",
            "country",
            "city",
        ]
    ],
    left_on="CustomerId_NAR",
    right_on="customer_id",
    how="left"
)

# Step 2. Export
output_path = "/Applications/WorkDataSets/WadeList_TakeoutHorizon_FULL.csv"
contacts_enriched.to_csv(output_path, index=False)

print(f"💾 Export complete! File saved to: {output_path}")
print(f"✅ Rows exported: {len(contacts_enriched)}")
print("🧱 Columns included:", contacts_enriched.columns.tolist())
# Out:
# 💾 Export complete! File saved to: /Applications/WorkDataSets/WadeList_TakeoutHorizon_FULL.csv
# ✅ Rows exported: 621
# 🧱 Columns included: ['party_number', 'email_address', 'person_name', 'party_unique_name', 'department_code', 'do_not_contact_flag', 'do_not_email_flag', 'do_not_mail_flag', 'job_title', 'job_title_code', 'sales_buying_role_code', 'sales_affinity_code', 'company_name', 'account_type', 'country_x', 'state', 'city_x', 'line_of_business_x', 'CustomerId_NAR', 'CustomerName_NAR', 'account_segmentation_x', 'total_arr', 'ats_owner', 'ae_owner', 'GEO', 'CustomerId_NAR_Clean', 'customer_id', 'tech_play_type_label', 'from_stage', 'from_stage_date', 'to_stage', 'to_stage_date', 'account_segmentation_y', 'line_of_business_y', 'partner_of_record', 'country_y', 'city_y']
